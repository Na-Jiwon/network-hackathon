# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install fasttext

# %%
seed_value = 777

# %%
import fasttext

import pandas as pd
import numpy as np
import random
import statsmodels as sm
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight


from sklearn.metrics import accuracy_score

from lightgbm import LGBMClassifier

import gensim
from gensim.models import Word2Vec
from gensim.models import FastText

import joblib

import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, Dense, Dropout, LayerNormalization
from tensorflow.keras.layers import MultiHeadAttention, Lambda
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D
from tensorflow.keras import Input, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy

from tensorflow.keras.models import save_model
from tensorflow.keras.models import load_model

tf.random.set_seed(seed_value)
np.random.seed(seed_value)
random.seed(seed_value)

# %%
label_sample_org = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/백지짱_분야2/Submit/data/Q2_label_sample.csv')
train_org = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/백지짱_분야2/Submit/data/Q2_train.csv')
test_org = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/백지짱_분야2/Submit/data/Q2_test.csv')

# %%
print(label_sample_org.shape)
print(train_org.shape)
print(test_org.shape)
# Out:
# (4327, 2)
# (9322, 13)
# (37671, 12)

# %%
train_change_msg= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/백지짱_분야2/Submit/data/train_map_3.csv')
test_change_msg = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/백지짱_분야2/Submit/data/test_map_3.csv')

# %%
print(train_change_msg.shape)
print(test_change_msg.shape)
# Out:
# (9322, 13)
# (37671, 12)

# %% [markdown]
# # **중복 제거**

# %%
# column의 각 행이 동일한 데이터로 되어있는지 확인하는 함수
# ex) a,b,c로 되어있는 행에서 a=b=c인지 확인, 다르면 list에 append

def different_value_count(df, column):
    different_label = []

    for i in range(df.shape[0]):
        type_value = df.loc[df.index[i], column]
        if len(set(type_value)) > 1:
            different_label.append(df.index[i])

    print(len(different_label))

# %%
# column의 각 행이 동일한 데이터로 되어있는지 확인하는 함수
# ex) a,b,c로 되어있는 행에서 a=b=c인지 확인

def different_value_df(df, column):
    different_index = []

    for i in range(df.shape[0]):
        type_value = df.loc[df.index[i], column]
        if len(set(type_value)) > 1:
            different_index.append(df.index[i])

    different_label = pd.DataFrame(different_index, columns = ['ticketno'])
    different_label = pd.merge(different_label, df[column], how = 'inner', on = 'ticketno')

    return different_label

# %%
# root_cause_type의 각 행의 값이 동일하면 맨 처음 값으로 변경되는 함수
# ex) a=b=c ==> a로 변경

def replace_root_cause_type(row):
    if 'PowerFail' in row:
        return 'PowerFail'
    elif 'UnitFail' in row:
        return 'UnitFail'
    elif 'LinkCut' in row:
        return 'LinkCut'
    return row

# %%
def unpack_list(lst):
    """
    list를 str로 변환하는 함수

    Args:
        lst (list): str로 변환하고 싶은 list

    Returns:
        str로 변환된 list의 요소들을 ','로 연결시킨 문자열
    """

    return ','.join(str(x) for x in lst)

# %% [markdown]
# ## **train, test divide**

# %%
# 필요 컬럼들만 모아 새로운 df 생성

col = ['ticketno', 'alarmtime', 'alarmlevel', 'alarmmsg_original','site', 'root_cause_type']
train_divide = train_change_msg[col]
train_divide.head()
# Out:
#      ticketno                  alarmtime  alarmlevel alarmmsg_original  site  \
# 0  21122633.0  2022-12-01 00:02:24+09:00           5    ETHERNET-ERROR  ACEN
# 1  21122633.0  2022-12-01 00:17:15+09:00           5    ETHERNET-ERROR  ACEN
# 2  21122633.0  2022-12-01 00:32:11+09:00           5    ETHERNET-ERROR  ACEN
# 3  21122633.0  2022-12-01 00:47:10+09:00           5    ETHERNET-ERROR  ACEN
# 4  21122633.0  2022-12-01 01:02:24+09:00           5    ETHERNET-ERROR  ACEN
#
#   root_cause_type
# 0         LinkCut
# 1         LinkCut
# 2         LinkCut
# 3         LinkCut
# 4         LinkCut

# %%
# ticketno / alarmtime / alarmlevel 별로 정렬(sort)

train_divide = train_divide.sort_values(['ticketno', 'alarmtime', 'alarmlevel', 'site', 'root_cause_type'])
train_divide.head()
# Out:
#         ticketno                  alarmtime  alarmlevel  \
# 1085  14753084.0  2022-12-02 13:13:48+09:00           4
# 1086  14753084.0  2022-12-02 13:13:48+09:00           4
# 1087  14753084.0  2022-12-02 13:13:48+09:00           7
# 1088  14753084.0  2022-12-02 13:13:48+09:00           7
# 1089  14753084.0  2022-12-02 13:13:48+09:00           7
#
#            alarmmsg_original  site root_cause_type
# 1085  POWER-SUPPLY-UNIT-FAIL  ABNE       PowerFail
# 1086  POWER-SUPPLY-UNIT-FAIL  ABNE       PowerFail
# 1087      ETHERNET-LINK-FAIL  ABNE       PowerFail
# 1088      ETHERNET-LINK-FAIL  ABNE       PowerFail
# 1089      ETHERNET-LINK-FAIL  ABNE       PowerFail

# %%
test_col = ['ticketno', 'alarmtime', 'alarmlevel', 'alarmmsg_original','site']

test_divide = test_change_msg[test_col]
test_divide.head()
# Out:
#      ticketno                  alarmtime  alarmlevel  \
# 0  21812391.0  2022-12-25 00:02:16+09:00           5
# 1  21775988.0  2022-12-25 00:02:51+09:00           5
# 2  21792259.0  2022-12-25 00:03:22+09:00           4
# 3  21812412.0  2022-12-25 00:03:33+09:00           5
# 4  21812417.0  2022-12-25 00:03:39+09:00           5
#
#           alarmmsg_original  site
# 0            LOSS-OF-SIGNAL  AEAQ
# 1            LOSS-OF-SIGNAL  ADZW
# 2  ALARM-RECEIVE-POWER-HIGH  AECE
# 3  BATTERY-ENVIRONMENT-FAIL  ACCN
# 4            LOSS-OF-SIGNAL  AEAQ

# %%
test_divide = test_divide.sort_values(['ticketno', 'alarmtime', 'alarmlevel','site'])
test_divide.head()
# Out:
#         ticketno                  alarmtime  alarmlevel  \
# 7436  15238899.0  2022-12-26 13:29:12+09:00           4
# 7437  15238899.0  2022-12-26 13:29:12+09:00           4
# 7438  15238899.0  2022-12-26 13:29:12+09:00           7
# 7439  15238899.0  2022-12-26 13:29:12+09:00           7
# 2769  15712444.0  2022-12-25 16:34:07+09:00           4
#
#            alarmmsg_original  site
# 7436  POWER-SUPPLY-UNIT-FAIL  ABMY
# 7437  POWER-SUPPLY-UNIT-FAIL  ABMY
# 7438      ETHERNET-LINK-FAIL  ABMY
# 7439      ETHERNET-LINK-FAIL  ABMY
# 2769  POWER-SUPPLY-UNIT-FAIL  AEOK

# %% [markdown]
# ## **train**

# %%
# ticketno 기준으로 중복된 행이 있으면 제일 마지막꺼만 남기고 제거

column = ['ticketno','alarmlevel','alarmmsg_original', 'site', 'root_cause_type']
train_last = train_divide[column].drop_duplicates(keep = 'last')
train_last.head()
# Out:
#         ticketno  alarmlevel            alarmmsg_original  site  \
# 1086  14753084.0           4       POWER-SUPPLY-UNIT-FAIL  ABNE
# 1089  14753084.0           7           ETHERNET-LINK-FAIL  ABNE
# 1090  14753084.0           5  ETHERNET-NO-RECEIVE-TRAFFIC  ABNE
# 1727  14771766.0           4       POWER-SUPPLY-UNIT-FAIL  ABLB
# 1729  14771766.0           7           ETHERNET-LINK-FAIL  ABLB
#
#      root_cause_type
# 1086       PowerFail
# 1089       PowerFail
# 1090       PowerFail
# 1727       PowerFail
# 1729       PowerFail

# %%
# ticketno를 그룹화하여 level과 msg 리스트로 만들기

train_last = pd.DataFrame(train_last.groupby(['ticketno'])[['alarmlevel', 'alarmmsg_original', 'site', 'root_cause_type']].agg(list))
train_last.head()
# Out:
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 14753084.0  [4, 7, 5]  [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL, E...
# 14771766.0     [4, 7]       [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL]
# 14777089.0     [4, 7]       [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL]
# 14790052.0        [4]                           [POWER-SUPPLY-UNIT-FAIL]
# 14879922.0  [4, 7, 5]  [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL, E...
#
#                           site                    root_cause_type
# ticketno
# 14753084.0  [ABNE, ABNE, ABNE]  [PowerFail, PowerFail, PowerFail]
# 14771766.0        [ABLB, ABLB]             [PowerFail, PowerFail]
# 14777089.0        [ABLZ, ABLZ]             [PowerFail, PowerFail]
# 14790052.0              [ACRX]                        [PowerFail]
# 14879922.0  [ABNE, ABNE, ABNE]  [PowerFail, PowerFail, PowerFail]

# %%
max_count_ticketno = max(train_last['alarmlevel'].apply(len))
max_count_ticketno
# Out:
# 10

# %%
# root_cause_type의 변경 값이 없는지 확인
different_value_count(train_last, 'root_cause_type')
# Out:
# 0

# %%
# site 변경 값이 없는지 확인

different_value_count(train_last, 'site')
# Out:
# 8

# %%
# 다른 site를 갖고 있는 data

different_value_df(train_last, 'site')
# Out:
#      ticketno                                               site
# 0  15885517.0  [AALT, ADTP, ADPA, AALT, ADTP, ADPA, AALT, ADT...
# 1  17872258.0                                       [ADMK, AFSV]
# 2  18390914.0                     [AAPL, AFIC, AFIC, AAPL, AAPL]
# 3  18392602.0                     [AFIC, AAPL, AAPL, AFIC, AFIC]
# 4  18522636.0                                 [ADRW, ADWR, ADWR]
# 5  18843859.0                     [AEMN, AEMN, AECB, AEMN, AEMN]
# 6  21257521.0   [ADML, ADML, ADML, AEWR, ADML, AEBW, AEBW, AEBW]
# 7  21667140.0               [AEJN, AEJN, AEJN, AEPT, AEPT, AEPT]

# %%
# map(lambda)를 사용하여 리스트 풀기
train_last = pd.DataFrame(train_last.applymap(lambda x: unpack_list(x)))

print(len(train_last))
train_last.head(10)
# Out:
# 1114
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 14753084.0      4,7,5  POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL,ETHE...
# 14771766.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14777089.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14790052.0          4                             POWER-SUPPLY-UNIT-FAIL
# 14879922.0      4,7,5  POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL,ETHE...
# 14901137.0      4,7,5  POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL,ETHE...
# 14919180.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14922559.0      4,4,5                         FAN-FAIL,48V-FAIL,48V-FAIL
# 14999487.0        7,7              OPTICAL-REMOVE,OPTICAL-LOSS-OF-SIGNAL
# 15036874.0          7             NON-VOLATILE-RANDOM-ACCESS-MEMORY-FAIL
#
#                       site                root_cause_type
# ticketno
# 14753084.0  ABNE,ABNE,ABNE  PowerFail,PowerFail,PowerFail
# 14771766.0       ABLB,ABLB            PowerFail,PowerFail
# 14777089.0       ABLZ,ABLZ            PowerFail,PowerFail
# 14790052.0            ACRX                      PowerFail
# 14879922.0  ABNE,ABNE,ABNE  PowerFail,PowerFail,PowerFail
# 14901137.0  ABNE,ABNE,ABNE  PowerFail,PowerFail,PowerFail
# 14919180.0       ABOJ,ABOJ            PowerFail,PowerFail
# 14922559.0  AEIK,AEIK,AEIK  PowerFail,PowerFail,PowerFail
# 14999487.0       ADWN,ADWN              UnitFail,UnitFail
# 15036874.0            ADTI                       UnitFail

# %%
train_last_reset = train_last.reset_index()

train_last_reset.head()
# Out:
#      ticketno alarmlevel                                  alarmmsg_original  \
# 0  14753084.0      4,7,5  POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL,ETHE...
# 1  14771766.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 2  14777089.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 3  14790052.0          4                             POWER-SUPPLY-UNIT-FAIL
# 4  14879922.0      4,7,5  POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL,ETHE...
#
#              site                root_cause_type
# 0  ABNE,ABNE,ABNE  PowerFail,PowerFail,PowerFail
# 1       ABLB,ABLB            PowerFail,PowerFail
# 2       ABLZ,ABLZ            PowerFail,PowerFail
# 3            ACRX                      PowerFail
# 4  ABNE,ABNE,ABNE  PowerFail,PowerFail,PowerFail

# %%
# 새로운 데이터프레임 생성을 위한 빈 리스트
new_rows = []

# 데이터프레임 순회하며 ','로 분리된 값을 새로운 행으로 추가
for _, row in train_last_reset.iterrows():
    alarmlevels = row['alarmlevel'].split(',')
    alarmmsgs = row['alarmmsg_original'].split(',')
    sites = row['site'].split(',')
    root_cause_types = row['root_cause_type'].split(',')

    # 분리된 값들을 새로운 행으로 추가
    for i in range(len(alarmlevels)):
        new_row = {
            'ticketno': row['ticketno'],
            'alarmlevel': alarmlevels[i],
            'alarmmsg_original': alarmmsgs[i],
            'site': sites[i],
            'root_cause_type': root_cause_types[i]
        }
        new_rows.append(new_row)

# 새로운 데이터프레임 생성
train_level_asc = pd.DataFrame(new_rows)

# 결과 출력
train_level_asc.head()
# Out:
#      ticketno alarmlevel            alarmmsg_original  site root_cause_type
# 0  14753084.0          4       POWER-SUPPLY-UNIT-FAIL  ABNE       PowerFail
# 1  14753084.0          7           ETHERNET-LINK-FAIL  ABNE       PowerFail
# 2  14753084.0          5  ETHERNET-NO-RECEIVE-TRAFFIC  ABNE       PowerFail
# 3  14771766.0          4       POWER-SUPPLY-UNIT-FAIL  ABLB       PowerFail
# 4  14771766.0          7           ETHERNET-LINK-FAIL  ABLB       PowerFail

# %%
train_level_asc = train_level_asc.sort_values(['ticketno', 'alarmlevel', 'site', 'root_cause_type'],)
train_level_asc.head(10)
# Out:
#       ticketno alarmlevel            alarmmsg_original  site root_cause_type
# 0   14753084.0          4       POWER-SUPPLY-UNIT-FAIL  ABNE       PowerFail
# 2   14753084.0          5  ETHERNET-NO-RECEIVE-TRAFFIC  ABNE       PowerFail
# 1   14753084.0          7           ETHERNET-LINK-FAIL  ABNE       PowerFail
# 3   14771766.0          4       POWER-SUPPLY-UNIT-FAIL  ABLB       PowerFail
# 4   14771766.0          7           ETHERNET-LINK-FAIL  ABLB       PowerFail
# 5   14777089.0          4       POWER-SUPPLY-UNIT-FAIL  ABLZ       PowerFail
# 6   14777089.0          7           ETHERNET-LINK-FAIL  ABLZ       PowerFail
# 7   14790052.0          4       POWER-SUPPLY-UNIT-FAIL  ACRX       PowerFail
# 8   14879922.0          4       POWER-SUPPLY-UNIT-FAIL  ABNE       PowerFail
# 10  14879922.0          5  ETHERNET-NO-RECEIVE-TRAFFIC  ABNE       PowerFail

# %%
train_level_asc = pd.DataFrame(train_level_asc.groupby(['ticketno'])[['alarmlevel', 'alarmmsg_original', 'site', 'root_cause_type']].agg(list))
train_level_asc.head()
# Out:
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 14753084.0  [4, 5, 7]  [POWER-SUPPLY-UNIT-FAIL, ETHERNET-NO-RECEIVE-T...
# 14771766.0     [4, 7]       [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL]
# 14777089.0     [4, 7]       [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL]
# 14790052.0        [4]                           [POWER-SUPPLY-UNIT-FAIL]
# 14879922.0  [4, 5, 7]  [POWER-SUPPLY-UNIT-FAIL, ETHERNET-NO-RECEIVE-T...
#
#                           site                    root_cause_type
# ticketno
# 14753084.0  [ABNE, ABNE, ABNE]  [PowerFail, PowerFail, PowerFail]
# 14771766.0        [ABLB, ABLB]             [PowerFail, PowerFail]
# 14777089.0        [ABLZ, ABLZ]             [PowerFail, PowerFail]
# 14790052.0              [ACRX]                        [PowerFail]
# 14879922.0  [ABNE, ABNE, ABNE]  [PowerFail, PowerFail, PowerFail]

# %%
train_level_asc = pd.DataFrame(train_level_asc.applymap(lambda x: unpack_list(x)))

print(len(train_level_asc))
train_level_asc.head(10)
# Out:
# 1114
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 14753084.0      4,5,7  POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
# 14771766.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14777089.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14790052.0          4                             POWER-SUPPLY-UNIT-FAIL
# 14879922.0      4,5,7  POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
# 14901137.0      4,5,7  POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
# 14919180.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14922559.0      4,4,5                         FAN-FAIL,48V-FAIL,48V-FAIL
# 14999487.0        7,7              OPTICAL-REMOVE,OPTICAL-LOSS-OF-SIGNAL
# 15036874.0          7             NON-VOLATILE-RANDOM-ACCESS-MEMORY-FAIL
#
#                       site                root_cause_type
# ticketno
# 14753084.0  ABNE,ABNE,ABNE  PowerFail,PowerFail,PowerFail
# 14771766.0       ABLB,ABLB            PowerFail,PowerFail
# 14777089.0       ABLZ,ABLZ            PowerFail,PowerFail
# 14790052.0            ACRX                      PowerFail
# 14879922.0  ABNE,ABNE,ABNE  PowerFail,PowerFail,PowerFail
# 14901137.0  ABNE,ABNE,ABNE  PowerFail,PowerFail,PowerFail
# 14919180.0       ABOJ,ABOJ            PowerFail,PowerFail
# 14922559.0  AEIK,AEIK,AEIK  PowerFail,PowerFail,PowerFail
# 14999487.0       ADWN,ADWN              UnitFail,UnitFail
# 15036874.0            ADTI                       UnitFail

# %%
# 변경되는 값이 없으므로 root_cause_type을 한개의 값으로 변경
train_level_asc['root_cause_type'] = train_level_asc['root_cause_type'].apply(replace_root_cause_type)
train_level_asc.head()
# Out:
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 14753084.0      4,5,7  POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
# 14771766.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14777089.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14790052.0          4                             POWER-SUPPLY-UNIT-FAIL
# 14879922.0      4,5,7  POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
#
#                       site root_cause_type
# ticketno
# 14753084.0  ABNE,ABNE,ABNE       PowerFail
# 14771766.0       ABLB,ABLB       PowerFail
# 14777089.0       ABLZ,ABLZ       PowerFail
# 14790052.0            ACRX       PowerFail
# 14879922.0  ABNE,ABNE,ABNE       PowerFail

# %% [markdown]
# ## **test**

# %%
# ticketno 기준으로 중복된 행이 있으면 제일 처음꺼만 남기고 제거

col = ['ticketno', 'alarmlevel', 'alarmmsg_original', 'site']
test_last = test_divide[col].drop_duplicates(keep = 'last')
test_last.head()
# Out:
#         ticketno  alarmlevel            alarmmsg_original  site
# 7437  15238899.0           4       POWER-SUPPLY-UNIT-FAIL  ABMY
# 7439  15238899.0           7           ETHERNET-LINK-FAIL  ABMY
# 2770  15712444.0           4       POWER-SUPPLY-UNIT-FAIL  AEOK
# 5965  15723187.0           5  ETHERNET-NO-RECEIVE-TRAFFIC  ACTL
# 6083  15723187.0           4       POWER-SUPPLY-UNIT-FAIL  ACTL

# %%
test_last = pd.DataFrame(test_last.groupby(['ticketno'])[['alarmlevel', 'alarmmsg_original', 'site']].agg(list))
test_last.head()
# Out:
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 15238899.0     [4, 7]       [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL]
# 15712444.0        [4]                           [POWER-SUPPLY-UNIT-FAIL]
# 15723187.0     [5, 4]  [ETHERNET-NO-RECEIVE-TRAFFIC, POWER-SUPPLY-UNI...
# 15737103.0     [4, 7]       [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL]
# 15737132.0     [4, 7]       [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL]
#
#                     site
# ticketno
# 15238899.0  [ABMY, ABMY]
# 15712444.0        [AEOK]
# 15723187.0  [ACTL, ACTL]
# 15737103.0  [ACQL, ACQL]
# 15737132.0  [ACQL, ACQL]

# %%
max_count_ticketno = max(test_last['alarmlevel'].apply(len))
max_count_ticketno
# Out:
# 42

# %%
# site 변경 값이 없는지 확인
different_value_count(test_last, 'site')
# Out:
# 447

# %%
# site가 다른 data
different_value_df(test_last, 'site')
# Out:
#        ticketno                                               site
# 0    18602743.0  [AAPI, AAPI, AFIC, AAPI, AEYX, AAPI, AEYX, AAP...
# 1    21819680.0                     [AEAZ, AEAA, AEAA, AEAZ, AEAA]
# 2    21827851.0                                       [ABFM, ADFL]
# 3    21828572.0                           [AADN, AADO, AADN, AADO]
# 4    21829232.0                                       [AEPG, ADUO]
# ..          ...                                                ...
# 442  22008868.0                                       [ADKU, ADTE]
# 443  22008913.0                                       [ACAR, ACCK]
# 444  22009895.0               [ADDF, ADFE, ADFE, ADFE, ADFE, ADDF]
# 445  22014653.0                     [AEBH, AEBH, AEBH, ACBY, ACBY]
# 446  22014673.0                     [AFHD, AFHD, AFHD, ACTQ, ACTQ]
#
# [447 rows x 2 columns]

# %%
test_last = pd.DataFrame(test_last.applymap(lambda x: unpack_list(x)))

print(len(test_last))
test_last.head(10)
# Out:
# 4327
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 15238899.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 15712444.0          4                             POWER-SUPPLY-UNIT-FAIL
# 15723187.0        5,4  ETHERNET-NO-RECEIVE-TRAFFIC,POWER-SUPPLY-UNIT-...
# 15737103.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 15737132.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 16188560.0          4                                            BOOTING
# 16199806.0          4                             POWER-SUPPLY-UNIT-FAIL
# 16201784.0    4,7,5,5  POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL,ETHE...
# 16203726.0      4,7,5  POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL,ETHE...
# 16237988.0          7                                     OPTICAL-REMOVE
#
#                            site
# ticketno
# 15238899.0            ABMY,ABMY
# 15712444.0                 AEOK
# 15723187.0            ACTL,ACTL
# 15737103.0            ACQL,ACQL
# 15737132.0            ACQL,ACQL
# 16188560.0                 AEHN
# 16199806.0                 ADFU
# 16201784.0  ABNX,ABNX,ABNX,ABNX
# 16203726.0       ABOE,ABOE,ABOE
# 16237988.0                 ABRV

# %%
test_last_reset = test_last.reset_index()

test_last_reset.head()
# Out:
#      ticketno alarmlevel                                  alarmmsg_original  \
# 0  15238899.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 1  15712444.0          4                             POWER-SUPPLY-UNIT-FAIL
# 2  15723187.0        5,4  ETHERNET-NO-RECEIVE-TRAFFIC,POWER-SUPPLY-UNIT-...
# 3  15737103.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 4  15737132.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
#
#         site
# 0  ABMY,ABMY
# 1       AEOK
# 2  ACTL,ACTL
# 3  ACQL,ACQL
# 4  ACQL,ACQL

# %%
# 새로운 데이터프레임 생성을 위한 빈 리스트
new_rows = []

# 데이터프레임 순회하며 ','로 분리된 값을 새로운 행으로 추가
for _, row in test_last_reset.iterrows():
    alarmlevels = row['alarmlevel'].split(',')
    alarmmsgs = row['alarmmsg_original'].split(',')
    sites = row['site'].split(',')


    # 분리된 값들을 새로운 행으로 추가
    for i in range(len(alarmlevels)):
        new_row = {
            'ticketno': row['ticketno'],
            'alarmlevel': alarmlevels[i],
            'alarmmsg_original': alarmmsgs[i],
            'site': sites[i]
        }
        new_rows.append(new_row)

# 새로운 데이터프레임 생성
test_level_asc = pd.DataFrame(new_rows)

# 결과 출력
test_level_asc.head()
# Out:
#      ticketno alarmlevel            alarmmsg_original  site
# 0  15238899.0          4       POWER-SUPPLY-UNIT-FAIL  ABMY
# 1  15238899.0          7           ETHERNET-LINK-FAIL  ABMY
# 2  15712444.0          4       POWER-SUPPLY-UNIT-FAIL  AEOK
# 3  15723187.0          5  ETHERNET-NO-RECEIVE-TRAFFIC  ACTL
# 4  15723187.0          4       POWER-SUPPLY-UNIT-FAIL  ACTL

# %%
test_level_asc = test_level_asc.sort_values(['ticketno', 'alarmlevel', 'site'])
test_level_asc.head(10)
# Out:
#      ticketno alarmlevel            alarmmsg_original  site
# 0  15238899.0          4       POWER-SUPPLY-UNIT-FAIL  ABMY
# 1  15238899.0          7           ETHERNET-LINK-FAIL  ABMY
# 2  15712444.0          4       POWER-SUPPLY-UNIT-FAIL  AEOK
# 4  15723187.0          4       POWER-SUPPLY-UNIT-FAIL  ACTL
# 3  15723187.0          5  ETHERNET-NO-RECEIVE-TRAFFIC  ACTL
# 5  15737103.0          4       POWER-SUPPLY-UNIT-FAIL  ACQL
# 6  15737103.0          7           ETHERNET-LINK-FAIL  ACQL
# 7  15737132.0          4       POWER-SUPPLY-UNIT-FAIL  ACQL
# 8  15737132.0          7           ETHERNET-LINK-FAIL  ACQL
# 9  16188560.0          4                      BOOTING  AEHN

# %%
test_level_asc = pd.DataFrame(test_level_asc.groupby(['ticketno'])[['alarmlevel', 'alarmmsg_original', 'site']].agg(list))
test_level_asc.head()
# Out:
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 15238899.0     [4, 7]       [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL]
# 15712444.0        [4]                           [POWER-SUPPLY-UNIT-FAIL]
# 15723187.0     [4, 5]  [POWER-SUPPLY-UNIT-FAIL, ETHERNET-NO-RECEIVE-T...
# 15737103.0     [4, 7]       [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL]
# 15737132.0     [4, 7]       [POWER-SUPPLY-UNIT-FAIL, ETHERNET-LINK-FAIL]
#
#                     site
# ticketno
# 15238899.0  [ABMY, ABMY]
# 15712444.0        [AEOK]
# 15723187.0  [ACTL, ACTL]
# 15737103.0  [ACQL, ACQL]
# 15737132.0  [ACQL, ACQL]

# %%
test_level_asc = pd.DataFrame(test_level_asc.applymap(lambda x: unpack_list(x)))

print(len(test_level_asc))
test_level_asc.head(10)
# Out:
# 4327
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 15238899.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 15712444.0          4                             POWER-SUPPLY-UNIT-FAIL
# 15723187.0        4,5  POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
# 15737103.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 15737132.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 16188560.0          4                                            BOOTING
# 16199806.0          4                             POWER-SUPPLY-UNIT-FAIL
# 16201784.0    4,5,5,7  POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
# 16203726.0      4,5,7  POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
# 16237988.0          7                                     OPTICAL-REMOVE
#
#                            site
# ticketno
# 15238899.0            ABMY,ABMY
# 15712444.0                 AEOK
# 15723187.0            ACTL,ACTL
# 15737103.0            ACQL,ACQL
# 15737132.0            ACQL,ACQL
# 16188560.0                 AEHN
# 16199806.0                 ADFU
# 16201784.0  ABNX,ABNX,ABNX,ABNX
# 16203726.0       ABOE,ABOE,ABOE
# 16237988.0                 ABRV

# %% [markdown]
# # **preprocessing**

# %%
msg_train = train_level_asc['alarmmsg_original']
print(len(msg_train))
# Out:
# 1114
# ticketno
# 14753084.0    POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
# 14771766.0            POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14777089.0            POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14790052.0                               POWER-SUPPLY-UNIT-FAIL
# 14879922.0    POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
#                                     ...
# 21792877.0                               OPTICAL-LOSS-OF-SIGNAL
# 21793984.0                               OPTICAL-LOSS-OF-SIGNAL
# 21799077.0    DATA-COMMUNICATE-CHANNEL-FAIL,PSEUDOWIRE-LOSS-...
# 21809789.0                               OPTICAL-LOSS-OF-SIGNAL
# 21811213.0                               OPTICAL-LOSS-OF-SIGNAL
# Name: alarmmsg_original, Length: 1114, dtype: object

# %%
# 문장에서 단어를 분리할 때 사용한 ','를 공백으로 대체
msg_train = [x.replace(',', ' ') for x in msg_train]
len(msg_train)
# Out:
# 1114

# %%
msg_test = test_level_asc['alarmmsg_original']
print(len(msg_test))
# Out:
# 4327
# ticketno
# 15238899.0            POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 15712444.0                               POWER-SUPPLY-UNIT-FAIL
# 15723187.0    POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
# 15737103.0            POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 15737132.0            POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
#                                     ...
# 22015278.0                             ALARM-RECEIVE-POWER-HIGH
# 22015300.0                                       LOSS-OF-SIGNAL
# 23818326.0      ETHERNET-FAIL,SERVER-SIGNAL-FAIL,LOSS-OF-SIGNAL
# 23819373.0                                   SERVER-SIGNAL-FAIL
# 26067480.0                                      LOSS-OF-CONNECT
# Name: alarmmsg_original, Length: 4327, dtype: object

# %%
# 문장에서 단어를 분리할 때 사용한 ','를 공백으로 대체
msg_test = [x.replace(',', ' ') for x in msg_test]
len(msg_test)
# Out:
# 4327

# %% [markdown]
# # **train**

# %%
train_level_asc.head()
# Out:
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 14753084.0      4,5,7  POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
# 14771766.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14777089.0        4,7          POWER-SUPPLY-UNIT-FAIL,ETHERNET-LINK-FAIL
# 14790052.0          4                             POWER-SUPPLY-UNIT-FAIL
# 14879922.0      4,5,7  POWER-SUPPLY-UNIT-FAIL,ETHERNET-NO-RECEIVE-TRA...
#
#                       site root_cause_type
# ticketno
# 14753084.0  ABNE,ABNE,ABNE       PowerFail
# 14771766.0       ABLB,ABLB       PowerFail
# 14777089.0       ABLZ,ABLZ       PowerFail
# 14790052.0            ACRX       PowerFail
# 14879922.0  ABNE,ABNE,ABNE       PowerFail

# %%
# '-'와 ',' 제거 함수 정의
def remove_chars(text):
    text = text.replace('-', ' ').replace(',', ' ')
    return text

# apply 함수를 사용하여 컬럼의 값에 함수 적용
train_level_asc['alarmmsg_original'] = train_level_asc['alarmmsg_original'].apply(remove_chars)
# Out:
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 14753084.0      4,5,7  POWER SUPPLY UNIT FAIL ETHERNET NO RECEIVE TRA...
# 14771766.0        4,7          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL
# 14777089.0        4,7          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL
# 14790052.0          4                             POWER SUPPLY UNIT FAIL
# 14879922.0      4,5,7  POWER SUPPLY UNIT FAIL ETHERNET NO RECEIVE TRA...
# ...               ...                                                ...
# 21792877.0          7                             OPTICAL LOSS OF SIGNAL
# 21793984.0          7                             OPTICAL LOSS OF SIGNAL
# 21799077.0      5,5,7  DATA COMMUNICATE CHANNEL FAIL PSEUDOWIRE LOSS ...
# 21809789.0          7                             OPTICAL LOSS OF SIGNAL
# 21811213.0          7                             OPTICAL LOSS OF SIGNAL
#
#                       site root_cause_type
# ticketno
# 14753084.0  ABNE,ABNE,ABNE       PowerFail
# 14771766.0       ABLB,ABLB       PowerFail
# 14777089.0       ABLZ,ABLZ       PowerFail
# 14790052.0            ACRX       PowerFail
# 14879922.0  ABNE,ABNE,ABNE       PowerFail
# ...                    ...             ...
# 21792877.0            ABZD         LinkCut
# 21793984.0            ADOK         LinkCut
# 21799077.0  ABUY,ABUY,ABUY         LinkCut
# 21809789.0            ADKA         LinkCut
# 21811213.0            ABZO         LinkCut
#
# [1114 rows x 4 columns]

# %%
# fasttext에 input 데이터의 형식을 지키기 위해 변환 필요
# 레이블 형식으로 변환하는 함수 정의
def convert_to_label(row):
    return f'__label__{row}'

# 'root_cause_type' 컬럼 값 변환
train_level_asc['root_cause_type'] = train_level_asc['root_cause_type'].apply(convert_to_label)
# Out:
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 14753084.0      4,5,7  POWER SUPPLY UNIT FAIL ETHERNET NO RECEIVE TRA...
# 14771766.0        4,7          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL
# 14777089.0        4,7          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL
# 14790052.0          4                             POWER SUPPLY UNIT FAIL
# 14879922.0      4,5,7  POWER SUPPLY UNIT FAIL ETHERNET NO RECEIVE TRA...
# ...               ...                                                ...
# 21792877.0          7                             OPTICAL LOSS OF SIGNAL
# 21793984.0          7                             OPTICAL LOSS OF SIGNAL
# 21799077.0      5,5,7  DATA COMMUNICATE CHANNEL FAIL PSEUDOWIRE LOSS ...
# 21809789.0          7                             OPTICAL LOSS OF SIGNAL
# 21811213.0          7                             OPTICAL LOSS OF SIGNAL
#
#                       site     root_cause_type
# ticketno
# 14753084.0  ABNE,ABNE,ABNE  __label__PowerFail
# 14771766.0       ABLB,ABLB  __label__PowerFail
# 14777089.0       ABLZ,ABLZ  __label__PowerFail
# 14790052.0            ACRX  __label__PowerFail
# 14879922.0  ABNE,ABNE,ABNE  __label__PowerFail
# ...                    ...                 ...
# 21792877.0            ABZD    __label__LinkCut
# 21793984.0            ADOK    __label__LinkCut
# 21799077.0  ABUY,ABUY,ABUY    __label__LinkCut
# 21809789.0            ADKA    __label__LinkCut
# 21811213.0            ABZO    __label__LinkCut
#
# [1114 rows x 4 columns]

# %%
col = ['root_cause_type', 'alarmmsg_original']
input_train_ft = train_level_asc[col]      # input train data
input_train_ft.head()
# Out:
#                root_cause_type  \
# ticketno
# 14753084.0  __label__PowerFail
# 14771766.0  __label__PowerFail
# 14777089.0  __label__PowerFail
# 14790052.0  __label__PowerFail
# 14879922.0  __label__PowerFail
#
#                                             alarmmsg_original
# ticketno
# 14753084.0  POWER SUPPLY UNIT FAIL ETHERNET NO RECEIVE TRA...
# 14771766.0          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL
# 14777089.0          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL
# 14790052.0                             POWER SUPPLY UNIT FAIL
# 14879922.0  POWER SUPPLY UNIT FAIL ETHERNET NO RECEIVE TRA...

# %%
# txt 파일로 저장 (fasttex에 넣으려면 txt 형식 필요)
output_file_path = 'input_train_ft.txt'
input_train_ft.to_csv(output_file_path, sep = '\t', index = False, header = False)

# %% [markdown]
# # **test**

# %%
# '-'와 ',' 제거 함수 정의
def remove_chars(text):
    text = text.replace('-', ' ').replace(',', ' ')
    return text

# apply 함수를 사용하여 컬럼의 값에 함수 적용
test_level_asc['alarmmsg_original'] = test_level_asc['alarmmsg_original'].apply(remove_chars)
# Out:
#            alarmlevel                                  alarmmsg_original  \
# ticketno
# 15238899.0        4,7          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL
# 15712444.0          4                             POWER SUPPLY UNIT FAIL
# 15723187.0        4,5  POWER SUPPLY UNIT FAIL ETHERNET NO RECEIVE TRA...
# 15737103.0        4,7          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL
# 15737132.0        4,7          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL
# ...               ...                                                ...
# 22015278.0          4                           ALARM RECEIVE POWER HIGH
# 22015300.0          5                                     LOSS OF SIGNAL
# 23818326.0      4,5,5    ETHERNET FAIL SERVER SIGNAL FAIL LOSS OF SIGNAL
# 23819373.0          5                                 SERVER SIGNAL FAIL
# 26067480.0          5                                    LOSS OF CONNECT
#
#                       site
# ticketno
# 15238899.0       ABMY,ABMY
# 15712444.0            AEOK
# 15723187.0       ACTL,ACTL
# 15737103.0       ACQL,ACQL
# 15737132.0       ACQL,ACQL
# ...                    ...
# 22015278.0            AEMD
# 22015300.0            AEAQ
# 23818326.0  AEKU,AEKU,AEKU
# 23819373.0            AEKU
# 26067480.0            ADUS
#
# [4327 rows x 3 columns]

# %%
col = ['alarmmsg_original']
output_test_last = test_level_asc[col]
output_test_last.head()
# Out:
#                                             alarmmsg_original
# ticketno
# 15238899.0          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL
# 15712444.0                             POWER SUPPLY UNIT FAIL
# 15723187.0  POWER SUPPLY UNIT FAIL ETHERNET NO RECEIVE TRA...
# 15737103.0          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL
# 15737132.0          POWER SUPPLY UNIT FAIL ETHERNET LINK FAIL

# %%
# txt 파일로 저장
output_file_path = 'output_test_ft.txt'
output_test_last.to_csv(output_file_path, sep = '\t', index = False, header = False)

# %% [markdown]
# # **fasttext - 모델 학습**

# %%
import fasttext

# 훈련 데이터 파일 경로
train_data_path = '/content/input_train_ft.txt'

# fasttext.train_supervised() 함수로 텍스트 분류 모델 훈련
model = fasttext.train_supervised(input = train_data_path, epoch = 100, lr = 1.0, wordNgrams = 2)

print(model)

# %% [markdown]
# # **fasttext - 모델 훈련**

# %%
import fasttext


# 테스트 데이터 파일 경로
test_data_path = '/content/output_test_ft.txt'

# 테스트 데이터 읽기
with open(test_data_path, 'r', encoding='utf-8') as test_file:
    lines = test_file.readlines()

# 예측 수행 및 결과 저장
predictions = []
for line in lines:
    line = line.strip()  # 줄바꿈 문자 제거
    pred_label = model.predict(line)[0][0]

#    pred_label = model.predict((line), k=3) # proba 뽑을때
    predictions.append(pred_label)

# 예측 결과 출력
for idx, pred_label in enumerate(predictions):
    print(f"Test Sample {idx+1} Predicted Label: {pred_label}")
# Out:
# Test Sample 1 Predicted Label: __label__PowerFail
# Test Sample 2 Predicted Label: __label__PowerFail
# Test Sample 3 Predicted Label: __label__PowerFail
# Test Sample 4 Predicted Label: __label__PowerFail
# Test Sample 5 Predicted Label: __label__PowerFail
# Test Sample 6 Predicted Label: __label__UnitFail
# Test Sample 7 Predicted Label: __label__PowerFail
# Test Sample 8 Predicted Label: __label__PowerFail
# Test Sample 9 Predicted Label: __label__PowerFail
# Test Sample 10 Predicted Label: __label__UnitFail
# Test Sample 11 Predicted Label: __label__PowerFail
# Test Sample 12 Predicted Label: __label__UnitFail
# Test Sample 13 Predicted Label: __label__UnitFail
# Test Sample 14 Predicted Label: __label__PowerFail
# Test Sample 15 Predicted Label: __label__PowerFail
# Test Sample 16 Predicted Label: __label__UnitFail
# Test Sample 17 Predicted Label: __label__UnitFail
# Test Sample 18 Predicted Label: __label__UnitFail
# Test Sample 19 Predicted Label: __label__UnitFail
# Test Sample 20 Predicted Label: __label__UnitFail
# Test Sample 21 Predicted Label: __label__PowerFail
# Test Sample 22 Predicted Label: __label__PowerFail
# Test Sample 23 Predicted Label: __label__PowerFail
# Test Sample 24 Predicted Label: __label__PowerFail
# Test Sample 25 Predicted Label: __label__PowerFail
# Test Sample 26 Predicted Label: __label__PowerFail
# Test Sample 27 Predicted Label: __label__UnitFail
# Test Sample 28 Predicted Label: __label__UnitFail
# Test Sample 29 Predicted Label: __label__UnitFail
# Test Sample 30 Predicted Label: __label__UnitFail
# Test Sample 31 Predicted Label: __label__UnitFail
# Test Sample 32 Predicted Label: __label__UnitFail
# Test Sample 33 Predicted Label: __label__UnitFail
# Test Sample 34 Predicted Label: __label__UnitFail
# Test Sample 35 Predicted Label: __label__UnitFail
# Test Sample 36 Predicted Label: __label__UnitFail
# Test Sample 37 Predicted Label: __label__UnitFail
# Test Sample 38 Predicted Label: __label__UnitFail
# Test Sample 39 Predicted Label: __label__UnitFail
# Test Sample 40 Predicted Label: __label__UnitFail
# Test Sample 41 Predicted Label: __label__UnitFail
# Test Sample 42 Predicted Label: __label__UnitFail
# Test Sample 43 Predicted Label: __label__UnitFail
# Test Sample 44 Predicted Label: __label__UnitFail
# Test Sample 45 Predicted Label: __label__UnitFail
# Test Sample 46 Predicted Label: __label__UnitFail
# Test Sample 47 Predicted Label: __label__UnitFail
# Test Sample 48 Predicted Label: __label__UnitFail
# Test Sample 49 Predicted Label: __label__UnitFail
# Test Sample 50 Predicted Label: __label__UnitFail
# Test Sample 51 Predicted Label: __label__UnitFail
# Test Sample 52 Predicted Label: __label__UnitFail
# Test Sample 53 Predicted Label: __label__UnitFail
# Test Sample 54 Predicted Label: __label__UnitFail
# Test Sample 55 Predicted Label: __label__UnitFail
# Test Sample 56 Predicted Label: __label__UnitFail
# Test Sample 57 Predicted Label: __label__UnitFail
# Test Sample 58 Predicted Label: __label__UnitFail
# Test Sample 59 Predicted Label: __label__UnitFail
# Test Sample 60 Predicted Label: __label__UnitFail
# Test Sample 61 Predicted Label: __label__UnitFail
# Test Sample 62 Predicted Label: __label__UnitFail
# Test Sample 63 Predicted Label: __label__UnitFail
# Test Sample 64 Predicted Label: __label__UnitFail
# Test Sample 65 Predicted Label: __label__UnitFail
# Test Sample 66 Predicted Label: __label__UnitFail
# Test Sample 67 Predicted Label: __label__UnitFail
# Test Sample 68 Predicted Label: __label__UnitFail
# Test Sample 69 Predicted Label: __label__UnitFail
# Test Sample 70 Predicted Label: __label__UnitFail
# Test Sample 71 Predicted Label: __label__UnitFail
# Test Sample 72 Predicted Label: __label__UnitFail
# Test Sample 73 Predicted Label: __label__UnitFail
# Test Sample 74 Predicted Label: __label__UnitFail
# Test Sample 75 Predicted Label: __label__UnitFail
# Test Sample 76 Predicted Label: __label__UnitFail
# Test Sample 77 Predicted Label: __label__UnitFail
# Test Sample 78 Predicted Label: __label__UnitFail
# Test Sample 79 Predicted Label: __label__UnitFail
# Test Sample 80 Predicted Label: __label__UnitFail
# Test Sample 81 Predicted Label: __label__UnitFail
# Test Sample 82 Predicted Label: __label__UnitFail
# Test Sample 83 Predicted Label: __label__UnitFail
# Test Sample 84 Predicted Label: __label__UnitFail
# Test Sample 85 Predicted Label: __label__UnitFail
# Test Sample 86 Predicted Label: __label__UnitFail
# Test Sample 87 Predicted Label: __label__UnitFail
# Test Sample 88 Predicted Label: __label__UnitFail
# Test Sample 89 Predicted Label: __label__UnitFail
# Test Sample 90 Predicted Label: __label__UnitFail
# Test Sample 91 Predicted Label: __label__UnitFail
# Test Sample 92 Predicted Label: __label__UnitFail
# Test Sample 93 Predicted Label: __label__UnitFail
# Test Sample 94 Predicted Label: __label__UnitFail
# Test Sample 95 Predicted Label: __label__UnitFail
# Test Sample 96 Predicted Label: __label__UnitFail
# Test Sample 97 Predicted Label: __label__UnitFail
# Test Sample 98 Predicted Label: __label__UnitFail
# Test Sample 99 Predicted Label: __label__UnitFail
# Test Sample 100 Predicted Label: __label__UnitFail
# Test Sample 101 Predicted Label: __label__UnitFail
# Test Sample 102 Predicted Label: __label__UnitFail
# Test Sample 103 Predicted Label: __label__UnitFail
# Test Sample 104 Predicted Label: __label__UnitFail
# Test Sample 105 Predicted Label: __label__UnitFail
# Test Sample 106 Predicted Label: __label__UnitFail
# Test Sample 107 Predicted Label: __label__UnitFail
# Test Sample 108 Predicted Label: __label__UnitFail
# Test Sample 109 Predicted Label: __label__UnitFail
# Test Sample 110 Predicted Label: __label__UnitFail
# Test Sample 111 Predicted Label: __label__PowerFail
# Test Sample 112 Predicted Label: __label__PowerFail
# Test Sample 113 Predicted Label: __label__PowerFail
# Test Sample 114 Predicted Label: __label__PowerFail
# Test Sample 115 Predicted Label: __label__UnitFail
# Test Sample 116 Predicted Label: __label__UnitFail
# Test Sample 117 Predicted Label: __label__UnitFail
# Test Sample 118 Predicted Label: __label__UnitFail
# Test Sample 119 Predicted Label: __label__LinkCut
# Test Sample 120 Predicted Label: __label__PowerFail
# Test Sample 121 Predicted Label: __label__PowerFail
# Test Sample 122 Predicted Label: __label__PowerFail
# Test Sample 123 Predicted Label: __label__PowerFail
# Test Sample 124 Predicted Label: __label__PowerFail
# Test Sample 125 Predicted Label: __label__PowerFail
# Test Sample 126 Predicted Label: __label__PowerFail
# Test Sample 127 Predicted Label: __label__PowerFail
# Test Sample 128 Predicted Label: __label__PowerFail
# Test Sample 129 Predicted Label: __label__PowerFail
# Test Sample 130 Predicted Label: __label__PowerFail
# Test Sample 131 Predicted Label: __label__PowerFail
# Test Sample 132 Predicted Label: __label__PowerFail
# Test Sample 133 Predicted Label: __label__PowerFail
# Test Sample 134 Predicted Label: __label__PowerFail
# Test Sample 135 Predicted Label: __label__PowerFail
# Test Sample 136 Predicted Label: __label__PowerFail
# Test Sample 137 Predicted Label: __label__PowerFail
# Test Sample 138 Predicted Label: __label__PowerFail
# Test Sample 139 Predicted Label: __label__PowerFail
# Test Sample 140 Predicted Label: __label__PowerFail
# Test Sample 141 Predicted Label: __label__PowerFail
# Test Sample 142 Predicted Label: __label__PowerFail
# Test Sample 143 Predicted Label: __label__PowerFail
# Test Sample 144 Predicted Label: __label__PowerFail
# Test Sample 145 Predicted Label: __label__PowerFail
# Test Sample 146 Predicted Label: __label__PowerFail
# Test Sample 147 Predicted Label: __label__PowerFail
# Test Sample 148 Predicted Label: __label__PowerFail
# Test Sample 149 Predicted Label: __label__PowerFail
# Test Sample 150 Predicted Label: __label__PowerFail
# Test Sample 151 Predicted Label: __label__PowerFail
# Test Sample 152 Predicted Label: __label__PowerFail
# Test Sample 153 Predicted Label: __label__PowerFail
# Test Sample 154 Predicted Label: __label__PowerFail
# Test Sample 155 Predicted Label: __label__PowerFail
# Test Sample 156 Predicted Label: __label__PowerFail
# Test Sample 157 Predicted Label: __label__PowerFail
# Test Sample 158 Predicted Label: __label__PowerFail
# Test Sample 159 Predicted Label: __label__PowerFail
# Test Sample 160 Predicted Label: __label__PowerFail
# Test Sample 161 Predicted Label: __label__PowerFail
# Test Sample 162 Predicted Label: __label__PowerFail
# Test Sample 163 Predicted Label: __label__PowerFail
# Test Sample 164 Predicted Label: __label__PowerFail
# Test Sample 165 Predicted Label: __label__PowerFail
# Test Sample 166 Predicted Label: __label__PowerFail
# Test Sample 167 Predicted Label: __label__PowerFail
# Test Sample 168 Predicted Label: __label__PowerFail
# Test Sample 169 Predicted Label: __label__PowerFail
# Test Sample 170 Predicted Label: __label__PowerFail
# Test Sample 171 Predicted Label: __label__PowerFail
# Test Sample 172 Predicted Label: __label__PowerFail
# Test Sample 173 Predicted Label: __label__PowerFail
# Test Sample 174 Predicted Label: __label__PowerFail
# Test Sample 175 Predicted Label: __label__PowerFail
# Test Sample 176 Predicted Label: __label__PowerFail
# Test Sample 177 Predicted Label: __label__PowerFail
# Test Sample 178 Predicted Label: __label__PowerFail
# Test Sample 179 Predicted Label: __label__PowerFail
# Test Sample 180 Predicted Label: __label__PowerFail
# Test Sample 181 Predicted Label: __label__PowerFail
# Test Sample 182 Predicted Label: __label__PowerFail
# Test Sample 183 Predicted Label: __label__PowerFail
# Test Sample 184 Predicted Label: __label__PowerFail
# Test Sample 185 Predicted Label: __label__PowerFail
# Test Sample 186 Predicted Label: __label__PowerFail
# Test Sample 187 Predicted Label: __label__PowerFail
# Test Sample 188 Predicted Label: __label__PowerFail
# Test Sample 189 Predicted Label: __label__PowerFail
# Test Sample 190 Predicted Label: __label__PowerFail
# Test Sample 191 Predicted Label: __label__PowerFail
# Test Sample 192 Predicted Label: __label__PowerFail
# Test Sample 193 Predicted Label: __label__PowerFail
# Test Sample 194 Predicted Label: __label__LinkCut
# Test Sample 195 Predicted Label: __label__UnitFail
# Test Sample 196 Predicted Label: __label__PowerFail
# Test Sample 197 Predicted Label: __label__PowerFail
# Test Sample 198 Predicted Label: __label__PowerFail
# Test Sample 199 Predicted Label: __label__PowerFail
# Test Sample 200 Predicted Label: __label__PowerFail
# Test Sample 201 Predicted Label: __label__PowerFail
# Test Sample 202 Predicted Label: __label__PowerFail
# Test Sample 203 Predicted Label: __label__PowerFail
# Test Sample 204 Predicted Label: __label__PowerFail
# Test Sample 205 Predicted Label: __label__LinkCut
# Test Sample 206 Predicted Label: __label__LinkCut
# Test Sample 207 Predicted Label: __label__LinkCut
# Test Sample 208 Predicted Label: __label__LinkCut
# Test Sample 209 Predicted Label: __label__LinkCut
# Test Sample 210 Predicted Label: __label__LinkCut
# Test Sample 211 Predicted Label: __label__LinkCut
# Test Sample 212 Predicted Label: __label__LinkCut
# Test Sample 213 Predicted Label: __label__LinkCut
# Test Sample 214 Predicted Label: __label__LinkCut
# Test Sample 215 Predicted Label: __label__LinkCut
# Test Sample 216 Predicted Label: __label__LinkCut
# Test Sample 217 Predicted Label: __label__LinkCut
# Test Sample 218 Predicted Label: __label__LinkCut
# Test Sample 219 Predicted Label: __label__LinkCut
# Test Sample 220 Predicted Label: __label__LinkCut
# Test Sample 221 Predicted Label: __label__LinkCut
# Test Sample 222 Predicted Label: __label__LinkCut
# Test Sample 223 Predicted Label: __label__LinkCut
# Test Sample 224 Predicted Label: __label__LinkCut
# Test Sample 225 Predicted Label: __label__LinkCut
# Test Sample 226 Predicted Label: __label__LinkCut
# Test Sample 227 Predicted Label: __label__LinkCut
# Test Sample 228 Predicted Label: __label__LinkCut
# Test Sample 229 Predicted Label: __label__LinkCut
# Test Sample 230 Predicted Label: __label__LinkCut
# Test Sample 231 Predicted Label: __label__LinkCut
# Test Sample 232 Predicted Label: __label__LinkCut
# Test Sample 233 Predicted Label: __label__LinkCut
# Test Sample 234 Predicted Label: __label__LinkCut
# Test Sample 235 Predicted Label: __label__LinkCut
# Test Sample 236 Predicted Label: __label__LinkCut
# Test Sample 237 Predicted Label: __label__LinkCut
# Test Sample 238 Predicted Label: __label__LinkCut
# Test Sample 239 Predicted Label: __label__LinkCut
# Test Sample 240 Predicted Label: __label__LinkCut
# Test Sample 241 Predicted Label: __label__LinkCut
# Test Sample 242 Predicted Label: __label__LinkCut
# Test Sample 243 Predicted Label: __label__LinkCut
# Test Sample 244 Predicted Label: __label__LinkCut
# Test Sample 245 Predicted Label: __label__LinkCut
# Test Sample 246 Predicted Label: __label__LinkCut
# Test Sample 247 Predicted Label: __label__PowerFail
# Test Sample 248 Predicted Label: __label__LinkCut
# Test Sample 249 Predicted Label: __label__LinkCut
# Test Sample 250 Predicted Label: __label__LinkCut
# Test Sample 251 Predicted Label: __label__PowerFail
# Test Sample 252 Predicted Label: __label__LinkCut
# Test Sample 253 Predicted Label: __label__LinkCut
# Test Sample 254 Predicted Label: __label__LinkCut
# Test Sample 255 Predicted Label: __label__LinkCut
# Test Sample 256 Predicted Label: __label__LinkCut
# Test Sample 257 Predicted Label: __label__PowerFail
# Test Sample 258 Predicted Label: __label__LinkCut
# Test Sample 259 Predicted Label: __label__LinkCut
# Test Sample 260 Predicted Label: __label__LinkCut
# Test Sample 261 Predicted Label: __label__LinkCut
# Test Sample 262 Predicted Label: __label__LinkCut
# Test Sample 263 Predicted Label: __label__PowerFail
# Test Sample 264 Predicted Label: __label__PowerFail
# Test Sample 265 Predicted Label: __label__PowerFail
# Test Sample 266 Predicted Label: __label__PowerFail
# Test Sample 267 Predicted Label: __label__PowerFail
# Test Sample 268 Predicted Label: __label__LinkCut
# Test Sample 269 Predicted Label: __label__LinkCut
# Test Sample 270 Predicted Label: __label__LinkCut
# Test Sample 271 Predicted Label: __label__PowerFail
# Test Sample 272 Predicted Label: __label__LinkCut
# Test Sample 273 Predicted Label: __label__PowerFail
# Test Sample 274 Predicted Label: __label__LinkCut
# Test Sample 275 Predicted Label: __label__PowerFail
# Test Sample 276 Predicted Label: __label__PowerFail
# Test Sample 277 Predicted Label: __label__PowerFail
# Test Sample 278 Predicted Label: __label__PowerFail
# Test Sample 279 Predicted Label: __label__LinkCut
# Test Sample 280 Predicted Label: __label__PowerFail
# Test Sample 281 Predicted Label: __label__LinkCut
# Test Sample 282 Predicted Label: __label__PowerFail
# Test Sample 283 Predicted Label: __label__PowerFail
# Test Sample 284 Predicted Label: __label__PowerFail
# Test Sample 285 Predicted Label: __label__LinkCut
# Test Sample 286 Predicted Label: __label__LinkCut
# Test Sample 287 Predicted Label: __label__PowerFail
# Test Sample 288 Predicted Label: __label__PowerFail
# Test Sample 289 Predicted Label: __label__LinkCut
# Test Sample 290 Predicted Label: __label__PowerFail
# Test Sample 291 Predicted Label: __label__LinkCut
# Test Sample 292 Predicted Label: __label__PowerFail
# Test Sample 293 Predicted Label: __label__LinkCut
# Test Sample 294 Predicted Label: __label__LinkCut
# Test Sample 295 Predicted Label: __label__PowerFail
# Test Sample 296 Predicted Label: __label__PowerFail
# Test Sample 297 Predicted Label: __label__PowerFail
# Test Sample 298 Predicted Label: __label__LinkCut
# Test Sample 299 Predicted Label: __label__PowerFail
# Test Sample 300 Predicted Label: __label__LinkCut
# Test Sample 301 Predicted Label: __label__PowerFail
# Test Sample 302 Predicted Label: __label__LinkCut
# Test Sample 303 Predicted Label: __label__PowerFail
# Test Sample 304 Predicted Label: __label__PowerFail
# Test Sample 305 Predicted Label: __label__LinkCut
# Test Sample 306 Predicted Label: __label__PowerFail
# Test Sample 307 Predicted Label: __label__LinkCut
# Test Sample 308 Predicted Label: __label__PowerFail
# Test Sample 309 Predicted Label: __label__LinkCut
# Test Sample 310 Predicted Label: __label__PowerFail
# Test Sample 311 Predicted Label: __label__PowerFail
# Test Sample 312 Predicted Label: __label__PowerFail
# Test Sample 313 Predicted Label: __label__PowerFail
# Test Sample 314 Predicted Label: __label__PowerFail
# Test Sample 315 Predicted Label: __label__PowerFail
# Test Sample 316 Predicted Label: __label__PowerFail
# Test Sample 317 Predicted Label: __label__PowerFail
# Test Sample 318 Predicted Label: __label__PowerFail
# Test Sample 319 Predicted Label: __label__PowerFail
# Test Sample 320 Predicted Label: __label__PowerFail
# Test Sample 321 Predicted Label: __label__PowerFail
# Test Sample 322 Predicted Label: __label__LinkCut
# Test Sample 323 Predicted Label: __label__PowerFail
# Test Sample 324 Predicted Label: __label__LinkCut
# Test Sample 325 Predicted Label: __label__PowerFail
# Test Sample 326 Predicted Label: __label__PowerFail
# Test Sample 327 Predicted Label: __label__PowerFail
# Test Sample 328 Predicted Label: __label__LinkCut
# Test Sample 329 Predicted Label: __label__PowerFail
# Test Sample 330 Predicted Label: __label__PowerFail
# Test Sample 331 Predicted Label: __label__PowerFail
# Test Sample 332 Predicted Label: __label__PowerFail
# Test Sample 333 Predicted Label: __label__PowerFail
# Test Sample 334 Predicted Label: __label__PowerFail
# Test Sample 335 Predicted Label: __label__LinkCut
# Test Sample 336 Predicted Label: __label__LinkCut
# Test Sample 337 Predicted Label: __label__PowerFail
# Test Sample 338 Predicted Label: __label__PowerFail
# Test Sample 339 Predicted Label: __label__LinkCut
# Test Sample 340 Predicted Label: __label__PowerFail
# Test Sample 341 Predicted Label: __label__PowerFail
# Test Sample 342 Predicted Label: __label__PowerFail
# Test Sample 343 Predicted Label: __label__PowerFail
# Test Sample 344 Predicted Label: __label__PowerFail
# Test Sample 345 Predicted Label: __label__PowerFail
# Test Sample 346 Predicted Label: __label__LinkCut
# Test Sample 347 Predicted Label: __label__PowerFail
# Test Sample 348 Predicted Label: __label__PowerFail
# Test Sample 349 Predicted Label: __label__LinkCut
# Test Sample 350 Predicted Label: __label__LinkCut
# Test Sample 351 Predicted Label: __label__PowerFail
# Test Sample 352 Predicted Label: __label__PowerFail
# Test Sample 353 Predicted Label: __label__LinkCut
# Test Sample 354 Predicted Label: __label__PowerFail
# Test Sample 355 Predicted Label: __label__LinkCut
# Test Sample 356 Predicted Label: __label__PowerFail
# Test Sample 357 Predicted Label: __label__PowerFail
# Test Sample 358 Predicted Label: __label__LinkCut
# Test Sample 359 Predicted Label: __label__LinkCut
# Test Sample 360 Predicted Label: __label__PowerFail
# Test Sample 361 Predicted Label: __label__LinkCut
# Test Sample 362 Predicted Label: __label__PowerFail
# Test Sample 363 Predicted Label: __label__LinkCut
# Test Sample 364 Predicted Label: __label__LinkCut
# Test Sample 365 Predicted Label: __label__PowerFail
# Test Sample 366 Predicted Label: __label__LinkCut
# Test Sample 367 Predicted Label: __label__LinkCut
# Test Sample 368 Predicted Label: __label__LinkCut
# Test Sample 369 Predicted Label: __label__LinkCut
# Test Sample 370 Predicted Label: __label__LinkCut
# Test Sample 371 Predicted Label: __label__LinkCut
# Test Sample 372 Predicted Label: __label__LinkCut
# Test Sample 373 Predicted Label: __label__PowerFail
# Test Sample 374 Predicted Label: __label__PowerFail
# Test Sample 375 Predicted Label: __label__PowerFail
# Test Sample 376 Predicted Label: __label__PowerFail
# Test Sample 377 Predicted Label: __label__LinkCut
# Test Sample 378 Predicted Label: __label__LinkCut
# Test Sample 379 Predicted Label: __label__PowerFail
# Test Sample 380 Predicted Label: __label__PowerFail
# Test Sample 381 Predicted Label: __label__PowerFail
# Test Sample 382 Predicted Label: __label__PowerFail
# Test Sample 383 Predicted Label: __label__PowerFail
# Test Sample 384 Predicted Label: __label__LinkCut
# Test Sample 385 Predicted Label: __label__LinkCut
# Test Sample 386 Predicted Label: __label__LinkCut
# Test Sample 387 Predicted Label: __label__PowerFail
# Test Sample 388 Predicted Label: __label__PowerFail
# Test Sample 389 Predicted Label: __label__LinkCut
# Test Sample 390 Predicted Label: __label__LinkCut
# Test Sample 391 Predicted Label: __label__LinkCut
# Test Sample 392 Predicted Label: __label__PowerFail
# Test Sample 393 Predicted Label: __label__LinkCut
# Test Sample 394 Predicted Label: __label__PowerFail
# Test Sample 395 Predicted Label: __label__PowerFail
# Test Sample 396 Predicted Label: __label__PowerFail
# Test Sample 397 Predicted Label: __label__PowerFail
# Test Sample 398 Predicted Label: __label__PowerFail
# Test Sample 399 Predicted Label: __label__PowerFail
# Test Sample 400 Predicted Label: __label__PowerFail
# Test Sample 401 Predicted Label: __label__LinkCut
# Test Sample 402 Predicted Label: __label__LinkCut
# Test Sample 403 Predicted Label: __label__LinkCut
# Test Sample 404 Predicted Label: __label__LinkCut
# Test Sample 405 Predicted Label: __label__PowerFail
# Test Sample 406 Predicted Label: __label__LinkCut
# Test Sample 407 Predicted Label: __label__LinkCut
# Test Sample 408 Predicted Label: __label__LinkCut
# Test Sample 409 Predicted Label: __label__LinkCut
# Test Sample 410 Predicted Label: __label__LinkCut
# Test Sample 411 Predicted Label: __label__PowerFail
# Test Sample 412 Predicted Label: __label__LinkCut
# Test Sample 413 Predicted Label: __label__PowerFail
# Test Sample 414 Predicted Label: __label__PowerFail
# Test Sample 415 Predicted Label: __label__PowerFail
# Test Sample 416 Predicted Label: __label__PowerFail
# Test Sample 417 Predicted Label: __label__PowerFail
# Test Sample 418 Predicted Label: __label__LinkCut
# Test Sample 419 Predicted Label: __label__PowerFail
# Test Sample 420 Predicted Label: __label__PowerFail
# Test Sample 421 Predicted Label: __label__LinkCut
# Test Sample 422 Predicted Label: __label__LinkCut
# Test Sample 423 Predicted Label: __label__PowerFail
# Test Sample 424 Predicted Label: __label__PowerFail
# Test Sample 425 Predicted Label: __label__PowerFail
# Test Sample 426 Predicted Label: __label__PowerFail
# Test Sample 427 Predicted Label: __label__PowerFail
# Test Sample 428 Predicted Label: __label__PowerFail
# Test Sample 429 Predicted Label: __label__LinkCut
# Test Sample 430 Predicted Label: __label__LinkCut
# Test Sample 431 Predicted Label: __label__PowerFail
# Test Sample 432 Predicted Label: __label__LinkCut
# Test Sample 433 Predicted Label: __label__LinkCut
# Test Sample 434 Predicted Label: __label__PowerFail
# Test Sample 435 Predicted Label: __label__LinkCut
# Test Sample 436 Predicted Label: __label__PowerFail
# Test Sample 437 Predicted Label: __label__PowerFail
# Test Sample 438 Predicted Label: __label__LinkCut
# Test Sample 439 Predicted Label: __label__LinkCut
# Test Sample 440 Predicted Label: __label__PowerFail
# Test Sample 441 Predicted Label: __label__PowerFail
# Test Sample 442 Predicted Label: __label__PowerFail
# Test Sample 443 Predicted Label: __label__LinkCut
# Test Sample 444 Predicted Label: __label__LinkCut
# Test Sample 445 Predicted Label: __label__LinkCut
# Test Sample 446 Predicted Label: __label__PowerFail
# Test Sample 447 Predicted Label: __label__PowerFail
# Test Sample 448 Predicted Label: __label__PowerFail
# Test Sample 449 Predicted Label: __label__PowerFail
# Test Sample 450 Predicted Label: __label__LinkCut
# Test Sample 451 Predicted Label: __label__PowerFail
# Test Sample 452 Predicted Label: __label__PowerFail
# Test Sample 453 Predicted Label: __label__LinkCut
# Test Sample 454 Predicted Label: __label__PowerFail
# Test Sample 455 Predicted Label: __label__PowerFail
# Test Sample 456 Predicted Label: __label__PowerFail
# Test Sample 457 Predicted Label: __label__LinkCut
# Test Sample 458 Predicted Label: __label__LinkCut
# Test Sample 459 Predicted Label: __label__LinkCut
# Test Sample 460 Predicted Label: __label__PowerFail
# Test Sample 461 Predicted Label: __label__LinkCut
# Test Sample 462 Predicted Label: __label__PowerFail
# Test Sample 463 Predicted Label: __label__LinkCut
# Test Sample 464 Predicted Label: __label__PowerFail
# Test Sample 465 Predicted Label: __label__PowerFail
# Test Sample 466 Predicted Label: __label__PowerFail
# Test Sample 467 Predicted Label: __label__PowerFail
# Test Sample 468 Predicted Label: __label__PowerFail
# Test Sample 469 Predicted Label: __label__PowerFail
# Test Sample 470 Predicted Label: __label__PowerFail
# Test Sample 471 Predicted Label: __label__PowerFail
# Test Sample 472 Predicted Label: __label__PowerFail
# Test Sample 473 Predicted Label: __label__PowerFail
# Test Sample 474 Predicted Label: __label__PowerFail
# Test Sample 475 Predicted Label: __label__PowerFail
# Test Sample 476 Predicted Label: __label__PowerFail
# Test Sample 477 Predicted Label: __label__PowerFail
# Test Sample 478 Predicted Label: __label__PowerFail
# Test Sample 479 Predicted Label: __label__PowerFail
# Test Sample 480 Predicted Label: __label__PowerFail
# Test Sample 481 Predicted Label: __label__PowerFail
# Test Sample 482 Predicted Label: __label__PowerFail
# Test Sample 483 Predicted Label: __label__LinkCut
# Test Sample 484 Predicted Label: __label__PowerFail
# Test Sample 485 Predicted Label: __label__PowerFail
# Test Sample 486 Predicted Label: __label__PowerFail
# Test Sample 487 Predicted Label: __label__PowerFail
# Test Sample 488 Predicted Label: __label__PowerFail
# Test Sample 489 Predicted Label: __label__PowerFail
# Test Sample 490 Predicted Label: __label__PowerFail
# Test Sample 491 Predicted Label: __label__LinkCut
# Test Sample 492 Predicted Label: __label__PowerFail
# Test Sample 493 Predicted Label: __label__LinkCut
# Test Sample 494 Predicted Label: __label__PowerFail
# Test Sample 495 Predicted Label: __label__PowerFail
# Test Sample 496 Predicted Label: __label__LinkCut
# Test Sample 497 Predicted Label: __label__PowerFail
# Test Sample 498 Predicted Label: __label__LinkCut
# Test Sample 499 Predicted Label: __label__PowerFail
# Test Sample 500 Predicted Label: __label__LinkCut
# Test Sample 501 Predicted Label: __label__PowerFail
# Test Sample 502 Predicted Label: __label__LinkCut
# Test Sample 503 Predicted Label: __label__LinkCut
# Test Sample 504 Predicted Label: __label__LinkCut
# Test Sample 505 Predicted Label: __label__PowerFail
# Test Sample 506 Predicted Label: __label__LinkCut
# Test Sample 507 Predicted Label: __label__PowerFail
# Test Sample 508 Predicted Label: __label__PowerFail
# Test Sample 509 Predicted Label: __label__LinkCut
# Test Sample 510 Predicted Label: __label__PowerFail
# Test Sample 511 Predicted Label: __label__LinkCut
# Test Sample 512 Predicted Label: __label__PowerFail
# Test Sample 513 Predicted Label: __label__PowerFail
# Test Sample 514 Predicted Label: __label__LinkCut
# Test Sample 515 Predicted Label: __label__LinkCut
# Test Sample 516 Predicted Label: __label__LinkCut
# Test Sample 517 Predicted Label: __label__PowerFail
# Test Sample 518 Predicted Label: __label__LinkCut
# Test Sample 519 Predicted Label: __label__LinkCut
# Test Sample 520 Predicted Label: __label__PowerFail
# Test Sample 521 Predicted Label: __label__PowerFail
# Test Sample 522 Predicted Label: __label__LinkCut
# Test Sample 523 Predicted Label: __label__PowerFail
# Test Sample 524 Predicted Label: __label__PowerFail
# Test Sample 525 Predicted Label: __label__PowerFail
# Test Sample 526 Predicted Label: __label__LinkCut
# Test Sample 527 Predicted Label: __label__PowerFail
# Test Sample 528 Predicted Label: __label__PowerFail
# Test Sample 529 Predicted Label: __label__LinkCut
# Test Sample 530 Predicted Label: __label__PowerFail
# Test Sample 531 Predicted Label: __label__LinkCut
# Test Sample 532 Predicted Label: __label__PowerFail
# Test Sample 533 Predicted Label: __label__PowerFail
# Test Sample 534 Predicted Label: __label__PowerFail
# Test Sample 535 Predicted Label: __label__PowerFail
# Test Sample 536 Predicted Label: __label__PowerFail
# Test Sample 537 Predicted Label: __label__PowerFail
# Test Sample 538 Predicted Label: __label__PowerFail
# Test Sample 539 Predicted Label: __label__PowerFail
# Test Sample 540 Predicted Label: __label__LinkCut
# Test Sample 541 Predicted Label: __label__LinkCut
# Test Sample 542 Predicted Label: __label__PowerFail
# Test Sample 543 Predicted Label: __label__LinkCut
# Test Sample 544 Predicted Label: __label__LinkCut
# Test Sample 545 Predicted Label: __label__PowerFail
# Test Sample 546 Predicted Label: __label__LinkCut
# Test Sample 547 Predicted Label: __label__PowerFail
# Test Sample 548 Predicted Label: __label__PowerFail
# Test Sample 549 Predicted Label: __label__PowerFail
# Test Sample 550 Predicted Label: __label__LinkCut
# Test Sample 551 Predicted Label: __label__PowerFail
# Test Sample 552 Predicted Label: __label__PowerFail
# Test Sample 553 Predicted Label: __label__PowerFail
# Test Sample 554 Predicted Label: __label__PowerFail
# Test Sample 555 Predicted Label: __label__PowerFail
# Test Sample 556 Predicted Label: __label__PowerFail
# Test Sample 557 Predicted Label: __label__PowerFail
# Test Sample 558 Predicted Label: __label__PowerFail
# Test Sample 559 Predicted Label: __label__LinkCut
# Test Sample 560 Predicted Label: __label__LinkCut
# Test Sample 561 Predicted Label: __label__PowerFail
# Test Sample 562 Predicted Label: __label__PowerFail
# Test Sample 563 Predicted Label: __label__PowerFail
# Test Sample 564 Predicted Label: __label__LinkCut
# Test Sample 565 Predicted Label: __label__PowerFail
# Test Sample 566 Predicted Label: __label__LinkCut
# Test Sample 567 Predicted Label: __label__PowerFail
# Test Sample 568 Predicted Label: __label__PowerFail
# Test Sample 569 Predicted Label: __label__PowerFail
# Test Sample 570 Predicted Label: __label__LinkCut
# Test Sample 571 Predicted Label: __label__PowerFail
# Test Sample 572 Predicted Label: __label__PowerFail
# Test Sample 573 Predicted Label: __label__PowerFail
# Test Sample 574 Predicted Label: __label__LinkCut
# Test Sample 575 Predicted Label: __label__PowerFail
# Test Sample 576 Predicted Label: __label__PowerFail
# Test Sample 577 Predicted Label: __label__LinkCut
# Test Sample 578 Predicted Label: __label__PowerFail
# Test Sample 579 Predicted Label: __label__PowerFail
# Test Sample 580 Predicted Label: __label__LinkCut
# Test Sample 581 Predicted Label: __label__PowerFail
# Test Sample 582 Predicted Label: __label__LinkCut
# Test Sample 583 Predicted Label: __label__LinkCut
# Test Sample 584 Predicted Label: __label__LinkCut
# Test Sample 585 Predicted Label: __label__LinkCut
# Test Sample 586 Predicted Label: __label__LinkCut
# Test Sample 587 Predicted Label: __label__LinkCut
# Test Sample 588 Predicted Label: __label__PowerFail
# Test Sample 589 Predicted Label: __label__LinkCut
# Test Sample 590 Predicted Label: __label__LinkCut
# Test Sample 591 Predicted Label: __label__LinkCut
# Test Sample 592 Predicted Label: __label__LinkCut
# Test Sample 593 Predicted Label: __label__LinkCut
# Test Sample 594 Predicted Label: __label__LinkCut
# Test Sample 595 Predicted Label: __label__LinkCut
# Test Sample 596 Predicted Label: __label__LinkCut
# Test Sample 597 Predicted Label: __label__LinkCut
# Test Sample 598 Predicted Label: __label__PowerFail
# Test Sample 599 Predicted Label: __label__LinkCut
# Test Sample 600 Predicted Label: __label__LinkCut
# Test Sample 601 Predicted Label: __label__LinkCut
# Test Sample 602 Predicted Label: __label__LinkCut
# Test Sample 603 Predicted Label: __label__PowerFail
# Test Sample 604 Predicted Label: __label__LinkCut
# Test Sample 605 Predicted Label: __label__LinkCut
# Test Sample 606 Predicted Label: __label__LinkCut
# Test Sample 607 Predicted Label: __label__LinkCut
# Test Sample 608 Predicted Label: __label__LinkCut
# Test Sample 609 Predicted Label: __label__LinkCut
# Test Sample 610 Predicted Label: __label__LinkCut
# Test Sample 611 Predicted Label: __label__LinkCut
# Test Sample 612 Predicted Label: __label__LinkCut
# Test Sample 613 Predicted Label: __label__LinkCut
# Test Sample 614 Predicted Label: __label__LinkCut
# Test Sample 615 Predicted Label: __label__LinkCut
# Test Sample 616 Predicted Label: __label__PowerFail
# Test Sample 617 Predicted Label: __label__LinkCut
# Test Sample 618 Predicted Label: __label__LinkCut
# Test Sample 619 Predicted Label: __label__LinkCut
# Test Sample 620 Predicted Label: __label__PowerFail
# Test Sample 621 Predicted Label: __label__LinkCut
# Test Sample 622 Predicted Label: __label__LinkCut
# Test Sample 623 Predicted Label: __label__LinkCut
# Test Sample 624 Predicted Label: __label__LinkCut
# Test Sample 625 Predicted Label: __label__LinkCut
# Test Sample 626 Predicted Label: __label__LinkCut
# Test Sample 627 Predicted Label: __label__LinkCut
# Test Sample 628 Predicted Label: __label__LinkCut
# Test Sample 629 Predicted Label: __label__LinkCut
# Test Sample 630 Predicted Label: __label__LinkCut
# Test Sample 631 Predicted Label: __label__LinkCut
# Test Sample 632 Predicted Label: __label__PowerFail
# Test Sample 633 Predicted Label: __label__LinkCut
# Test Sample 634 Predicted Label: __label__LinkCut
# Test Sample 635 Predicted Label: __label__LinkCut
# Test Sample 636 Predicted Label: __label__LinkCut
# Test Sample 637 Predicted Label: __label__PowerFail
# Test Sample 638 Predicted Label: __label__LinkCut
# Test Sample 639 Predicted Label: __label__LinkCut
# Test Sample 640 Predicted Label: __label__PowerFail
# Test Sample 641 Predicted Label: __label__LinkCut
# Test Sample 642 Predicted Label: __label__PowerFail
# Test Sample 643 Predicted Label: __label__LinkCut
# Test Sample 644 Predicted Label: __label__LinkCut
# Test Sample 645 Predicted Label: __label__PowerFail
# Test Sample 646 Predicted Label: __label__PowerFail
# Test Sample 647 Predicted Label: __label__PowerFail
# Test Sample 648 Predicted Label: __label__LinkCut
# Test Sample 649 Predicted Label: __label__LinkCut
# Test Sample 650 Predicted Label: __label__PowerFail
# Test Sample 651 Predicted Label: __label__LinkCut
# Test Sample 652 Predicted Label: __label__LinkCut
# Test Sample 653 Predicted Label: __label__LinkCut
# Test Sample 654 Predicted Label: __label__LinkCut
# Test Sample 655 Predicted Label: __label__LinkCut
# Test Sample 656 Predicted Label: __label__LinkCut
# Test Sample 657 Predicted Label: __label__PowerFail
# Test Sample 658 Predicted Label: __label__PowerFail
# Test Sample 659 Predicted Label: __label__PowerFail
# Test Sample 660 Predicted Label: __label__LinkCut
# Test Sample 661 Predicted Label: __label__PowerFail
# Test Sample 662 Predicted Label: __label__LinkCut
# Test Sample 663 Predicted Label: __label__LinkCut
# Test Sample 664 Predicted Label: __label__PowerFail
# Test Sample 665 Predicted Label: __label__LinkCut
# Test Sample 666 Predicted Label: __label__PowerFail
# Test Sample 667 Predicted Label: __label__LinkCut
# Test Sample 668 Predicted Label: __label__PowerFail
# Test Sample 669 Predicted Label: __label__LinkCut
# Test Sample 670 Predicted Label: __label__LinkCut
# Test Sample 671 Predicted Label: __label__PowerFail
# Test Sample 672 Predicted Label: __label__PowerFail
# Test Sample 673 Predicted Label: __label__PowerFail
# Test Sample 674 Predicted Label: __label__LinkCut
# Test Sample 675 Predicted Label: __label__LinkCut
# Test Sample 676 Predicted Label: __label__PowerFail
# Test Sample 677 Predicted Label: __label__PowerFail
# Test Sample 678 Predicted Label: __label__PowerFail
# Test Sample 679 Predicted Label: __label__PowerFail
# Test Sample 680 Predicted Label: __label__PowerFail
# Test Sample 681 Predicted Label: __label__PowerFail
# Test Sample 682 Predicted Label: __label__LinkCut
# Test Sample 683 Predicted Label: __label__LinkCut
# Test Sample 684 Predicted Label: __label__LinkCut
# Test Sample 685 Predicted Label: __label__LinkCut
# Test Sample 686 Predicted Label: __label__PowerFail
# Test Sample 687 Predicted Label: __label__LinkCut
# Test Sample 688 Predicted Label: __label__LinkCut
# Test Sample 689 Predicted Label: __label__LinkCut
# Test Sample 690 Predicted Label: __label__LinkCut
# Test Sample 691 Predicted Label: __label__LinkCut
# Test Sample 692 Predicted Label: __label__PowerFail
# Test Sample 693 Predicted Label: __label__PowerFail
# Test Sample 694 Predicted Label: __label__PowerFail
# Test Sample 695 Predicted Label: __label__PowerFail
# Test Sample 696 Predicted Label: __label__LinkCut
# Test Sample 697 Predicted Label: __label__LinkCut
# Test Sample 698 Predicted Label: __label__PowerFail
# Test Sample 699 Predicted Label: __label__LinkCut
# Test Sample 700 Predicted Label: __label__PowerFail
# Test Sample 701 Predicted Label: __label__PowerFail
# Test Sample 702 Predicted Label: __label__LinkCut
# Test Sample 703 Predicted Label: __label__PowerFail
# Test Sample 704 Predicted Label: __label__PowerFail
# Test Sample 705 Predicted Label: __label__LinkCut
# Test Sample 706 Predicted Label: __label__PowerFail
# Test Sample 707 Predicted Label: __label__PowerFail
# Test Sample 708 Predicted Label: __label__PowerFail
# Test Sample 709 Predicted Label: __label__LinkCut
# Test Sample 710 Predicted Label: __label__LinkCut
# Test Sample 711 Predicted Label: __label__LinkCut
# Test Sample 712 Predicted Label: __label__PowerFail
# Test Sample 713 Predicted Label: __label__PowerFail
# Test Sample 714 Predicted Label: __label__PowerFail
# Test Sample 715 Predicted Label: __label__PowerFail
# Test Sample 716 Predicted Label: __label__LinkCut
# Test Sample 717 Predicted Label: __label__PowerFail
# Test Sample 718 Predicted Label: __label__LinkCut
# Test Sample 719 Predicted Label: __label__PowerFail
# Test Sample 720 Predicted Label: __label__LinkCut
# Test Sample 721 Predicted Label: __label__LinkCut
# Test Sample 722 Predicted Label: __label__PowerFail
# Test Sample 723 Predicted Label: __label__LinkCut
# Test Sample 724 Predicted Label: __label__PowerFail
# Test Sample 725 Predicted Label: __label__LinkCut
# Test Sample 726 Predicted Label: __label__LinkCut
# Test Sample 727 Predicted Label: __label__LinkCut
# Test Sample 728 Predicted Label: __label__PowerFail
# Test Sample 729 Predicted Label: __label__LinkCut
# Test Sample 730 Predicted Label: __label__LinkCut
# Test Sample 731 Predicted Label: __label__PowerFail
# Test Sample 732 Predicted Label: __label__LinkCut
# Test Sample 733 Predicted Label: __label__PowerFail
# Test Sample 734 Predicted Label: __label__LinkCut
# Test Sample 735 Predicted Label: __label__PowerFail
# Test Sample 736 Predicted Label: __label__LinkCut
# Test Sample 737 Predicted Label: __label__LinkCut
# Test Sample 738 Predicted Label: __label__LinkCut
# Test Sample 739 Predicted Label: __label__LinkCut
# Test Sample 740 Predicted Label: __label__LinkCut
# Test Sample 741 Predicted Label: __label__LinkCut
# Test Sample 742 Predicted Label: __label__LinkCut
# Test Sample 743 Predicted Label: __label__LinkCut
# Test Sample 744 Predicted Label: __label__LinkCut
# Test Sample 745 Predicted Label: __label__PowerFail
# Test Sample 746 Predicted Label: __label__LinkCut
# Test Sample 747 Predicted Label: __label__LinkCut
# Test Sample 748 Predicted Label: __label__LinkCut
# Test Sample 749 Predicted Label: __label__LinkCut
# Test Sample 750 Predicted Label: __label__LinkCut
# Test Sample 751 Predicted Label: __label__LinkCut
# Test Sample 752 Predicted Label: __label__LinkCut
# Test Sample 753 Predicted Label: __label__LinkCut
# Test Sample 754 Predicted Label: __label__LinkCut
# Test Sample 755 Predicted Label: __label__LinkCut
# Test Sample 756 Predicted Label: __label__LinkCut
# Test Sample 757 Predicted Label: __label__LinkCut
# Test Sample 758 Predicted Label: __label__LinkCut
# Test Sample 759 Predicted Label: __label__LinkCut
# Test Sample 760 Predicted Label: __label__PowerFail
# Test Sample 761 Predicted Label: __label__LinkCut
# Test Sample 762 Predicted Label: __label__LinkCut
# Test Sample 763 Predicted Label: __label__LinkCut
# Test Sample 764 Predicted Label: __label__LinkCut
# Test Sample 765 Predicted Label: __label__PowerFail
# Test Sample 766 Predicted Label: __label__LinkCut
# Test Sample 767 Predicted Label: __label__PowerFail
# Test Sample 768 Predicted Label: __label__LinkCut
# Test Sample 769 Predicted Label: __label__LinkCut
# Test Sample 770 Predicted Label: __label__LinkCut
# Test Sample 771 Predicted Label: __label__LinkCut
# Test Sample 772 Predicted Label: __label__LinkCut
# Test Sample 773 Predicted Label: __label__LinkCut
# Test Sample 774 Predicted Label: __label__LinkCut
# Test Sample 775 Predicted Label: __label__PowerFail
# Test Sample 776 Predicted Label: __label__LinkCut
# Test Sample 777 Predicted Label: __label__LinkCut
# Test Sample 778 Predicted Label: __label__LinkCut
# Test Sample 779 Predicted Label: __label__LinkCut
# Test Sample 780 Predicted Label: __label__LinkCut
# Test Sample 781 Predicted Label: __label__LinkCut
# Test Sample 782 Predicted Label: __label__LinkCut
# Test Sample 783 Predicted Label: __label__LinkCut
# Test Sample 784 Predicted Label: __label__PowerFail
# Test Sample 785 Predicted Label: __label__PowerFail
# Test Sample 786 Predicted Label: __label__LinkCut
# Test Sample 787 Predicted Label: __label__LinkCut
# Test Sample 788 Predicted Label: __label__LinkCut
# Test Sample 789 Predicted Label: __label__LinkCut
# Test Sample 790 Predicted Label: __label__LinkCut
# Test Sample 791 Predicted Label: __label__LinkCut
# Test Sample 792 Predicted Label: __label__LinkCut
# Test Sample 793 Predicted Label: __label__PowerFail
# Test Sample 794 Predicted Label: __label__LinkCut
# Test Sample 795 Predicted Label: __label__LinkCut
# Test Sample 796 Predicted Label: __label__LinkCut
# Test Sample 797 Predicted Label: __label__LinkCut
# Test Sample 798 Predicted Label: __label__PowerFail
# Test Sample 799 Predicted Label: __label__PowerFail
# Test Sample 800 Predicted Label: __label__LinkCut
# Test Sample 801 Predicted Label: __label__LinkCut
# Test Sample 802 Predicted Label: __label__LinkCut
# Test Sample 803 Predicted Label: __label__LinkCut
# Test Sample 804 Predicted Label: __label__LinkCut
# Test Sample 805 Predicted Label: __label__LinkCut
# Test Sample 806 Predicted Label: __label__PowerFail
# Test Sample 807 Predicted Label: __label__LinkCut
# Test Sample 808 Predicted Label: __label__PowerFail
# Test Sample 809 Predicted Label: __label__LinkCut
# Test Sample 810 Predicted Label: __label__PowerFail
# Test Sample 811 Predicted Label: __label__PowerFail
# Test Sample 812 Predicted Label: __label__LinkCut
# Test Sample 813 Predicted Label: __label__LinkCut
# Test Sample 814 Predicted Label: __label__LinkCut
# Test Sample 815 Predicted Label: __label__LinkCut
# Test Sample 816 Predicted Label: __label__LinkCut
# Test Sample 817 Predicted Label: __label__LinkCut
# Test Sample 818 Predicted Label: __label__LinkCut
# Test Sample 819 Predicted Label: __label__PowerFail
# Test Sample 820 Predicted Label: __label__LinkCut
# Test Sample 821 Predicted Label: __label__LinkCut
# Test Sample 822 Predicted Label: __label__PowerFail
# Test Sample 823 Predicted Label: __label__PowerFail
# Test Sample 824 Predicted Label: __label__LinkCut
# Test Sample 825 Predicted Label: __label__PowerFail
# Test Sample 826 Predicted Label: __label__LinkCut
# Test Sample 827 Predicted Label: __label__PowerFail
# Test Sample 828 Predicted Label: __label__LinkCut
# Test Sample 829 Predicted Label: __label__LinkCut
# Test Sample 830 Predicted Label: __label__LinkCut
# Test Sample 831 Predicted Label: __label__LinkCut
# Test Sample 832 Predicted Label: __label__LinkCut
# Test Sample 833 Predicted Label: __label__PowerFail
# Test Sample 834 Predicted Label: __label__LinkCut
# Test Sample 835 Predicted Label: __label__LinkCut
# Test Sample 836 Predicted Label: __label__LinkCut
# Test Sample 837 Predicted Label: __label__LinkCut
# Test Sample 838 Predicted Label: __label__PowerFail
# Test Sample 839 Predicted Label: __label__LinkCut
# Test Sample 840 Predicted Label: __label__LinkCut
# Test Sample 841 Predicted Label: __label__LinkCut
# Test Sample 842 Predicted Label: __label__LinkCut
# Test Sample 843 Predicted Label: __label__LinkCut
# Test Sample 844 Predicted Label: __label__LinkCut
# Test Sample 845 Predicted Label: __label__LinkCut
# Test Sample 846 Predicted Label: __label__LinkCut
# Test Sample 847 Predicted Label: __label__LinkCut
# Test Sample 848 Predicted Label: __label__LinkCut
# Test Sample 849 Predicted Label: __label__LinkCut
# Test Sample 850 Predicted Label: __label__LinkCut
# Test Sample 851 Predicted Label: __label__LinkCut
# Test Sample 852 Predicted Label: __label__LinkCut
# Test Sample 853 Predicted Label: __label__LinkCut
# Test Sample 854 Predicted Label: __label__LinkCut
# Test Sample 855 Predicted Label: __label__LinkCut
# Test Sample 856 Predicted Label: __label__LinkCut
# Test Sample 857 Predicted Label: __label__LinkCut
# Test Sample 858 Predicted Label: __label__LinkCut
# Test Sample 859 Predicted Label: __label__LinkCut
# Test Sample 860 Predicted Label: __label__LinkCut
# Test Sample 861 Predicted Label: __label__LinkCut
# Test Sample 862 Predicted Label: __label__LinkCut
# Test Sample 863 Predicted Label: __label__LinkCut
# Test Sample 864 Predicted Label: __label__LinkCut
# Test Sample 865 Predicted Label: __label__PowerFail
# Test Sample 866 Predicted Label: __label__LinkCut
# Test Sample 867 Predicted Label: __label__LinkCut
# Test Sample 868 Predicted Label: __label__LinkCut
# Test Sample 869 Predicted Label: __label__LinkCut
# Test Sample 870 Predicted Label: __label__LinkCut
# Test Sample 871 Predicted Label: __label__LinkCut
# Test Sample 872 Predicted Label: __label__LinkCut
# Test Sample 873 Predicted Label: __label__LinkCut
# Test Sample 874 Predicted Label: __label__UnitFail
# Test Sample 875 Predicted Label: __label__UnitFail
# Test Sample 876 Predicted Label: __label__LinkCut
# Test Sample 877 Predicted Label: __label__LinkCut
# Test Sample 878 Predicted Label: __label__PowerFail
# Test Sample 879 Predicted Label: __label__LinkCut
# Test Sample 880 Predicted Label: __label__LinkCut
# Test Sample 881 Predicted Label: __label__LinkCut
# Test Sample 882 Predicted Label: __label__LinkCut
# Test Sample 883 Predicted Label: __label__LinkCut
# Test Sample 884 Predicted Label: __label__LinkCut
# Test Sample 885 Predicted Label: __label__LinkCut
# Test Sample 886 Predicted Label: __label__PowerFail
# Test Sample 887 Predicted Label: __label__LinkCut
# Test Sample 888 Predicted Label: __label__LinkCut
# Test Sample 889 Predicted Label: __label__LinkCut
# Test Sample 890 Predicted Label: __label__PowerFail
# Test Sample 891 Predicted Label: __label__LinkCut
# Test Sample 892 Predicted Label: __label__LinkCut
# Test Sample 893 Predicted Label: __label__LinkCut
# Test Sample 894 Predicted Label: __label__LinkCut
# Test Sample 895 Predicted Label: __label__LinkCut
# Test Sample 896 Predicted Label: __label__LinkCut
# Test Sample 897 Predicted Label: __label__LinkCut
# Test Sample 898 Predicted Label: __label__LinkCut
# Test Sample 899 Predicted Label: __label__LinkCut
# Test Sample 900 Predicted Label: __label__LinkCut
# Test Sample 901 Predicted Label: __label__LinkCut
# Test Sample 902 Predicted Label: __label__LinkCut
# Test Sample 903 Predicted Label: __label__LinkCut
# Test Sample 904 Predicted Label: __label__LinkCut
# Test Sample 905 Predicted Label: __label__PowerFail
# Test Sample 906 Predicted Label: __label__PowerFail
# Test Sample 907 Predicted Label: __label__LinkCut
# Test Sample 908 Predicted Label: __label__LinkCut
# Test Sample 909 Predicted Label: __label__LinkCut
# Test Sample 910 Predicted Label: __label__LinkCut
# Test Sample 911 Predicted Label: __label__LinkCut
# Test Sample 912 Predicted Label: __label__LinkCut
# Test Sample 913 Predicted Label: __label__LinkCut
# Test Sample 914 Predicted Label: __label__LinkCut
# Test Sample 915 Predicted Label: __label__LinkCut
# Test Sample 916 Predicted Label: __label__LinkCut
# Test Sample 917 Predicted Label: __label__LinkCut
# Test Sample 918 Predicted Label: __label__LinkCut
# Test Sample 919 Predicted Label: __label__LinkCut
# Test Sample 920 Predicted Label: __label__LinkCut
# Test Sample 921 Predicted Label: __label__LinkCut
# Test Sample 922 Predicted Label: __label__LinkCut
# Test Sample 923 Predicted Label: __label__LinkCut
# Test Sample 924 Predicted Label: __label__PowerFail
# Test Sample 925 Predicted Label: __label__LinkCut
# Test Sample 926 Predicted Label: __label__LinkCut
# Test Sample 927 Predicted Label: __label__LinkCut
# Test Sample 928 Predicted Label: __label__PowerFail
# Test Sample 929 Predicted Label: __label__LinkCut
# Test Sample 930 Predicted Label: __label__LinkCut
# Test Sample 931 Predicted Label: __label__LinkCut
# Test Sample 932 Predicted Label: __label__LinkCut
# Test Sample 933 Predicted Label: __label__PowerFail
# Test Sample 934 Predicted Label: __label__LinkCut
# Test Sample 935 Predicted Label: __label__LinkCut
# Test Sample 936 Predicted Label: __label__LinkCut
# Test Sample 937 Predicted Label: __label__LinkCut
# Test Sample 938 Predicted Label: __label__LinkCut
# Test Sample 939 Predicted Label: __label__LinkCut
# Test Sample 940 Predicted Label: __label__LinkCut
# Test Sample 941 Predicted Label: __label__LinkCut
# Test Sample 942 Predicted Label: __label__LinkCut
# Test Sample 943 Predicted Label: __label__LinkCut
# Test Sample 944 Predicted Label: __label__LinkCut
# ...
# Test Sample 4016 Predicted Label: __label__LinkCut
# Test Sample 4017 Predicted Label: __label__LinkCut
# Test Sample 4018 Predicted Label: __label__LinkCut
# Test Sample 4019 Predicted Label: __label__LinkCut
# Test Sample 4020 Predicted Label: __label__LinkCut
# Test Sample 4021 Predicted Label: __label__LinkCut
# Test Sample 4022 Predicted Label: __label__LinkCut
# Test Sample 4023 Predicted Label: __label__LinkCut
# Test Sample 4024 Predicted Label: __label__LinkCut
# Test Sample 4025 Predicted Label: __label__LinkCut
# Test Sample 4026 Predicted Label: __label__LinkCut
# Test Sample 4027 Predicted Label: __label__LinkCut
# Test Sample 4028 Predicted Label: __label__LinkCut
# Test Sample 4029 Predicted Label: __label__LinkCut
# Test Sample 4030 Predicted Label: __label__LinkCut
# Test Sample 4031 Predicted Label: __label__LinkCut
# Test Sample 4032 Predicted Label: __label__LinkCut
# Test Sample 4033 Predicted Label: __label__LinkCut
# Test Sample 4034 Predicted Label: __label__LinkCut
# Test Sample 4035 Predicted Label: __label__LinkCut
# Test Sample 4036 Predicted Label: __label__LinkCut
# Test Sample 4037 Predicted Label: __label__LinkCut
# Test Sample 4038 Predicted Label: __label__LinkCut
# Test Sample 4039 Predicted Label: __label__LinkCut
# Test Sample 4040 Predicted Label: __label__LinkCut
# Test Sample 4041 Predicted Label: __label__LinkCut
# Test Sample 4042 Predicted Label: __label__LinkCut
# Test Sample 4043 Predicted Label: __label__LinkCut
# Test Sample 4044 Predicted Label: __label__LinkCut
# Test Sample 4045 Predicted Label: __label__LinkCut
# Test Sample 4046 Predicted Label: __label__LinkCut
# Test Sample 4047 Predicted Label: __label__PowerFail
# Test Sample 4048 Predicted Label: __label__LinkCut
# Test Sample 4049 Predicted Label: __label__PowerFail
# Test Sample 4050 Predicted Label: __label__LinkCut
# Test Sample 4051 Predicted Label: __label__LinkCut
# Test Sample 4052 Predicted Label: __label__LinkCut
# Test Sample 4053 Predicted Label: __label__LinkCut
# Test Sample 4054 Predicted Label: __label__LinkCut
# Test Sample 4055 Predicted Label: __label__LinkCut
# Test Sample 4056 Predicted Label: __label__LinkCut
# Test Sample 4057 Predicted Label: __label__LinkCut
# Test Sample 4058 Predicted Label: __label__LinkCut
# Test Sample 4059 Predicted Label: __label__LinkCut
# Test Sample 4060 Predicted Label: __label__LinkCut
# Test Sample 4061 Predicted Label: __label__LinkCut
# Test Sample 4062 Predicted Label: __label__LinkCut
# Test Sample 4063 Predicted Label: __label__LinkCut
# Test Sample 4064 Predicted Label: __label__LinkCut
# Test Sample 4065 Predicted Label: __label__LinkCut
# Test Sample 4066 Predicted Label: __label__LinkCut
# Test Sample 4067 Predicted Label: __label__LinkCut
# Test Sample 4068 Predicted Label: __label__LinkCut
# Test Sample 4069 Predicted Label: __label__LinkCut
# Test Sample 4070 Predicted Label: __label__LinkCut
# Test Sample 4071 Predicted Label: __label__LinkCut
# Test Sample 4072 Predicted Label: __label__LinkCut
# Test Sample 4073 Predicted Label: __label__LinkCut
# Test Sample 4074 Predicted Label: __label__LinkCut
# Test Sample 4075 Predicted Label: __label__LinkCut
# Test Sample 4076 Predicted Label: __label__LinkCut
# Test Sample 4077 Predicted Label: __label__LinkCut
# Test Sample 4078 Predicted Label: __label__LinkCut
# Test Sample 4079 Predicted Label: __label__LinkCut
# Test Sample 4080 Predicted Label: __label__LinkCut
# Test Sample 4081 Predicted Label: __label__LinkCut
# Test Sample 4082 Predicted Label: __label__LinkCut
# Test Sample 4083 Predicted Label: __label__LinkCut
# Test Sample 4084 Predicted Label: __label__LinkCut
# Test Sample 4085 Predicted Label: __label__LinkCut
# Test Sample 4086 Predicted Label: __label__LinkCut
# Test Sample 4087 Predicted Label: __label__LinkCut
# Test Sample 4088 Predicted Label: __label__LinkCut
# Test Sample 4089 Predicted Label: __label__LinkCut
# Test Sample 4090 Predicted Label: __label__LinkCut
# Test Sample 4091 Predicted Label: __label__LinkCut
# Test Sample 4092 Predicted Label: __label__LinkCut
# Test Sample 4093 Predicted Label: __label__LinkCut
# Test Sample 4094 Predicted Label: __label__LinkCut
# Test Sample 4095 Predicted Label: __label__LinkCut
# Test Sample 4096 Predicted Label: __label__LinkCut
# Test Sample 4097 Predicted Label: __label__LinkCut
# Test Sample 4098 Predicted Label: __label__LinkCut
# Test Sample 4099 Predicted Label: __label__LinkCut
# Test Sample 4100 Predicted Label: __label__LinkCut
# Test Sample 4101 Predicted Label: __label__LinkCut
# Test Sample 4102 Predicted Label: __label__LinkCut
# Test Sample 4103 Predicted Label: __label__LinkCut
# Test Sample 4104 Predicted Label: __label__LinkCut
# Test Sample 4105 Predicted Label: __label__LinkCut
# Test Sample 4106 Predicted Label: __label__LinkCut
# Test Sample 4107 Predicted Label: __label__LinkCut
# Test Sample 4108 Predicted Label: __label__LinkCut
# Test Sample 4109 Predicted Label: __label__LinkCut
# Test Sample 4110 Predicted Label: __label__LinkCut
# Test Sample 4111 Predicted Label: __label__LinkCut
# Test Sample 4112 Predicted Label: __label__LinkCut
# Test Sample 4113 Predicted Label: __label__LinkCut
# Test Sample 4114 Predicted Label: __label__LinkCut
# Test Sample 4115 Predicted Label: __label__LinkCut
# Test Sample 4116 Predicted Label: __label__LinkCut
# Test Sample 4117 Predicted Label: __label__LinkCut
# Test Sample 4118 Predicted Label: __label__LinkCut
# Test Sample 4119 Predicted Label: __label__LinkCut
# Test Sample 4120 Predicted Label: __label__LinkCut
# Test Sample 4121 Predicted Label: __label__LinkCut
# Test Sample 4122 Predicted Label: __label__LinkCut
# Test Sample 4123 Predicted Label: __label__LinkCut
# Test Sample 4124 Predicted Label: __label__LinkCut
# Test Sample 4125 Predicted Label: __label__LinkCut
# Test Sample 4126 Predicted Label: __label__LinkCut
# Test Sample 4127 Predicted Label: __label__LinkCut
# Test Sample 4128 Predicted Label: __label__LinkCut
# Test Sample 4129 Predicted Label: __label__LinkCut
# Test Sample 4130 Predicted Label: __label__LinkCut
# Test Sample 4131 Predicted Label: __label__LinkCut
# Test Sample 4132 Predicted Label: __label__PowerFail
# Test Sample 4133 Predicted Label: __label__LinkCut
# Test Sample 4134 Predicted Label: __label__LinkCut
# Test Sample 4135 Predicted Label: __label__LinkCut
# Test Sample 4136 Predicted Label: __label__LinkCut
# Test Sample 4137 Predicted Label: __label__LinkCut
# Test Sample 4138 Predicted Label: __label__LinkCut
# Test Sample 4139 Predicted Label: __label__LinkCut
# Test Sample 4140 Predicted Label: __label__LinkCut
# Test Sample 4141 Predicted Label: __label__LinkCut
# Test Sample 4142 Predicted Label: __label__LinkCut
# Test Sample 4143 Predicted Label: __label__LinkCut
# Test Sample 4144 Predicted Label: __label__LinkCut
# Test Sample 4145 Predicted Label: __label__LinkCut
# Test Sample 4146 Predicted Label: __label__LinkCut
# Test Sample 4147 Predicted Label: __label__LinkCut
# Test Sample 4148 Predicted Label: __label__LinkCut
# Test Sample 4149 Predicted Label: __label__LinkCut
# Test Sample 4150 Predicted Label: __label__LinkCut
# Test Sample 4151 Predicted Label: __label__LinkCut
# Test Sample 4152 Predicted Label: __label__LinkCut
# Test Sample 4153 Predicted Label: __label__LinkCut
# Test Sample 4154 Predicted Label: __label__LinkCut
# Test Sample 4155 Predicted Label: __label__LinkCut
# Test Sample 4156 Predicted Label: __label__LinkCut
# Test Sample 4157 Predicted Label: __label__LinkCut
# Test Sample 4158 Predicted Label: __label__LinkCut
# Test Sample 4159 Predicted Label: __label__LinkCut
# Test Sample 4160 Predicted Label: __label__LinkCut
# Test Sample 4161 Predicted Label: __label__LinkCut
# Test Sample 4162 Predicted Label: __label__LinkCut
# Test Sample 4163 Predicted Label: __label__LinkCut
# Test Sample 4164 Predicted Label: __label__LinkCut
# Test Sample 4165 Predicted Label: __label__PowerFail
# Test Sample 4166 Predicted Label: __label__LinkCut
# Test Sample 4167 Predicted Label: __label__LinkCut
# Test Sample 4168 Predicted Label: __label__LinkCut
# Test Sample 4169 Predicted Label: __label__LinkCut
# Test Sample 4170 Predicted Label: __label__LinkCut
# Test Sample 4171 Predicted Label: __label__LinkCut
# Test Sample 4172 Predicted Label: __label__LinkCut
# Test Sample 4173 Predicted Label: __label__LinkCut
# Test Sample 4174 Predicted Label: __label__LinkCut
# Test Sample 4175 Predicted Label: __label__LinkCut
# Test Sample 4176 Predicted Label: __label__LinkCut
# Test Sample 4177 Predicted Label: __label__LinkCut
# Test Sample 4178 Predicted Label: __label__LinkCut
# Test Sample 4179 Predicted Label: __label__LinkCut
# Test Sample 4180 Predicted Label: __label__LinkCut
# Test Sample 4181 Predicted Label: __label__LinkCut
# Test Sample 4182 Predicted Label: __label__PowerFail
# Test Sample 4183 Predicted Label: __label__LinkCut
# Test Sample 4184 Predicted Label: __label__LinkCut
# Test Sample 4185 Predicted Label: __label__LinkCut
# Test Sample 4186 Predicted Label: __label__LinkCut
# Test Sample 4187 Predicted Label: __label__LinkCut
# Test Sample 4188 Predicted Label: __label__LinkCut
# Test Sample 4189 Predicted Label: __label__LinkCut
# Test Sample 4190 Predicted Label: __label__LinkCut
# Test Sample 4191 Predicted Label: __label__LinkCut
# Test Sample 4192 Predicted Label: __label__LinkCut
# Test Sample 4193 Predicted Label: __label__LinkCut
# Test Sample 4194 Predicted Label: __label__LinkCut
# Test Sample 4195 Predicted Label: __label__PowerFail
# Test Sample 4196 Predicted Label: __label__LinkCut
# Test Sample 4197 Predicted Label: __label__LinkCut
# Test Sample 4198 Predicted Label: __label__LinkCut
# Test Sample 4199 Predicted Label: __label__LinkCut
# Test Sample 4200 Predicted Label: __label__LinkCut
# Test Sample 4201 Predicted Label: __label__LinkCut
# Test Sample 4202 Predicted Label: __label__LinkCut
# Test Sample 4203 Predicted Label: __label__LinkCut
# Test Sample 4204 Predicted Label: __label__LinkCut
# Test Sample 4205 Predicted Label: __label__LinkCut
# Test Sample 4206 Predicted Label: __label__LinkCut
# Test Sample 4207 Predicted Label: __label__LinkCut
# Test Sample 4208 Predicted Label: __label__PowerFail
# Test Sample 4209 Predicted Label: __label__LinkCut
# Test Sample 4210 Predicted Label: __label__LinkCut
# Test Sample 4211 Predicted Label: __label__LinkCut
# Test Sample 4212 Predicted Label: __label__LinkCut
# Test Sample 4213 Predicted Label: __label__LinkCut
# Test Sample 4214 Predicted Label: __label__LinkCut
# Test Sample 4215 Predicted Label: __label__LinkCut
# Test Sample 4216 Predicted Label: __label__LinkCut
# Test Sample 4217 Predicted Label: __label__LinkCut
# Test Sample 4218 Predicted Label: __label__LinkCut
# Test Sample 4219 Predicted Label: __label__LinkCut
# Test Sample 4220 Predicted Label: __label__LinkCut
# Test Sample 4221 Predicted Label: __label__LinkCut
# Test Sample 4222 Predicted Label: __label__LinkCut
# Test Sample 4223 Predicted Label: __label__LinkCut
# Test Sample 4224 Predicted Label: __label__LinkCut
# Test Sample 4225 Predicted Label: __label__LinkCut
# Test Sample 4226 Predicted Label: __label__LinkCut
# Test Sample 4227 Predicted Label: __label__LinkCut
# Test Sample 4228 Predicted Label: __label__LinkCut
# Test Sample 4229 Predicted Label: __label__LinkCut
# Test Sample 4230 Predicted Label: __label__LinkCut
# Test Sample 4231 Predicted Label: __label__LinkCut
# Test Sample 4232 Predicted Label: __label__LinkCut
# Test Sample 4233 Predicted Label: __label__LinkCut
# Test Sample 4234 Predicted Label: __label__LinkCut
# Test Sample 4235 Predicted Label: __label__PowerFail
# Test Sample 4236 Predicted Label: __label__LinkCut
# Test Sample 4237 Predicted Label: __label__LinkCut
# Test Sample 4238 Predicted Label: __label__LinkCut
# Test Sample 4239 Predicted Label: __label__PowerFail
# Test Sample 4240 Predicted Label: __label__LinkCut
# Test Sample 4241 Predicted Label: __label__PowerFail
# Test Sample 4242 Predicted Label: __label__LinkCut
# Test Sample 4243 Predicted Label: __label__LinkCut
# Test Sample 4244 Predicted Label: __label__LinkCut
# Test Sample 4245 Predicted Label: __label__LinkCut
# Test Sample 4246 Predicted Label: __label__LinkCut
# Test Sample 4247 Predicted Label: __label__LinkCut
# Test Sample 4248 Predicted Label: __label__LinkCut
# Test Sample 4249 Predicted Label: __label__PowerFail
# Test Sample 4250 Predicted Label: __label__LinkCut
# Test Sample 4251 Predicted Label: __label__LinkCut
# Test Sample 4252 Predicted Label: __label__LinkCut
# Test Sample 4253 Predicted Label: __label__PowerFail
# Test Sample 4254 Predicted Label: __label__PowerFail
# Test Sample 4255 Predicted Label: __label__LinkCut
# Test Sample 4256 Predicted Label: __label__PowerFail
# Test Sample 4257 Predicted Label: __label__LinkCut
# Test Sample 4258 Predicted Label: __label__LinkCut
# Test Sample 4259 Predicted Label: __label__PowerFail
# Test Sample 4260 Predicted Label: __label__LinkCut
# Test Sample 4261 Predicted Label: __label__LinkCut
# Test Sample 4262 Predicted Label: __label__LinkCut
# Test Sample 4263 Predicted Label: __label__LinkCut
# Test Sample 4264 Predicted Label: __label__LinkCut
# Test Sample 4265 Predicted Label: __label__LinkCut
# Test Sample 4266 Predicted Label: __label__LinkCut
# Test Sample 4267 Predicted Label: __label__PowerFail
# Test Sample 4268 Predicted Label: __label__LinkCut
# Test Sample 4269 Predicted Label: __label__LinkCut
# Test Sample 4270 Predicted Label: __label__PowerFail
# Test Sample 4271 Predicted Label: __label__LinkCut
# Test Sample 4272 Predicted Label: __label__LinkCut
# Test Sample 4273 Predicted Label: __label__LinkCut
# Test Sample 4274 Predicted Label: __label__PowerFail
# Test Sample 4275 Predicted Label: __label__LinkCut
# Test Sample 4276 Predicted Label: __label__LinkCut
# Test Sample 4277 Predicted Label: __label__PowerFail
# Test Sample 4278 Predicted Label: __label__PowerFail
# Test Sample 4279 Predicted Label: __label__LinkCut
# Test Sample 4280 Predicted Label: __label__LinkCut
# Test Sample 4281 Predicted Label: __label__PowerFail
# Test Sample 4282 Predicted Label: __label__LinkCut
# Test Sample 4283 Predicted Label: __label__LinkCut
# Test Sample 4284 Predicted Label: __label__PowerFail
# Test Sample 4285 Predicted Label: __label__LinkCut
# Test Sample 4286 Predicted Label: __label__PowerFail
# Test Sample 4287 Predicted Label: __label__LinkCut
# Test Sample 4288 Predicted Label: __label__LinkCut
# Test Sample 4289 Predicted Label: __label__LinkCut
# Test Sample 4290 Predicted Label: __label__PowerFail
# Test Sample 4291 Predicted Label: __label__LinkCut
# Test Sample 4292 Predicted Label: __label__PowerFail
# Test Sample 4293 Predicted Label: __label__PowerFail
# Test Sample 4294 Predicted Label: __label__LinkCut
# Test Sample 4295 Predicted Label: __label__PowerFail
# Test Sample 4296 Predicted Label: __label__LinkCut
# Test Sample 4297 Predicted Label: __label__PowerFail
# Test Sample 4298 Predicted Label: __label__PowerFail
# Test Sample 4299 Predicted Label: __label__PowerFail
# Test Sample 4300 Predicted Label: __label__PowerFail
# Test Sample 4301 Predicted Label: __label__PowerFail
# Test Sample 4302 Predicted Label: __label__LinkCut
# Test Sample 4303 Predicted Label: __label__PowerFail
# Test Sample 4304 Predicted Label: __label__LinkCut
# Test Sample 4305 Predicted Label: __label__PowerFail
# Test Sample 4306 Predicted Label: __label__LinkCut
# Test Sample 4307 Predicted Label: __label__PowerFail
# Test Sample 4308 Predicted Label: __label__LinkCut
# Test Sample 4309 Predicted Label: __label__PowerFail
# Test Sample 4310 Predicted Label: __label__LinkCut
# Test Sample 4311 Predicted Label: __label__PowerFail
# Test Sample 4312 Predicted Label: __label__PowerFail
# Test Sample 4313 Predicted Label: __label__PowerFail
# Test Sample 4314 Predicted Label: __label__LinkCut
# Test Sample 4315 Predicted Label: __label__LinkCut
# Test Sample 4316 Predicted Label: __label__PowerFail
# Test Sample 4317 Predicted Label: __label__PowerFail
# Test Sample 4318 Predicted Label: __label__PowerFail
# Test Sample 4319 Predicted Label: __label__PowerFail
# Test Sample 4320 Predicted Label: __label__PowerFail
# Test Sample 4321 Predicted Label: __label__LinkCut
# Test Sample 4322 Predicted Label: __label__LinkCut
# Test Sample 4323 Predicted Label: __label__LinkCut
# Test Sample 4324 Predicted Label: __label__LinkCut
# Test Sample 4325 Predicted Label: __label__LinkCut
# Test Sample 4326 Predicted Label: __label__LinkCut
# Test Sample 4327 Predicted Label: __label__LinkCut

# %%
# 예측 결과를 데이터프레임으로 저장
pred_label = pd.DataFrame({"Test Sample": range(1, len(predictions) + 1)})
pred_label["Predicted Label"] = predictions  # 'Predicted Label' 열에 예측 결과 추가
# Out:
#       Test Sample     Predicted Label
# 0               1  __label__PowerFail
# 1               2  __label__PowerFail
# 2               3  __label__PowerFail
# 3               4  __label__PowerFail
# 4               5  __label__PowerFail
# ...           ...                 ...
# 4322         4323    __label__LinkCut
# 4323         4324    __label__LinkCut
# 4324         4325    __label__LinkCut
# 4325         4326    __label__LinkCut
# 4326         4327    __label__LinkCut
#
# [4327 rows x 2 columns]

# %%
# 'Predicted Label' 컬럼 값 변환
pred_label['Predicted Label'] = pred_label['Predicted Label'].apply(lambda x: x.replace('__label__', ''))
pred_label.head()
# Out:
#    Test Sample Predicted Label
# 0            1       PowerFail
# 1            2       PowerFail
# 2            3       PowerFail
# 3            4       PowerFail
# 4            5       PowerFail

# %%
label_sample = label_sample_org.copy()

# %%
# 원래 데이터프레임에 새로운 데이터 추가
label_sample['root_cause_type'] = pred_label['Predicted Label']

# 결과 출력
label_sample.head()
# Out:
#      ticketno root_cause_type
# 0  15238899.0       PowerFail
# 1  15712444.0       PowerFail
# 2  15723187.0       PowerFail
# 3  15737103.0       PowerFail
# 4  15737132.0       PowerFail

# %%
# 타겟 비율 확인
label_sample['root_cause_type'].value_counts()/len(label_sample['root_cause_type'])
# Out:
# LinkCut      0.658655
# PowerFail    0.308990
# UnitFail     0.032355
# Name: root_cause_type, dtype: float64

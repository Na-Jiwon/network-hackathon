# %% [markdown]
# # **Library**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
seed_value = 777

# %%
import pandas as pd
import numpy as np
import random
import statsmodels as sm
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight


from sklearn.metrics import accuracy_score

from lightgbm import LGBMClassifier

import gensim
from gensim.models import Word2Vec
from gensim.models import FastText

import joblib

import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, Dense, Dropout, LayerNormalization
from tensorflow.keras.layers import MultiHeadAttention, Lambda
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D
from tensorflow.keras import Input, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy

from tensorflow.keras.models import save_model
from tensorflow.keras.models import load_model

tf.random.set_seed(seed_value)
np.random.seed(seed_value)
random.seed(seed_value)

# %% [markdown]
# # **Data**

# %%
label_sample_org = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/백지짱_분야2/Submit/data/Q2_train.csv')
train_org = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/백지짱_분야2/Submit/data/Q2_train.csv')
test_org = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/백지짱_분야2/Submit/data/Q2_test.csv')

# %%
print(label_sample_org.shape)
print(train_org.shape)
print(test_org.shape)
# Out:
# (9322, 13)
# (9322, 13)
# (37671, 12)

# %%
train_org.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9322 entries, 0 to 9321
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ticketno           9322 non-null   float64
#  1   alarmno            9322 non-null   int64
#  2   alarmtime          9322 non-null   object
#  3   alarmlevel         9322 non-null   int64
#  4   alarmmsg_original  9322 non-null   object
#  5   site               9322 non-null   object
#  6   sysname            9322 non-null   object
#  7   unit               9322 non-null   object
#  8   slot               8957 non-null   float64
#  9   port               8725 non-null   float64
#  10  sva                9322 non-null   object
#  11  root_cause_domain  9322 non-null   object
#  12  root_cause_type    9322 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 946.9+ KB

# %%
test_org.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37671 entries, 0 to 37670
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ticketno           37671 non-null  float64
#  1   alarmno            37671 non-null  int64
#  2   alarmtime          37671 non-null  object
#  3   alarmlevel         37671 non-null  int64
#  4   alarmmsg_original  37671 non-null  object
#  5   site               37671 non-null  object
#  6   sysname            37671 non-null  object
#  7   unit               37671 non-null  object
#  8   slot               34890 non-null  float64
#  9   port               34853 non-null  float64
#  10  sva                37671 non-null  object
#  11  root_cause_domain  37671 non-null  object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 3.4+ MB

# %%
label_sample_org.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9322 entries, 0 to 9321
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ticketno           9322 non-null   float64
#  1   alarmno            9322 non-null   int64
#  2   alarmtime          9322 non-null   object
#  3   alarmlevel         9322 non-null   int64
#  4   alarmmsg_original  9322 non-null   object
#  5   site               9322 non-null   object
#  6   sysname            9322 non-null   object
#  7   unit               9322 non-null   object
#  8   slot               8957 non-null   float64
#  9   port               8725 non-null   float64
#  10  sva                9322 non-null   object
#  11  root_cause_domain  9322 non-null   object
#  12  root_cause_type    9322 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 946.9+ KB

# %%
# 중복행 존재 유무 확인
print('train: ', train_org.duplicated().sum())
print('test: ', test_org.duplicated().sum())
# Out:
# train:  0
# test:  0

# %%
# train 데이터 컬럼, 결측치 수, 퍼센트 확인
data_missing = []

for i in train_org.columns:
    missings = train_org[i].isnull().sum()
    if missings > 0:
        data_missing.append(i)
        missings_perc = missings / train_org.shape[0]
        print(f"{i} 칼럼 결측치 수: {missings} ({missings_perc:.2%})")

print('------------------------------')
print(f"결측치가 존재하는 총 컬럼 수: {len(data_missing)}")
# Out:
# slot 칼럼 결측치 수: 365 (3.92%)
# port 칼럼 결측치 수: 597 (6.40%)
# ------------------------------
# 결측치가 존재하는 총 컬럼 수: 2

# %%
# test 데이터 컬럼, 결측치 수, 퍼센트 확인
data_missing = []

for i in test_org.columns:
    missings = test_org[i].isnull().sum()
    if missings > 0:
        data_missing.append(i)
        missings_perc = missings / test_org.shape[0]
        print(f"{i} 칼럼 결측치 수: {missings} ({missings_perc:.2%})")

print('------------------------------')
print(f"결측치가 존재하는 총 컬럼 수: {len(data_missing)}")
# Out:
# slot 칼럼 결측치 수: 2781 (7.38%)
# port 칼럼 결측치 수: 2818 (7.48%)
# ------------------------------
# 결측치가 존재하는 총 컬럼 수: 2

# %%
# 두 데이터셋의 unique개수 비교 함수
def unique_count(column):
    print('train unique값 개수 -->', len(train_org[column].unique()))
    print('test unique값 개수 --> ', len(test_org[column].unique()))

# %%
column = ['ticketno', 'alarmno', 'alarmtime', 'alarmlevel', 'alarmmsg_original',
       'site', 'sysname', 'unit', 'slot', 'port', 'sva', 'root_cause_domain']

for i in column:
    print('###', i, '###')
    unique_count(i)
    print('-------------'*2)
# Out:
# ### ticketno ###
# train unique값 개수 --> 1114
# test unique값 개수 -->  4327
# --------------------------
# ### alarmno ###
# train unique값 개수 --> 9322
# test unique값 개수 -->  37671
# --------------------------
# ### alarmtime ###
# train unique값 개수 --> 8132
# test unique값 개수 -->  32986
# --------------------------
# ### alarmlevel ###
# train unique값 개수 --> 4
# test unique값 개수 -->  4
# --------------------------
# ### alarmmsg_original ###
# train unique값 개수 --> 31
# test unique값 개수 -->  73
# --------------------------
# ### site ###
# train unique값 개수 --> 535
# test unique값 개수 -->  1329
# --------------------------
# ### sysname ###
# train unique값 개수 --> 605
# test unique값 개수 -->  1566
# --------------------------
# ### unit ###
# train unique값 개수 --> 2
# test unique값 개수 -->  666
# --------------------------
# ### slot ###
# train unique값 개수 --> 12
# test unique값 개수 -->  21
# --------------------------
# ### port ###
# train unique값 개수 --> 11
# test unique값 개수 -->  41
# --------------------------
# ### sva ###
# train unique값 개수 --> 1
# test unique값 개수 -->  2
# --------------------------
# ### root_cause_domain ###
# train unique값 개수 --> 1
# test unique값 개수 -->  3
# --------------------------

# %%
# ticketno와 alarmno 각각의 중복 개수 확인
for column in train_org.columns[:2]:
    train_dup = train_org[column].duplicated().sum()
    test_dup = test_org[column].duplicated().sum()
    print('Train - {} : {} duplicated values'.format(column, train_dup))
    print('Test - {} : {} duplicated values'.format(column, test_dup))
    print('\n')
# Out:
# Train - ticketno : 8208 duplicated values
# Test - ticketno : 33344 duplicated values
#
#
# Train - alarmno : 0 duplicated values
# Test - alarmno : 0 duplicated values

# %%
# 두 데이터셋의 unique값 비교 함수
def unique_result(column):
    print('train unique값 -->', train_org[column].unique())
    print('test unique값 -->', test_org[column].unique())

# %%
column = ['alarmlevel', 'alarmmsg_original',
       'site', 'sysname', 'unit', 'slot', 'port', 'sva', 'root_cause_domain']

for i in column:
    print('###', i, '###')
    unique_result(i)
    print('----------------------------------------------'*2)
# Out:
# ### alarmlevel ###
# train unique값 --> [5 7 4 3]
# test unique값 --> [5 4 3 7]
# --------------------------------------------------------------------------------------------
# ### alarmmsg_original ###
# train unique값 --> ['ETH-ERR' 'OPT-LOS' 'DCC-FAIL' 'LSP-LOC' 'ETH-NO-RX-TRAFFIC'
#  'OPT-PWR-LOW' 'PSU-FAIL' 'ETH-LINK-FAIL' 'AUTONEGO_MISMATCH'
#  'TDM-PW-RMT_FAIL' 'OPT-REMOVE' 'TRK-CONN-MIS' 'ProtectionSwitched'
#  'NVRAM-FAIL' 'PW-LOC' 'BATT-LOW' 'BOOTING' 'ETH-NO-TX-TRAFFIC'
#  'Restarted' 'OS_MISMATCH' 'UNIT-REM' 'TDM-PW-LOF' 'FAN-48V-FAIL'
#  'FAN-FAIL' '48V-FAIL' 'PortShutdown' 'QL_FAIL' 'UNIT-IPC-FAIL'
#  'LINK_FAIL_MANUAL' 'PSU-REM' 'OPT-MIS']
# test unique값 --> ['Loss Of Signal' 'DDM_RX_PWR_HIGH' 'BATT_ENV_FAIL' 'DDM_RX_PWR_LOW'
#  'Remote Defect Indication' 'MEP_LSP_LOC' 'Input Power Degrade Defect'
#  'OPT-LOS' 'ETH-LINK-FAIL' 'ETHER_LINK_DOWN (LOCAL_FAULT)'
#  'ETHER_LINK_DOWN (LLCF)' 'Server Signal Failure' 'PPP Fail' 'MEP_PWE_LOC'
#  'House Keeping Alarm' 'Rx Fail' 'ETHER_TCA_DROP_1D' 'Client Signal Fail'
#  'Loss of Connectivity' 'Unexpected MEG' 'ETH-NO-TX-TRAFFIC' 'MEP_PWE_CSF'
#  'UNIT_FAIL' 'LSP-LOC' 'PSU-FAIL' 'ETHER_LINK_DOWN (LOS)'
#  'OAM Loss Of Continuity' 'NE Not Reachable Via Primary Mng Interf'
#  'Node Isolation' 'NE Not Reach Via Primary Mng Interf' 'OPT-PWR-LOW'
#  'OPT-REMOVE' 'ETHER_TCA_CRC_15M' 'ETHER_TCA_CRC_1D' 'ETHER_PORT_CRC'
#  'BATTERY_FAIL' 'ETHER_TCA_DROP_15M' 'BOOTING' 'OAM RDI'
#  'Hardware failure' 'DCN_FAIL' 'ETH-NO-RX-TRAFFIC' 'DCC-FAIL' 'ETH-ERR'
#  'Improper Removal' 'OPT-PWR-HIGH' 'AUTONEGO_MISMATCH'
#  'Underlying Resource Unavailable' 'OAMLoss Of Continuity'
#  'MODULE_OUT ( SFP+ )' 'MODULE_OUT ( SFP )' 'DC_INPUT_A_FAIL'
#  'TRK-CONN-MIS' 'Manual (Management) Removal' 'MEP_LSP_RDI' 'PW-LOC'
#  'Procedure Error' 'OPT-MIS' 'ETHER_LINK_DOWN (REMOTE_FAULT)'
#  'UNIT_INIT (BY INSLOT)' 'UNIT_INIT (BY RESET)' 'UNIT_OUT' 'STM1_LOS'
#  'SYS_TEMP_LOW' 'TDM-PW-RMT_FAIL' 'LINK_FAIL_MANUAL'
#  'Abnormal Condition: Laser Forced' 'QL_FAIL'
#  'IOC Payload-Links with Matrix Failure' '48V-FAIL'
#  'Remote Fault Indication' 'CEP_AIS' 'Synchronization Signal Fail Raise']
# --------------------------------------------------------------------------------------------
# ### site ###
# train unique값 --> ['ACEN' 'AENP' 'AENQ' 'ABVR' 'AECU' 'ACET' 'ADUA' 'ADKJ' 'AEPS' 'AEOM'
#  'AELY' 'ABZH' 'ABKX' 'AESQ' 'AFHW' 'ACFC' 'ABUQ' 'ABUO' 'AETG' 'ADZB'
#  'ABUP' 'ABUS' 'AEAX' 'AFCR' 'AEYE' 'ABUG' 'ACAR' 'ADLG' 'AEJN' 'ABUI'
#  'AEWS' 'ADKA' 'AFAA' 'ABZO' 'AESL' 'ADQH' 'ACCM' 'ACBP' 'AEZO' 'ABNE'
#  'ABZI' 'ADKL' 'ADWA' 'AEZR' 'ACGD' 'ADTP' 'AECZ' 'ABOZ' 'ADEZ' 'ABLB'
#  'ADPP' 'ADPM' 'ABUJ' 'ACBJ' 'ACTU' 'ABLZ' 'ABSU' 'ADPL' 'ADTU' 'ADKE'
#  'ACRX' 'AFEK' 'ABVN' 'ABWA' 'AEUC' 'ADFC' 'ACLL' 'ACVN' 'ACDO' 'ACAW'
#  'ADPO' 'AEZT' 'ADKI' 'ACFQ' 'ADTC' 'ABZM' 'AEAP' 'ABYO' 'ABYJ' 'ABYR'
#  'ABYN' 'ADMY' 'AFJR' 'AEVV' 'AEPF' 'AFCS' 'ADXE' 'AEPU' 'AFIX' 'ABUY'
#  'ADNY' 'AFFH' 'ADLD' 'ADVM' 'AEBQ' 'AECT' 'AFXY' 'ABPY' 'AERI' 'ADBT'
#  'AEAF' 'ABLT' 'AEBW' 'AEWR' 'ADML' 'AEHR' 'AEHS' 'ADRP' 'ACBV' 'AELE'
#  'AFAV' 'ABTB' 'ACHS' 'AEMJ' 'ADOM' 'ACBO' 'ADWW' 'ADEV' 'AFKU' 'AAOE'
#  'AEPT' 'AAMX' 'AEPB' 'AEJT' 'ADMM' 'AEPK' 'ADPA' 'AALT' 'AFSJ' 'ADXX'
#  'AEBM' 'AFVK' 'AFWJ' 'AFWN' 'AFFW' 'AFHL' 'AESZ' 'AFSA' 'ABTA' 'ADXL'
#  'ABXK' 'ACAU' 'AEBH' 'ADFA' 'AFIA' 'AENG' 'AEVK' 'AFFF' 'ADQE' 'AFBM'
#  'AEZG' 'AANT' 'AEAY' 'AASB' 'AAOU' 'AFFI' 'ADSE' 'AAOI' 'AENK' 'AEZD'
#  'ADWO' 'AAMM' 'AAOO' 'AAOG' 'AEGW' 'AAPS' 'AASR' 'AFBO' 'AAOQ' 'AAOZ'
#  'AAQJ' 'ADUI' 'AEDF' 'AANK' 'AFAS' 'AEJH' 'AANW' 'AAAA' 'ADTL' 'AARW'
#  'AAQD' 'AEJI' 'AFAB' 'ADHJ' 'ADYG' 'ADVF' 'AASJ' 'AANF' 'ABXR' 'AFGE'
#  'ABXO' 'AELS' 'ACHR' 'ADOF' 'AEHI' 'AEHJ' 'AEVF' 'ABXA' 'AESJ' 'AEZC'
#  'ACBZ' 'ADPR' 'ABVD' 'ACTL' 'AEIX' 'ADTI' 'AFIN' 'AERC' 'AERD' 'AFDE'
#  'AEOI' 'AFMB' 'AEYB' 'AEKS' 'AGGN' 'AESW' 'AELD' 'AFIS' 'ADZO' 'AFKO'
#  'ACGC' 'ADLE' 'ACNP' 'AEPJ' 'AFOW' 'ADYT' 'AEBO' 'AGHK' 'AEBP' 'AFFY'
#  'AFEZ' 'AETJ' 'ADED' 'AFBZ' 'ABOJ' 'ACDF' 'ABXQ' 'AEVG' 'AEIK' 'AECG'
#  'AFKS' 'ABTK' 'ABUU' 'AEEI' 'AEWO' 'ADKD' 'ADJX' 'AFSK' 'ADXW' 'ADRQ'
#  'AEFI' 'AECR' 'AFMX' 'AEXX' 'AFNI' 'AFNJ' 'AETR' 'ADXJ' 'AEIW' 'AFQU'
#  'AEGR' 'AFLO' 'ADYD' 'AERL' 'ADQQ' 'ADZA' 'AFCF' 'AFEO' 'ADZE' 'ADOY'
#  'AERK' 'AERE' 'ACCI' 'ACSB' 'ACSC' 'AEOO' 'AFIE' 'ABYW' 'AFVB' 'AEZE'
#  'ABZA' 'AEMR' 'ADVG' 'AEBT' 'AFEX' 'AGBM' 'AFEY' 'ACAY' 'ABZZ' 'ADKC'
#  'ADKF' 'ADKG' 'ADYU' 'ADQA' 'AFIY' 'ABTC' 'AFLD' 'ADWN' 'AESS' 'ABYF'
#  'ACBH' 'AFSE' 'ACEZ' 'ACCU' 'AEQI' 'AEPO' 'AFMY' 'AELQ' 'AGDX' 'AGDY'
#  'ADVB' 'ACBL' 'AFMZ' 'AFTI' 'AGAC' 'AFFP' 'AFNM' 'AEEV' 'ADXQ' 'AEGJ'
#  'AFXR' 'AGDT' 'AGIZ' 'AEOS' 'AFEB' 'AFEC' 'AEOY' 'AFDF' 'AFKI' 'AFHX'
#  'AFHR' 'AESP' 'ADYB' 'AEFQ' 'ADQC' 'ADQR' 'AEPW' 'ACGS' 'ACEE' 'AFHA'
#  'AFYH' 'ACCZ' 'AGII' 'ACFD' 'ACBR' 'ACBS' 'AFGZ' 'ACER' 'ACFH' 'ACGT'
#  'ACGJ' 'ADQG' 'ADQF' 'ADQM' 'ADQD' 'ADQO' 'ADQJ' 'ADQP' 'ADQI' 'ADQU'
#  'ADQL' 'ADQN' 'ADQK' 'ADQT' 'AEQE' 'AFUJ' 'ACGQ' 'ACHV' 'ACES' 'ACEF'
#  'ACFL' 'ACEO' 'ACEG' 'ACII' 'ACIH' 'ACIF' 'AFNY' 'ACAX' 'ACBB' 'ACBD'
#  'ACBF' 'ACBI' 'ACHC' 'ACEL' 'ACBQ' 'ACEK' 'ACCE' 'ACCG' 'ACCJ' 'ACCT'
#  'ACCB' 'ACCF' 'ACBX' 'ACBU' 'ACBT' 'ACAQ' 'ADPV' 'AFIC' 'AAPL' 'ACQH'
#  'ADEX' 'AEGU' 'ACOW' 'ACCQ' 'AEKY' 'AEMN' 'AEAO' 'ABWM' 'AEPD' 'AECB'
#  'ACPG' 'ACCA' 'ABRZ' 'ABRM' 'ACEM' 'ACEQ' 'AEDT' 'AFLM' 'ADYR' 'AEFH'
#  'ADYQ' 'ADYO' 'ADYP' 'AEFJ' 'AFIT' 'AEFE' 'AEFK' 'AFJC' 'ADKB' 'AEWN'
#  'ABZB' 'AEFM' 'AEFL' 'ADVZ' 'AFLG' 'AAPI' 'AEXY' 'AFLL' 'ADXA' 'AEXV'
#  'AFPC' 'ABVG' 'AFID' 'AEDM' 'AFII' 'AEMY' 'AECW' 'AEFP' 'AEXW' 'AFLH'
#  'AEMZ' 'AFAK' 'AFAL' 'AETE' 'AEFN' 'AFIJ' 'AEGS' 'ADPW' 'AGIU' 'AEDA'
#  'ABYM' 'ACGZ' 'ACCS' 'ADHC' 'AFRX' 'ABTI' 'AFBX' 'ACAA' 'ACTD' 'ADPB'
#  'ADZT' 'ABSX' 'ABWF' 'ABTX' 'ABUM' 'AEZN' 'AELM' 'ADHA' 'ABWW' 'AFDG'
#  'AEWW' 'AEZX' 'ABZP' 'ADIJ' 'ADIG' 'ABYP' 'ABZK' 'ABYL' 'ACSE' 'ABZY'
#  'ABXM' 'ABUF' 'ADZC' 'AFDO' 'AFHM' 'ADDT' 'AFCM' 'ACPJ' 'AFNC' 'AGQO'
#  'AEDN' 'ACFE' 'ACRQ' 'ABXS' 'ADKH' 'ABZD' 'ACHK' 'ACCX' 'ADOJ' 'AFIP'
#  'ADRM' 'ACAI' 'ABYT' 'AGFD' 'ABVL' 'AELF' 'AFSV' 'ADMK' 'AEAZ' 'ADRZ'
#  'AFAP' 'ABXE' 'AFSW' 'AFNQ' 'ADJZ' 'ADWS' 'ABNO' 'ADRW' 'ADWR' 'ACCK'
#  'AEAC' 'ABVZ' 'AERS' 'ADOK' 'ADZQ']
# test unique값 --> ['AEAQ' 'ADZW' 'AECE' ... 'AASC' 'ADDF' 'AFEJ']
# --------------------------------------------------------------------------------------------
# ### sysname ###
# train unique값 --> ['acnt' 'afvf' 'afvc' 'afvh' 'afvg' 'afvl' 'acdi' 'affb' 'acok' 'aeqe'
#  'aeaz' 'afxi' 'afwp' 'afsg' 'achw' 'abps' 'agdd' 'ahbn' 'acnx' 'acbr'
#  'acbp' 'ager' 'aezu' 'acbq' 'acbt' 'afcd' 'agtf' 'agtg' 'aglz' 'acbe'
#  'acbf' 'acik' 'afsf' 'aecp' 'afop' 'accl' 'agkg' 'aeaq' 'agow' 'acie'
#  'agcv' 'aekb' 'aclo' 'ackp' 'agod' 'absb' 'achx' 'aebb' 'aeua' 'agoi'
#  'acpx' 'aeny' 'afea' 'abuc' 'adsj' 'aehg' 'aehd' 'accm' 'acki' 'admr'
#  'abqs' 'abzg' 'acde' 'aehc' 'aepx' 'aeau' 'addp' 'agsg' 'accr' 'aceu'
#  'agfw' 'aduv' 'adci' 'adht' 'acmr' 'ackd' 'aehf' 'agom' 'aeay' 'acom'
#  'aeot' 'acic' 'afbb' 'acha' 'acgv' 'ache' 'achb' 'acgz' 'aehv' 'agza'
#  'agel' 'afxr' 'agth' 'agtl' 'agtk' 'aevv' 'afyn' 'ahcx' 'acca' 'accb'
#  'acbz' 'accc' 'aeha' 'agrq' 'aech' 'aesx' 'afdq' 'afca' 'ahwt' 'abxh'
#  'agav' 'adqj' 'afal' 'abqr' 'afdx' 'agkd' 'aeex' 'afjv' 'afjx' 'aemh'
#  'ackw' 'afqx' 'agpy' 'agpx' 'abzn' 'aeou' 'acru' 'aftc' 'aehl' 'ackx'
#  'aewa' 'aduo' 'ahbk' 'aaqe' 'afym' 'aaor' 'afxg' 'afms' 'aeey' 'afxw'
#  'aeia' 'aamw' 'aenx' 'ahbl' 'ahob' 'aeuq' 'afaf' 'ahsb' 'ahtz' 'ahuf'
#  'agum' 'agwr' 'agbx' 'ahns' 'acai' 'agau' 'agas' 'agar' 'agat' 'aewe'
#  'acfq' 'acjg' 'afdg' 'adut' 'ahba' 'aftz' 'aggj' 'agxk' 'aeik' 'agqo'
#  'agna' 'aapr' 'afat' 'agnc' 'aaul' 'aaqv' 'agxn' 'aeme' 'aaqj' 'afue'
#  'agmp' 'aeta' 'aaod' 'aaqp' 'aaqh' 'afjf' 'aary' 'aavh' 'agqw' 'aaqr'
#  'aarc' 'aasr' 'aepb' 'afeh' 'aapf' 'agpe' 'afof' 'aapu' 'aaab' 'aenv'
#  'aaug' 'aasj' 'afog' 'agox' 'aedn' 'aevp' 'aeql' 'aaux' 'aevo' 'agnb'
#  'aapa' 'acfz' 'agyt' 'agti' 'acfw' 'afrz' 'acqw' 'aehh' 'afkh' 'afkp'
#  'aghk' 'acfg' 'agnk' 'acko' 'aegp' 'acch' 'admf' 'agaw' 'afnw' 'agih'
#  'aepk' 'ahcm' 'afze' 'afzf' 'agqe' 'afuu' 'ahdk' 'agiq' 'ahzp' 'aijp'
#  'agbs' 'afon' 'ahcr' 'aezc' 'acpw' 'affc' 'aecj' 'acya' 'afwh' 'ackv'
#  'ahiu' 'aevq' 'afaj' 'aiks' 'afak' 'agup' 'afwn' 'afya' 'adtt' 'agsd'
#  'abti' 'acmh' 'acdy' 'agho' 'aghp' 'afsh' 'agmb' 'ahbe' 'acbk' 'acda'
#  'afcz' 'agok' 'aeat' 'aean' 'ahoc' 'aeye' 'aekz' 'afhh' 'afdk' 'ahib'
#  'aglb' 'ahis' 'ahiv' 'agcs' 'aeum' 'afns' 'ahox' 'afiy' 'ahga' 'agyg'
#  'aevl' 'afzx' 'aejd' 'aexb' 'agrp' 'agwf' 'aexg' 'aegd' 'afzv' 'afzp'
#  'acma' 'accj' 'adde' 'addf' 'afup' 'agwc' 'acgk' 'ahrp' 'agnm' 'achp'
#  'aftn' 'aess' 'afdu' 'agrf' 'ahwa' 'agrg' 'ackf' 'acir' 'aeas' 'aeav'
#  'aciq' 'aeaw' 'afcn' 'aejs' 'ahcz' 'ahda' 'afyl' 'acii' 'abzo' 'ahce'
#  'aezq' 'agds' 'agdt' 'acgw' 'acjw' 'affe' 'affd' 'ahnw' 'acog' 'acme'
#  'afwm' 'ahfa' 'afpp' 'aign' 'aigr' 'aepu' 'acku' 'ahfk' 'ahpd' 'aiap'
#  'agud' 'ahgn' 'affz' 'aeud' 'afic' 'ahwh' 'aigi' 'ainz' 'agro' 'afvn'
#  'agqh' 'ahat' 'agxf' 'agwy' 'agbh' 'aeuu' 'afha' 'aewp' 'aeis' 'aeie'
#  'acmq' 'acmp' 'aeit' 'afwv' 'acqn' 'ahxe' 'acmj' 'aimy' 'acov' 'acla'
#  'aclb' 'agwb' 'acoi' 'acoz' 'acqo' 'acqd' 'acqe' 'aeii' 'aeig' 'aeih'
#  'aeio' 'aeif' 'aeiq' 'aeil' 'aeir' 'aeiw' 'aein' 'aeip' 'aeij' 'aeim'
#  'aeiv' 'ahqp' 'acql' 'acrx' 'acoj' 'acnu' 'acpd' 'acpi' 'acof' 'acnv'
#  'acsk' 'acsj' 'acsh' 'ahhi' 'acke' 'ackk' 'ackn' 'ackq' 'ackr' 'acqz'
#  'acoc' 'ackz' 'acoa' 'acob' 'aclq' 'aclt' 'acmd' 'acll' 'aclp' 'aclg'
#  'acld' 'aclj' 'aclc' 'acij' 'agxr' 'aaqx' 'adim' 'adax' 'aduq' 'afga'
#  'agtn' 'agtm' 'aczw' 'acmi' 'afqh' 'acjj' 'afba' 'acdh' 'afxo' 'aeuo'
#  'afhz' 'adag' 'aclk' 'acho' 'abyi' 'abxu' 'acns' 'acnw' 'afgx' 'ahft'
#  'ahbg' 'aewo' 'afhg' 'aewn' 'aewl' 'aewm' 'afhi' 'ahby' 'afhd' 'afhj'
#  'ahci' 'aear' 'agoj' 'afhl' 'afhk' 'aesi' 'ahfn' 'aesj' 'aaro' 'aglc'
#  'ahfs' 'aetx' 'agkz' 'ahen' 'ahmk' 'acdz' 'ahbf' 'afeq' 'aftq' 'afdw'
#  'afho' 'agla' 'ahfo' 'aftr' 'afhm' 'afky' 'aegv' 'ainu' 'addu' 'affo'
#  'acgy' 'acmk' 'advt' 'ahnn' 'abzv' 'agoe' 'adeo' 'aezi' 'aghr' 'acaf'
#  'aght' 'aghq' 'agpv' 'aesn' 'ahbp' 'afff' 'ahde' 'acae' 'aghs' 'acea'
#  'acbl' 'agpu' 'agoa' 'acad' 'acac' 'afve' 'ahbo' 'ahcl' 'ahdb' 'affa'
#  'ahbm' 'agdp' 'aesm' 'ahck' 'ahdc' 'agob' 'afrq' 'afvd' 'ahdd' 'advq'
#  'afrp' 'agdo' 'agpt' 'acez' 'agun' 'agkl' 'agoq' 'acif' 'adxi' 'adxf'
#  'agoc' 'achc' 'achz' 'acgx' 'addw' 'acip' 'acex' 'aaql' 'acat' 'aeyn'
#  'agvf' 'ahav' 'aeyf' 'agsx' 'adhh' 'ahih' 'airg' 'afgi' 'acol' 'addi'
#  'acfd' 'aeax' 'aelc' 'agpw' 'achs' 'acqp' 'ahbr' 'aekf' 'acit' 'aibb'
#  'acak' 'afra' 'ahrm' 'afav' 'aely' 'agpb' 'acen' 'aaaa' 'ahjc' 'aeap'
#  'aeyr' 'absm' 'aekx' 'ahbz' 'aehi' 'acmc' 'affr' 'agov' 'aghl' 'aekm'
#  'agaf' 'aehm' 'aeca' 'aexe' 'aexx']
# test unique값 --> ['afbd' 'aezn' 'afeg' ... 'adwj' 'adqm' 'agwk']
# --------------------------------------------------------------------------------------------
# ### unit ###
# train unique값 --> ['EQPT' 'NODE']
# test unique값 --> ['r1sr1sl16/ETHLocPort#15#1' 'r1sr1sl13/ETHLocPort#20#1' 'X2FUA' '---'
#  'r1sr1sl16/ETHLocPort#16#1' 'r1sr1sl19/ETHLocPort#12#1' 'XFU-A'
#  'r1sr1sl17/ETHLocPort#18#1' 'TUSEG-1-1-14,TUSEG,FEND,RCV'
#  'TUSEG-1-1-13,TUSEG,FEND,RCV' 'r1sr1sl17/ETHLocPort#15#1'
#  'r1sr1sl17/ETHLocPort#14#1' 'r1sr1sl17/ETHLocPort#17#1' 'GFU40'
#  'r1sr1sl2/ETHLocPort#8#1' 'r1sr1sl16/ETHLocPort#18#1'
#  'r1sr1sl17/ETHLocPort#11#1' 'r1sr1sl16/ETHLocPort#19#1'
#  'r1sr1sl17/ETHLocPort#16#1' 'r1sr1sl19/ETHLocPort#16#1' 'EQPT' 'G2FUA'
#  'r1sr1sl17/ETHLocPort#12#1' 'r1sr1sl15/ETHLocPort#14#1'
#  'TUSEG-1-1-15,TUSEG,FEND,RCV' 'r1sr1sl16/ETHLocPort#14#1'
#  'r1sr1sl17/ETHLocPort#19#1' 'r1sr1sl19/ETHLocPort#14#1'
#  'r1sr1sl17/ETHLocPort#8#1' 'r1sr1sl17/ETHLocPort#9#1'
#  'r1sr1sl16/ETHLocPort#8#1' 'r1sr1sl16/ETHLocPort#9#1'
#  'TUSEG-1-1-113,TUSEG,NEND,RCV' 'TUSEG-1-1-63,TUSEG,NEND,RCV'
#  'TUSEG-1-1-114,TUSEG,NEND,RCV' 'TUSEG-1-1-64,TUSEG,NEND,RCV'
#  'r1sr1sl17/INFiberINBand#8' 'r1sr1sl16/INFiberINBand#9'
#  'r1sr1sl17/INFiberINBand#9' 'G16FU' 'X4FUA' 'CPI-1-1-1-2,ENV'
#  'r1sr1sl13/ETHLocPort#10#1' 'r1sr1sl12/ETHLocPort#1#1' 'G4FUA'
#  'r1sr1sl2/ETHLocPort#7#1' 'r1sr1sl4/ETHLocPort#2#1'
#  'r1sr1sl17/ETHLocPort#2#1' 'MEP#1#25#1' 'TUSEG-1-1-2,TUSEG,FEND,RCV'
#  'TUSEG-1-1-1,TUSEG,FEND,RCV' 'TUSEG-1-1-28,TUSEG,NEND,RCV'
#  'TUSEG-1-1-27,TUSEG,NEND,RCV' 'MEP#1#1#1' 'r1sr1sl2/ETHLocPort#9#1'
#  'r1sr1sl13/ETHLocPort#15#1' 'TUSEG-1-1-2,TUSEG,RCV'
#  'TUSEG-1-1-18,TUSEG,NEND,RCV' 'r1sr1sl2/INFiberINBand#8'
#  'r1sr1sl18/ETHLocPort#2#1' 'r1sr1sl19/ETHLocPort#2#1'
#  'TUSEG-1-1-8,TUSEG,NEND,RCV' 'TUSEG-1-1-3,TUSEG,NEND,RCV'
#  'r1sr1sl18/INFiberINBand#2' 'r1sr1sl2/ETHLocPort#4#1'
#  'r1sr1sl2/ETHLocPort#2#1' 'r1sr1sl2/ETHLocPort#3#1'
#  'r1sr1sl2/ETHLocPort#5#1' 'r1sr1sl2/ETHLocPort#1#1' 'MEP#1#1#2'
#  'MEP#1#2#2' 'G4TU' 'PSUAC' 'r1sr1sl15/ETHLocPort#17#1'
#  'r1sr1sl13/ETHLocPort#17#1' 'TUSEG-1-1-49,TUSEG,NEND,RCV'
#  'TUSEG-1-1-50,TUSEG,NEND,RCV' 'r1sr1sl13/INFiberINBand#17'
#  'r1sr1sl15/INFiberINBand#17' 'r1sr1sl2/ETHLocPort#13#1'
#  'r1sr1sl3/ETHLocPort#9#1' 'r1sr1sl3/ETHLocPort#11#1'
#  'r1sr1sl2/ETHLocPort#11#1' 'GE12FU' 'r1sr1sl8/ETHLocPort#1#1'
#  'r1sr1sl14/ETHLocPort#18#1' 'r1sr1sl15/ETHLocPort#18#1'
#  'r1sr1sl15/INFiberINBand#18' 'r1sr1sl14/INFiberINBand#18' 'G16TU' 'G2TU'
#  'r1sr1sl12/ETHLocPort#2#1' 'MEP#1#59#1' 'MEP#2#28#1'
#  'r1sr1sl12/ETHLocPort#9#1' 'r1sr1sl12/ETHLocPort#15#1'
#  'r1sr1sl15/ETHLocPort#5#1' 'r1sr1sl14/ETHLocPort#5#1'
#  'r1sr1sl12/ETHLocPort#7#1' 'MEP#1#14#1' 'MEP#1#11#1'
#  'TUSEG-1-1-9,TUSEG,NEND,RCV' 'TUSEG-1-1-10,TUSEG,NEND,RCV'
#  'TUSEG-1-1-39,TUSEG,NEND,RCV' 'TUSEG-1-1-40,TUSEG,NEND,RCV'
#  'r1sr1sl15/INFiberINBand#5' 'r1sr1sl14/INFiberINBand#5'
#  'r1sr1sl12/INFiberINBand#15' 'r1sr1sl13/INFiberINBand#15' ' '
#  'r1sr1sl17/INFiberINBand#10' 'r1sr1sl8/ETHLocPort#13#1'
#  'TUSEG-1-1-17,TUSEG,NEND,RCV' 'r1sr1sl16/ETHLocPort#2#1'
#  'r1sr1sl16/ETHLocPort#5#1' 'TUSEG-1-1-15,TUSEG,NEND,RCV'
#  'r1sr1sl16/INFiberINBand#2' 'MEP#1#6#1' 'r1sr1sl12/ETHLocPort#12#1'
#  'r1sr1sl16/ETHLocPort#6#1' 'MBU' 'r1sr1sl6/ETHLocPort#2#1'
#  'r1sr1sl13/ETHLocPort#14#1' 'r1sr1sl12/ETHLocPort#14#1'
#  'r1sr1sl12/INFiberINBand#14' 'r1sr1sl13/INFiberINBand#14'
#  'r1sr1sl2/ETHLocPort#10#1' 'r1sr1sl4/ETHLocPort#3#1'
#  'r1sr1sl4/ETHLocPort#5#1' 'r1sr1sl5/ETHLocPort#6#1'
#  'r1sr1sl3/ETHLocPort#6#1' 'TUSEG-1-1-75,TUSEG,NEND,RCV'
#  'TUSEG-1-1-76,TUSEG,NEND,RCV' 'r1sr1sl3/INFiberINBand#6'
#  'r1sr1sl5/INFiberINBand#6' 'r1sr1sl17/ETHLocPort#1#1'
#  'r1sr1sl19/ETHLocPort#1#1' 'TUSEG-1-1-1,TUSEG,NEND,RCV'
#  'TUSEG-1-1-2,TUSEG,NEND,RCV' 'r1sr1sl19/INFiberINBand#1'
#  'r1sr1sl17/INFiberINBand#1' 'TUSEG-1-1-29,TUSEG,FEND,RCV'
#  'TUSEG-1-1-30,TUSEG,FEND,RCV' 'r1sr1sl19/ETHLocPort#3#1'
#  'r1sr1sl19/ETHLocPort#4#1' 'r1sr1sl17/ETHLocPort#4#1'
#  'r1sr1sl17/ETHLocPort#3#1' 'MEP#1#6#2' 'TUSEG-1-1-73,TUSEG,NEND,RCV'
#  'TUSEG-1-1-74,TUSEG,NEND,RCV' 'MEP#1#25#2' 'r1sr1sl5/ETHLocPort#5#1'
#  'r1sr1sl7/ETHLocPort#13#1' 'r1sr1sl17/INFiberINBand#3'
#  'r1sr1sl19/INFiberINBand#3' 'r1sr1sl17/INFiberINBand#4'
#  'r1sr1sl19/INFiberINBand#4' 'TUSEG-1-1-74,TUSEG,FEND,RCV'
#  'r1sr1sl15/ETHLocPort#10#1' 'PP1GEX20-1-1-18,EQPT,NEND' 'MEP#1#3#2'
#  'r1sr1sl19/INFiberINBand#2' 'r1sr1sl13/ETHLocPort#3#1'
#  'r1sr1sl14/ETHLocPort#4#1' 'r1sr1sl13/ETHLocPort#4#1'
#  'TUSEG-1-1-13,TUSEG,NEND,RCV' 'TUSEG-1-1-14,TUSEG,NEND,RCV'
#  'r1sr1sl13/INFiberINBand#4' 'r1sr1sl14/INFiberINBand#4'
#  'r1sr1sl13/ETHLocPort#1#1' 'r1sr1sl13/INFiberINBand#1'
#  'r1sr1sl12/INFiberINBand#1' 'MEP#1#16#1' 'r1sr1sl8/ETHLocPort#17#1' 'MCU'
#  'r1sr1sl13/ETHLocPort#12#1' 'TUSEG-1-1-30,TUSEG,NEND,RCV'
#  'TUSEG-1-1-29,TUSEG,NEND,RCV' 'r1sr1sl12/INFiberINBand#12'
#  'r1sr1sl13/INFiberINBand#12' 'TUSEG-1-1-31,TUSEG,FEND,RCV'
#  'TUSEG-1-1-32,TUSEG,FEND,RCV' 'r1sr1sl2/ETHLocPort#17#1'
#  'r1sr1sl18/ETHLocPort#19#1' 'TUSEG-1-1-1,TUSEG,RCV'
#  'r1sr1sl2/INFiberINBand#7' 'r1sr1sl18/INFiberINBand#19'
#  'r1sr1sl5/ETHLocPort#1#1' 'TUSEG-1-1-27,TUSEG,FEND,RCV'
#  'r1sr1sl19/INFiberINBand#19' 'MEP#1#8#1' 'r1sr1sl15/ETHLocPort#9#1'
#  'r1sr1sl6/ETHLocPort#14#1' 'r1sr1sl6/INFiberINBand#14'
#  'SFP-1-1-18-13,EQPT,NEND' 'SFP-1-1-6-14,EQPT,NEND'
#  'r1sr1sl18/ETHLocPort#12#1' 'r1sr1sl19/INFiberINBand#12'
#  'r1sr1sl18/ETHLocPort#13#1' 'r1sr1sl18/INFiberINBand#13'
#  'SFP-1-1-12-2,EQPT,NEND' 'r1sr1sl19/ETHLocPort#13#1'
#  'SFP-1-1-13-2,EQPT,NEND' 'r1sr1sl19/INFiberINBand#13'
#  'r1sr1sl7/ETHLocPort#14#1' 'r1sr1sl7/INFiberINBand#14'
#  'r1sr1sl19/ETHLocPort#19#1' 'r1sr1sl19/ETHLocPort#8#1'
#  'r1sr1sl19/INFiberINBand#8' 'r1sr1sl19/ETHLocPort#18#1'
#  'TUSEG-1-1-42,TUSEG,NEND,RCV' 'TUSEG-1-1-41,TUSEG,NEND,RCV' 'MEP#2#7#2'
#  'r1sr1sl8/ETHLocPort#7#1' 'r1sr1sl17/INFiberINBand#18'
#  'r1sr1sl19/INFiberINBand#18' 'r1sr1sl13/ETHLocPort#2#1'
#  'r1sr1sl18/ETHLocPort#7#1' 'r1sr1sl18/INFiberINBand#7'
#  'r1sr1sl19/ETHLocPort#7#1' 'r1sr1sl19/INFiberINBand#7'
#  'SFP-1-1-13-1,EQPT,NEND' 'TUSEG-1-1-42,TUSEG,FEND,RCV'
#  'r1sr1sl16/ETHLocPort#13#1' 'r1sr1sl16/INFiberINBand#13' 'PSUDC'
#  'SFP-1-1-7-6,EQPT,NEND' 'SFP-1-1-9-6,EQPT,NEND'
#  'r1sr1sl17/ETHLocPort#13#1' 'X1FA' 'SFP-1-1-17-13,EQPT,NEND'
#  'r1sr1sl3/ETHLocPort#8#1' 'r1sr1sl3/INFiberINBand#8'
#  'r1sr1sl7/ETHLocPort#6#1' 'r1sr1sl9/ETHLocPort#6#1'
#  'r1sr1sl5/ETHLocPort#3#1' 'r1sr1sl12/ETHLocPort#19#1'
#  'r1sr1sl13/ETHLocPort#19#1' 'r1sr1sl14/ETHLocPort#19#1'
#  'TUSEG-1-1-7,TUSEG,NEND,RCV' 'r1sr1sl13/INFiberINBand#19'
#  'r1sr1sl12/INFiberINBand#19' 'r1sr1sl14/INFiberINBand#19'
#  'r1sr1sl16/INFiberINBand#19' 'X10EU' 'r1sr1sl13/ETHLocPort#13#1'
#  'r1sr1sl15/ETHLocPort#3#1' 'r1sr1sl14/ETHLocPort#3#1'
#  'TUSEG-1-1-81,TUSEG,NEND,RCV' 'TUSEG-1-1-82,TUSEG,NEND,RCV'
#  'r1sr1sl14/INFiberINBand#3' 'r1sr1sl15/INFiberINBand#3'
#  'r1sr1sl19/ETHLocPort#9#1' 'r1sr1sl18/ETHLocPort#5#1'
#  'SFP-1-1-15-7,EQPT,NEND' 'r1sr1sl4/ETHLocPort#1#1'
#  'r1sr1sl8/ETHLocPort#3#1' 'r1sr1sl15/ETHLocPort#11#1'
#  'r1sr1sl9/ETHLocPort#3#1' 'TUSEG-1-1-52,TUSEG,NEND,RCV'
#  'SFP-1-1-9-3,EQPT,NEND' 'r1sr1sl12/ETHLocPort#18#1'
#  'r1sr1sl13/ETHLocPort#18#1' 'TUSEG-1-1-5,TUSEG,NEND,RCV'
#  'TUSEG-1-1-6,TUSEG,NEND,RCV' 'r1sr1sl13/INFiberINBand#18'
#  'r1sr1sl12/INFiberINBand#18' 'TUSEG-1-1-45,TUSEG,NEND,RCV'
#  'TUSEG-1-1-46,TUSEG,NEND,RCV' 'MEP#1#4#1' 'MEP#2#3#2'
#  'r1sr1sl7/ETHLocPort#11#1' 'CPI-1-1-45-3,ENV' 'CPI-1-1-45-1,ENV'
#  'r1sr1sl18/ETHLocPort#4#1' 'r1sr1sl18/ETHLocPort#3#1'
#  'SFP-1-1-19-5,EQPT,NEND' 'r1sr1sl15/ETHLocPort#4#1' 'MEP#2#10#2'
#  'r1sr1sl15/INFiberINBand#4' 'TUSEG-1-1-8,TUSEG,FEND,RCV'
#  'r1sr1sl18/INFiberINBand#5' 'r1sr1sl19/ETHLocPort#5#1'
#  'r1sr1sl19/INFiberINBand#5' 'SFP-1-1-18-7,EQPT,NEND'
#  'r1sr1sl18/ETHLocPort#6#1' 'r1sr1sl18/INFiberINBand#6'
#  'r1sr1sl7/ETHLocPort#16#1' 'r1sr1sl19/ETHLocPort#6#1'
#  'r1sr1sl19/INFiberINBand#6' 'r1sr1sl12/ETHLocPort#10#1'
#  'r1sr1sl13/ETHLocPort#11#1' 'r1sr1sl12/ETHLocPort#11#1' 'MEP#2#13#2'
#  'MEP#1#12#1' 'TUSEG-1-1-37,TUSEG,NEND,RCV' 'TUSEG-1-1-38,TUSEG,NEND,RCV'
#  'r1sr1sl13/INFiberINBand#11' 'r1sr1sl12/INFiberINBand#10'
#  'r1sr1sl12/INFiberINBand#11' 'SFP-1-1-18-8,EQPT,NEND'
#  'SFP-1-1-18-9,EQPT,NEND' 'SFP-1-1-13-13,EQPT,NEND'
#  'SFP-1-1-19-7,EQPT,NEND' 'SFP-1-1-19-8,EQPT,NEND'
#  'SFP-1-1-19-9,EQPT,NEND' 'SFP-1-1-19-11,EQPT,NEND'
#  'r1sr1sl18/ETHLocPort#14#1' 'MEP#1#17#2' 'TUSEG-1-1-43,TUSEG,NEND,RCV'
#  'r1sr1sl19/INFiberINBand#14' 'r1sr1sl18/INFiberINBand#14'
#  'SFP-1-1-15-20,EQPT,NEND' 'SFP-1-1-18-10,EQPT,NEND'
#  'r1sr1sl18/ETHLocPort#16#1' 'r1sr1sl18/INFiberINBand#16' 'G40FU'
#  'SFP-1-1-18-11,EQPT,NEND' 'SFP-1-1-18-12,EQPT,NEND'
#  'SFP-1-1-19-10,EQPT,NEND' 'MEP#1#32#2' 'r1sr1sl18/ETHLocPort#9#1'
#  'TUSEG-1-1-32,TUSEG,NEND,RCV' 'TUSEG-1-1-31,TUSEG,NEND,RCV'
#  'r1sr1sl17/INFiberINBand#2' 'TUSEG-1-1-16,TUSEG,NEND,RCV'
#  'r1sr1sl19/INFiberINBand#9' 'r1sr1sl12/ETHLocPort#13#1'
#  'TUSEG-1-1-77,TUSEG,NEND,RCV' 'TUSEG-1-1-78,TUSEG,NEND,RCV'
#  'r1sr1sl13/INFiberINBand#13' 'r1sr1sl12/INFiberINBand#13'
#  'TUSEG-1-1-68,TUSEG,NEND,RCV' 'TUSEG-1-1-67,TUSEG,NEND,RCV'
#  'r1sr1sl16/INFiberINBand#14' 'r1sr1sl17/INFiberINBand#14'
#  'TUSEG-1-1-98,TUSEG,NEND,RCV' 'SWU' 'r1sr1sl12/ETHLocPort#4#1'
#  'r1sr1sl6/ETHLocPort#1#1' 'TUSEG-1-1-11,TUSEG,FEND,RCV'
#  'r1sr1sl8/ETHLocPort#2#1' 'TUSEG-1-1-11,TUSEG,NEND,RCV'
#  'r1sr1sl15/ETHLocPort#19#1' 'r1sr1sl15/ETHLocPort#20#1'
#  'r1sr1sl15/INFiberINBand#20' 'r1sr1sl15/INFiberINBand#19' 'STM1U'
#  'r1sr1sl13/ETHLocPort#16#1' 'r1sr1sl15/ETHLocPort#15#1'
#  'r1sr1sl15/ETHLocPort#16#1' 'MEP#1#21#2' 'MEP#1#31#2'
#  'TUSEG-1-1-19,TUSEG,NEND,RCV' 'TUSEG-1-1-20,TUSEG,NEND,RCV'
#  'r1sr1sl15/ETHLocPort#7#1' 'r1sr1sl15/INFiberINBand#15'
#  'r1sr1sl15/INFiberINBand#16' 'r1sr1sl13/INFiberINBand#16'
#  'TUSEG-1-1-20,TUSEG,FEND,RCV' 'TUSEG-1-1-24,TUSEG,FEND,RCV'
#  'TUSEG-1-1-23,TUSEG,FEND,RCV' 'TUSEG-1-1-61,TUSEG,NEND,RCV'
#  'r1sr1sl12/ETHLocPort#20#1' 'TUSEG-1-1-4,TUSEG,NEND,RCV'
#  'r1sr1sl13/INFiberINBand#20' 'r1sr1sl12/INFiberINBand#20'
#  'SFP-1-1-15-11,EQPT,NEND' 'SFP-1-1-14-11,EQPT,NEND'
#  'SFP-1-1-12-5,EQPT,NEND' 'MEP#2#43#1' 'r1sr1sl14/ETHLocPort#8#1'
#  'r1sr1sl2/ETHLocPort#16#1' 'r1sr1sl2/INFiberINBand#16'
#  'r1sr1sl3/ETHLocPort#16#1' 'SFP-1-1-5-18,EQPT,NEND'
#  'SFP-1-1-4-18,EQPT,NEND' 'r1sr1sl18/INFiberINBand#9'
#  'r1sr1sl3/INFiberINBand#16' 'r1sr1sl8/ETHLocPort#6#1'
#  'r1sr1sl4/ETHLocPort#18#1' 'r1sr1sl4/INFiberINBand#18'
#  'r1sr1sl5/ETHLocPort#18#1' 'r1sr1sl5/ETHLocPort#9#1'
#  'r1sr1sl4/ETHLocPort#9#1' 'TUSEG-1-1-36,TUSEG,NEND,RCV'
#  'TUSEG-1-1-35,TUSEG,NEND,RCV' 'TUSEG-1-1-48,TUSEG,NEND,RCV'
#  'TUSEG-1-1-47,TUSEG,NEND,RCV' 'r1sr1sl5/INFiberINBand#9'
#  'r1sr1sl4/INFiberINBand#9' 'SFP-1-1-12-18,EQPT,NEND'
#  'SFP-1-1-13-18,EQPT,NEND' 'PP1GEX20-1-1-7,EQPT,NEND'
#  'PP1GEX20-1-1-9,EQPT,NEND' 'MDL-1-1-9,EQPT,NEND'
#  'r1sr1sl7/ETHLocPort#1#1' 'r1sr1sl7/ETHLocPort#2#1'
#  'r1sr1sl7/INFiberINBand#2' 'r1sr1sl7/ETHLocPort#3#1'
#  'r1sr1sl7/INFiberINBand#3' 'r1sr1sl9/ETHLocPort#1#1'
#  'r1sr1sl9/INFiberINBand#1' 'r1sr1sl9/ETHLocPort#2#1'
#  'r1sr1sl9/INFiberINBand#2' 'r1sr1sl9/INFiberINBand#3'
#  'SFP-1-1-13-6,EQPT,NEND' 'SFP-1-1-9-14,EQPT,NEND'
#  'SFP-1-1-7-14,EQPT,NEND' 'r1sr1sl16/ETHLocPort#1#1'
#  'r1sr1sl16/INFiberINBand#1' 'SFP-1-1-12-8,EQPT,NEND'
#  'r1sr1sl12/ETHLocPort#8#1' 'r1sr1sl13/ETHLocPort#8#1'
#  'r1sr1sl13/INFiberINBand#2' 'r1sr1sl12/INFiberINBand#2'
#  'r1sr1sl4/ETHLocPort#8#1' 'r1sr1sl6/ETHLocPort#8#1'
#  'r1sr1sl7/ETHLocPort#17#1' 'r1sr1sl9/ETHLocPort#17#1'
#  'r1sr1sl9/ETHLocPort#14#1' 'r1sr1sl9/INFiberINBand#14'
#  'r1sr1sl9/ETHLocPort#19#1' 'r1sr1sl9/INFiberINBand#19'
#  'r1sr1sl7/ETHLocPort#18#1' 'r1sr1sl7/INFiberINBand#18'
#  'r1sr1sl9/ETHLocPort#18#1' 'r1sr1sl9/INFiberINBand#18'
#  'SFP-1-1-16-13,EQPT,NEND' 'SFP-1-1-17-14,EQPT,NEND'
#  'SFP-1-1-16-14,EQPT,NEND' 'SFP-1-1-13-8,EQPT,NEND'
#  'MT320-1-1-10,EQPT,NEND' 'r1sr1sl17/INFiberINBand#13'
#  'SFP-1-1-7-18,EQPT,NEND' 'SFP-1-1-9-18,EQPT,NEND'
#  'r1sr1sl16/INFiberINBand#3' 'r1sr1sl2/ETHLocPort#6#1'
#  'r1sr1sl12/ETHLocPort#3#1' 'r1sr1sl13/INFiberINBand#3'
#  'r1sr1sl12/INFiberINBand#3' 'SFP-1-1-17-7,EQPT,NEND'
#  'r1sr1sl17/ETHLocPort#7#1' 'r1sr1sl17/INFiberINBand#7' 'MEP#1#3#1'
#  'TUSEG-1-1-139,TUSEG,NEND,RCV' 'r1sr1sl14/ETHLocPort#10#1'
#  'r1sr1sl14/ETHLocPort#11#1' 'TUSEG-1-1-22,TUSEG,NEND,RCV'
#  'TUSEG-1-1-21,TUSEG,NEND,RCV' 'r1sr1sl15/INFiberINBand#10'
#  'r1sr1sl15/INFiberINBand#11' 'r1sr1sl14/INFiberINBand#10'
#  'r1sr1sl14/INFiberINBand#11' 'r1sr1sl17/ETHLocPort#6#1'
#  'SFP-1-1-2-9,EQPT' 'MDL-1-1-5-4,EQPT,NEND' 'SFP-1-1-13-3,EQPT,NEND'
#  'MDL-1-1-12-9,EQPT,NEND' 'SFP-1-1-15-19,EQPT,NEND'
#  'SFP-1-1-13-5,EQPT,NEND' 'SFP-1-1-16-19,EQPT,NEND'
#  'TUSEG-1-1-23,TUSEG,NEND,RCV' 'SFP-1-1-12-1,EQPT,NEND'
#  'SFP-1-1-3-11,EQPT,NEND' 'TUSEG-1-1-59,TUSEG,NEND,RCV'
#  'TUSEG-1-1-60,TUSEG,NEND,RCV' 'MEP#1#12#2' 'r1sr1sl16/ETHLocPort#7#1'
#  'r1sr1sl16/ETHLocPort#3#1' 'r1sr1sl16/ETHLocPort#10#1'
#  'r1sr1sl16/ETHLocPort#4#1' 'r1sr1sl3/ETHLocPort#1#1'
#  'r1sr1sl4/ETHLocPort#12#1' 'r1sr1sl5/ETHLocPort#12#1'
#  'r1sr1sl4/INFiberINBand#12' 'r1sr1sl5/INFiberINBand#12'
#  'MT320-1-1-11,EQPT,NEND' 'MEP#2#39#2' 'r1sr1sl8/ETHLocPort#8#1'
#  'r1sr1sl4/ETHLocPort#4#1' 'TUSEG-1-1-12,TUSEG,NEND,RCV'
#  'TUSEG-1-1-24,TUSEG,NEND,RCV' 'SFP-1-1-13-11,EQPT,NEND'
#  'SFP-1-1-13-12,EQPT,NEND' 'TUSEG-1-1-7,TUSEG,FEND,RCV'
#  'TUSEG-1-1-4,TUSEG,FEND,RCV' 'TUSEG-1-1-37,TUSEG,FEND,RCV'
#  'TUSEG-1-1-9,TUSEG,FEND,RCV' 'TUSEG-1-1-12,TUSEG,FEND,RCV'
#  'TUSEG-1-1-38,TUSEG,FEND,RCV' 'TUSEG-1-1-44,TUSEG,NEND,RCV'
#  'r1sr1sl3/INFiberINBand#1' 'TUSEG-1-1-43,TUSEG,FEND,RCV'
#  'r1sr1sl18/ETHLocPort#18#1' 'r1sr1sl18/INFiberINBand#18' 'MEP#2#4#1'
#  'MEP#2#2#1' 'MEP#2#5#1' 'r1sr1sl12/INFiberINBand#8'
#  'SFP-1-1-17-17,EQPT,NEND' 'SFP-1-1-17-18,EQPT,NEND'
#  'SFP-1-1-19-16,EQPT,NEND' 'SFP-1-1-19-17,EQPT,NEND'
#  'SFP-1-1-19-18,EQPT,NEND' 'SFP-1-1-19-19,EQPT,NEND'
#  'SFP-1-1-17-12,EQPT,NEND' 'SFP-1-1-19-12,EQPT,NEND'
#  'SFP-1-1-19-13,EQPT,NEND' 'SFP-1-1-19-14,EQPT,NEND' 'MEP#2#18#2'
#  'r1sr1sl12/ETHLocPort#5#1' 'SFP-1-1-17-16,EQPT,NEND'
#  'r1sr1sl17/INFiberINBand#16' 'r1sr1sl13/INFiberINBand#8'
#  'r1sr1sl15/ETHLocPort#8#1' 'r1sr1sl6/ETHLocPort#11#1'
#  'TUSEG-1-1-85,TUSEG,NEND,RCV' 'r1sr1sl6/INFiberINBand#11'
#  'r1sr1sl17/ETHLocPort#10#1' 'TUSEG-1-1-118,TUSEG,NEND,RCV'
#  'TUSEG-1-1-117,TUSEG,NEND,RCV' 'r1sr1sl16/INFiberINBand#10'
#  'SFP-1-1-12-4,EQPT,NEND' 'r1sr1sl12/INFiberINBand#4'
#  'r1sr1sl13/ETHLocPort#9#1' 'TUSEG-1-1-25,TUSEG,NEND,RCV'
#  'r1sr1sl15/INFiberINBand#9' 'r1sr1sl19/INFiberINBand#16'
#  'r1sr1sl5/ETHLocPort#2#1' 'r1sr1sl5/INFiberINBand#2'
#  'r1sr1sl4/INFiberINBand#2' 'r1sr1sl13/ETHLocPort#5#1'
#  'SFP-1-1-13-16,EQPT,NEND' 'SFP-1-1-12-16,EQPT,NEND'
#  'r1sr1sl12/ETHLocPort#16#1' 'r1sr1sl5/ETHLocPort#8#1'
#  'SFP-1-1-15-13,EQPT,NEND' 'SFP-1-1-18-14,EQPT,NEND' 'MEP#1#30#1'
#  'r1sr1sl15/ETHLocPort#13#1' 'SFP-1-1-15-18,EQPT,NEND'
#  'TUSEG-1-1-70,TUSEG,NEND,RCV' 'r1sr1sl7/ETHLocPort#12#1'
#  'r1sr1sl6/ETHLocPort#10#1' 'MEP#1#13#2' 'r1sr1sl14/ETHLocPort#14#1'
#  'r1sr1sl14/INFiberINBand#14' 'r1sr1sl2/INFiberINBand#2'
#  'TUSEG-1-1-104,TUSEG,NEND,RCV' 'TUSEG-1-1-103,TUSEG,NEND,RCV'
#  'r1sr1sl7/INFiberINBand#1' 'TUSEG-1-1-104,TUSEG,FEND,RCV'
#  'SFP-1-1-4-6,EQPT,NEND' 'r1sr1sl4/ETHLocPort#6#1'
#  'r1sr1sl18/INFiberINBand#12' 'r1sr1sl5/ETHLocPort#11#1'
#  'SFP-1-1-5-14,EQPT,NEND' 'r1sr1sl14/ETHLocPort#9#1'
#  'r1sr1sl19/ETHLocPort#17#1' 'r1sr1sl18/ETHLocPort#17#1'
#  'r1sr1sl19/INFiberINBand#17' 'r1sr1sl18/INFiberINBand#17' 'MEP#2#32#2'
#  'r1sr1sl14/ETHLocPort#17#1' 'TUSEG-1-1-69,TUSEG,NEND,RCV'
#  'r1sr1sl14/INFiberINBand#17' 'TUSEG-1-1-68,TUSEG,FEND,RCV'
#  'r1sr1sl12/ETHLocPort#17#1' 'r1sr1sl12/INFiberINBand#17'
#  'TUSEG-1-1-26,TUSEG,NEND,RCV' 'MEP#2#7#1' 'MEP#1#2#1'
#  'MDL-1-1-12-4,EQPT,NEND' 'MEP#3#10#1' 'MEP#2#9#1'
#  'r1sr1sl8/ETHLocPort#9#1' 'TUSEG-1-1-21,TUSEG,FEND,RCV'
#  'SFP-1-1-9-8,EQPT,NEND' 'TUSEG-1-1-22,TUSEG,FEND,RCV'
#  'r1sr1sl12/INFiberINBand#9' 'SFP-1-1-17-15,EQPT,NEND'
#  'SFP-1-1-19-15,EQPT,NEND' 'MDL-1-1-19-10,EQPT,NEND'
#  'MDL-1-1-17-10,EQPT,NEND' 'r1sr1sl9/ETHLocPort#7#1'
#  'r1sr1sl9/ETHLocPort#8#1' 'r1sr1sl9/INFiberINBand#8'
#  'r1sr1sl14/INFiberINBand#9' 'r1sr1sl12/ETHLocPort#6#1'
#  'r1sr1sl14/ETHLocPort#6#1' 'r1sr1sl17/ETHLocPort#20#1'
#  'r1sr1sl19/ETHLocPort#20#1' 'MEP#2#16#2' 'r1sr1sl13/ETHLocPort#6#1'
#  'SFP-1-1-19-20,EQPT,NEND' 'r1sr1sl6/ETHLocPort#5#1'
#  'r1sr1sl14/ETHLocPort#2#1' 'r1sr1sl14/ETHLocPort#1#1'
#  'r1sr1sl19/INFiberINBand#20' 'r1sr1sl17/INFiberINBand#20'
#  'TUSEG-1-1-72,TUSEG,NEND,RCV' 'MEP#1#16#2' 'r1sr1sl8/ETHLocPort#16#1'
#  'r1sr1sl15/ETHLocPort#2#1' 'SFP-1-1-17-20,EQPT,NEND'
#  'TUSEG-1-1-71,TUSEG,NEND,RCV' 'r1sr1sl17/INFiberINBand#17'
#  'r1sr1sl9/ETHLocPort#13#1' 'r1sr1sl9/INFiberINBand#13'
#  'SFP-1-1-3-1,EQPT,NEND' 'SFP-1-1-5-11,EQPT,NEND'
#  'TUSEG-1-1-105,TUSEG,NEND,RCV' 'r1sr1sl15/ETHLocPort#1#1'
#  'TUSEG-1-1-106,TUSEG,NEND,RCV' 'MEP#2#9#2' 'r1sr1sl15/INFiberINBand#1'
#  'r1sr1sl7/ETHLocPort#4#1' 'r1sr1sl7/INFiberINBand#6'
#  'r1sr1sl7/ETHLocPort#7#1' 'r1sr1sl7/INFiberINBand#7'
#  'r1sr1sl9/ETHLocPort#4#1' 'r1sr1sl9/INFiberINBand#6'
#  'r1sr1sl9/INFiberINBand#7' 'SFP-1-1-13-10,EQPT,NEND'
#  'SFP-1-1-15-10,EQPT,NEND' 'r1sr1sl14/ETHLocPort#7#1' 'MEP#1#10#2'
#  'SFP-1-1-17-19,EQPT,NEND' 'TUSEG-1-1-16,TUSEG,FEND,RCV' 'MEP#2#14#1'
#  'r1sr1sl13/INFiberINBand#9' 'MEP#1#26#2' 'r1sr1sl15/ETHLocPort#6#1'
#  'TUSEG-1-1-51,TUSEG,NEND,RCV' 'r1sr1sl15/INFiberINBand#6'
#  'r1sr1sl14/INFiberINBand#6' 'r1sr1sl7/ETHLocPort#15#1'
#  'r1sr1sl9/ETHLocPort#15#1' 'TUSEG-1-1-97,TUSEG,FEND,RCV'
#  'r1sr1sl8/INFiberINBand#2' 'MEP#1#23#2' 'r1sr1sl18/ETHLocPort#11#1'
#  'r1sr1sl3/INFiberINBand#9' 'r1sr1sl13/ETHLocPort#7#1'
#  'r1sr1sl19/ETHLocPort#15#1' 'TUSEG-1-1-55,TUSEG,NEND,RCV' 'MEP#1#51#2'
#  'TUSEG-1-1-56,TUSEG,NEND,RCV' 'r1sr1sl19/INFiberINBand#15'
#  'r1sr1sl17/INFiberINBand#15' 'TUSEG-1-1-56,TUSEG,FEND,RCV' 'MEP#1#42#1'
#  'TUSEG-1-1-6,TUSEG,RCV' 'SyncRef#2' 'TUSEG-1-1-4,TUSEG,RCV'
#  'TUSEG-1-1-111,TUSEG,NEND,RCV' 'TUSEG-1-1-112,TUSEG,NEND,RCV'
#  'r1sr1sl6/ETHLocPort#7#1' 'r1sr1sl6/ETHLocPort#3#1'
#  'r1sr1sl6/ETHLocPort#6#1' 'r1sr1sl8/ETHLocPort#5#1'
#  'r1sr1sl8/ETHLocPort#10#1' 'r1sr1sl8/ETHLocPort#4#1'
#  'r1sr1sl6/ETHLocPort#4#1' 'r1sr1sl6/ETHLocPort#9#1']
# --------------------------------------------------------------------------------------------
# ### slot ###
# train unique값 --> [ 3.  1.  2.  4.  5.  7.  6. nan 10.  0.  9.  8.]
# test unique값 --> [16. 13.  2. nan 19.  1. 17.  7.  3. 15. 11.  8.  6. 12.  5.  4. 18. 14.
#   0.  9. 10.]
# --------------------------------------------------------------------------------------------
# ### port ###
# train unique값 --> [ 1.  2. nan  4.  3.  5.  6.  7.  8.  9. 10.]
# test unique값 --> [15. 20.  1. nan 16. 12.  2. 18. 14. 17. 39.  8. 11. 19.  6.  7.  9. 10.
#  32. 33.  4.  3.  5. 13. 34. 40. 37. 35. 36. 31. 29. 24. 27. 26. 28. 25.
#  38. 22. 21. 30. 23.]
# --------------------------------------------------------------------------------------------
# ### sva ###
# train unique값 --> ['NSA']
# test unique값 --> ['NSA' 'SA']
# --------------------------------------------------------------------------------------------
# ### root_cause_domain ###
# train unique값 --> ['A']
# test unique값 --> ['C' 'B' 'A']
# --------------------------------------------------------------------------------------------

# %%
# target 비율 확인
train_org['root_cause_type'].value_counts()/len(train_org['root_cause_type'])
# Out:
# LinkCut      0.868269
# PowerFail    0.077880
# UnitFail     0.053851
# Name: root_cause_type, dtype: float64

# %% [markdown]
# # **Data Cleansing & Pre-Processing**

# %% [markdown]
# # 1. alarmmsg의 Data Cleansing

# %% [markdown]
# * Data Cleansing을 위한 함수

# %%
# '_' -> '-'
def preprocess_hyphen(text):
    return text.replace('_', '-')

# %%
# 소문자 -> 대문자
def preprocess_uppercase(text):
    return text.upper()

# %%
# 공백 -> ‘-’
def preprocess_blank(text):
    return text.replace(' ', '-')

# %%
# 공백 제거
def preprocess_blank_remove(text):
    return text.replace(' ', '')

# %%
# ‘ :’ 제거
def preprocess_remove_colon(text):
    return text.replace(':', '')

# %%
# 축약어 변환
def preprocess_tolong(text, replacements_msg):

    processed_text = text
    for key, value in replacements_msg.items():
        processed_text = processed_text.replace(key, value)

    return processed_text

# %% [markdown]
# * train 데이터의 A제조사

# %%
alarmmsg_unique = train_org['alarmmsg_original'].unique()
msg_uniq = pd.DataFrame(alarmmsg_unique, columns = ['alarmmsg_not_processed'])
msg_uniq
# Out:
#    alarmmsg_not_processed
# 0                 ETH-ERR
# 1                 OPT-LOS
# 2                DCC-FAIL
# 3                 LSP-LOC
# 4       ETH-NO-RX-TRAFFIC
# 5             OPT-PWR-LOW
# 6                PSU-FAIL
# 7           ETH-LINK-FAIL
# 8       AUTONEGO_MISMATCH
# 9         TDM-PW-RMT_FAIL
# 10             OPT-REMOVE
# 11           TRK-CONN-MIS
# 12     ProtectionSwitched
# 13             NVRAM-FAIL
# 14                 PW-LOC
# 15               BATT-LOW
# 16                BOOTING
# 17      ETH-NO-TX-TRAFFIC
# 18              Restarted
# 19            OS_MISMATCH
# 20               UNIT-REM
# 21             TDM-PW-LOF
# 22           FAN-48V-FAIL
# 23               FAN-FAIL
# 24               48V-FAIL
# 25           PortShutdown
# 26                QL_FAIL
# 27          UNIT-IPC-FAIL
# 28       LINK_FAIL_MANUAL
# 29                PSU-REM
# 30                OPT-MIS

# %%
# preprocess_hyphen 함수 사용
msg_uniq['alarmmsg_hyphen'] = msg_uniq['alarmmsg_not_processed'].apply(preprocess_hyphen)
msg_uniq
# Out:
#    alarmmsg_not_processed     alarmmsg_hyphen
# 0                 ETH-ERR             ETH-ERR
# 1                 OPT-LOS             OPT-LOS
# 2                DCC-FAIL            DCC-FAIL
# 3                 LSP-LOC             LSP-LOC
# 4       ETH-NO-RX-TRAFFIC   ETH-NO-RX-TRAFFIC
# 5             OPT-PWR-LOW         OPT-PWR-LOW
# 6                PSU-FAIL            PSU-FAIL
# 7           ETH-LINK-FAIL       ETH-LINK-FAIL
# 8       AUTONEGO_MISMATCH   AUTONEGO-MISMATCH
# 9         TDM-PW-RMT_FAIL     TDM-PW-RMT-FAIL
# 10             OPT-REMOVE          OPT-REMOVE
# 11           TRK-CONN-MIS        TRK-CONN-MIS
# 12     ProtectionSwitched  ProtectionSwitched
# 13             NVRAM-FAIL          NVRAM-FAIL
# 14                 PW-LOC              PW-LOC
# 15               BATT-LOW            BATT-LOW
# 16                BOOTING             BOOTING
# 17      ETH-NO-TX-TRAFFIC   ETH-NO-TX-TRAFFIC
# 18              Restarted           Restarted
# 19            OS_MISMATCH         OS-MISMATCH
# 20               UNIT-REM            UNIT-REM
# 21             TDM-PW-LOF          TDM-PW-LOF
# 22           FAN-48V-FAIL        FAN-48V-FAIL
# 23               FAN-FAIL            FAN-FAIL
# 24               48V-FAIL            48V-FAIL
# 25           PortShutdown        PortShutdown
# 26                QL_FAIL             QL-FAIL
# 27          UNIT-IPC-FAIL       UNIT-IPC-FAIL
# 28       LINK_FAIL_MANUAL    LINK-FAIL-MANUAL
# 29                PSU-REM             PSU-REM
# 30                OPT-MIS             OPT-MIS

# %%
# preprocess_uppercase 함수 사용
msg_uniq['alarmmsg_uppercase'] = msg_uniq['alarmmsg_hyphen'].apply(preprocess_uppercase)
msg_uniq
# Out:
#    alarmmsg_not_processed     alarmmsg_hyphen  alarmmsg_uppercase
# 0                 ETH-ERR             ETH-ERR             ETH-ERR
# 1                 OPT-LOS             OPT-LOS             OPT-LOS
# 2                DCC-FAIL            DCC-FAIL            DCC-FAIL
# 3                 LSP-LOC             LSP-LOC             LSP-LOC
# 4       ETH-NO-RX-TRAFFIC   ETH-NO-RX-TRAFFIC   ETH-NO-RX-TRAFFIC
# 5             OPT-PWR-LOW         OPT-PWR-LOW         OPT-PWR-LOW
# 6                PSU-FAIL            PSU-FAIL            PSU-FAIL
# 7           ETH-LINK-FAIL       ETH-LINK-FAIL       ETH-LINK-FAIL
# 8       AUTONEGO_MISMATCH   AUTONEGO-MISMATCH   AUTONEGO-MISMATCH
# 9         TDM-PW-RMT_FAIL     TDM-PW-RMT-FAIL     TDM-PW-RMT-FAIL
# 10             OPT-REMOVE          OPT-REMOVE          OPT-REMOVE
# 11           TRK-CONN-MIS        TRK-CONN-MIS        TRK-CONN-MIS
# 12     ProtectionSwitched  ProtectionSwitched  PROTECTIONSWITCHED
# 13             NVRAM-FAIL          NVRAM-FAIL          NVRAM-FAIL
# 14                 PW-LOC              PW-LOC              PW-LOC
# 15               BATT-LOW            BATT-LOW            BATT-LOW
# 16                BOOTING             BOOTING             BOOTING
# 17      ETH-NO-TX-TRAFFIC   ETH-NO-TX-TRAFFIC   ETH-NO-TX-TRAFFIC
# 18              Restarted           Restarted           RESTARTED
# 19            OS_MISMATCH         OS-MISMATCH         OS-MISMATCH
# 20               UNIT-REM            UNIT-REM            UNIT-REM
# 21             TDM-PW-LOF          TDM-PW-LOF          TDM-PW-LOF
# 22           FAN-48V-FAIL        FAN-48V-FAIL        FAN-48V-FAIL
# 23               FAN-FAIL            FAN-FAIL            FAN-FAIL
# 24               48V-FAIL            48V-FAIL            48V-FAIL
# 25           PortShutdown        PortShutdown        PORTSHUTDOWN
# 26                QL_FAIL             QL-FAIL             QL-FAIL
# 27          UNIT-IPC-FAIL       UNIT-IPC-FAIL       UNIT-IPC-FAIL
# 28       LINK_FAIL_MANUAL    LINK-FAIL-MANUAL    LINK-FAIL-MANUAL
# 29                PSU-REM             PSU-REM             PSU-REM
# 30                OPT-MIS             OPT-MIS             OPT-MIS

# %%
# A 제조사의 축약어 변환을 위한 딕셔너리 형태의 단어사전
replacements = {
    'ETH' : 'ETHERNET',
    'ERR' : 'ERROR',
    'IT-REM' : 'IT-REMOVE',
    'U-REM' : 'U-REMOVE',
    'RX' : 'RECEIVE',
    'TX-' : 'TRANSMISSION-',
    'BATT' : 'BATTERY',
    'QL' : 'QUALITY',
    'PWR' : 'POWER',
    'PW' : 'PSEUDOWIRE',
    '-LOS' : '-LOSS-OF-SIGNAL',
    'CONN' : 'CONNECT',
    '-LOC' : '-LOSS-OF-CONNECT',
    'OS-' : 'OPERATING-SYSTEM-',
    'LOF' : 'LOSS-OF-PACKET',
    'PSU' : 'POWER-SUPPLY-UNIT',
    'DCC' : 'DATA-COMMUNICATE-CHANNEL',
    'RMT' : 'REMOTE',
    'TDM' : 'TIME-DIVISION-MULTIPLEX',
    'OPT' : 'OPTICAL',
    'NVRAM' : 'NON-VOLATILE-RANDOM-ACCESS-MEMORY',
    'IPC' : 'INTEGRATED-PACKET-CONTROL',
    'T-MIS' : 'T-MISMATCH',
    'L-MIS' : 'L-MISMATCH',
    'TRK' : 'TRACK',
    'LSP' : 'LABEL-SWITCHED-PATH',
    'AUTONEGO' : 'AUTO-NEGOTIATION',
    'PROTECTIONSWITCHED' : 'PROTECTION-SWITCHED',
    'PORTSHUTDOWN' : 'PORT-SHUTDOWN',
    'FAN-48V-FAIL' : '48V-FAIL'
    }

# %%
# preprocess_tolong, replacements_msg = replacements 함수 사용
msg_uniq['alarmmsg_tolong'] = msg_uniq['alarmmsg_uppercase'].apply(preprocess_tolong, replacements_msg = replacements)
msg_uniq
# Out:
#    alarmmsg_not_processed     alarmmsg_hyphen  alarmmsg_uppercase  \
# 0                 ETH-ERR             ETH-ERR             ETH-ERR
# 1                 OPT-LOS             OPT-LOS             OPT-LOS
# 2                DCC-FAIL            DCC-FAIL            DCC-FAIL
# 3                 LSP-LOC             LSP-LOC             LSP-LOC
# 4       ETH-NO-RX-TRAFFIC   ETH-NO-RX-TRAFFIC   ETH-NO-RX-TRAFFIC
# 5             OPT-PWR-LOW         OPT-PWR-LOW         OPT-PWR-LOW
# 6                PSU-FAIL            PSU-FAIL            PSU-FAIL
# 7           ETH-LINK-FAIL       ETH-LINK-FAIL       ETH-LINK-FAIL
# 8       AUTONEGO_MISMATCH   AUTONEGO-MISMATCH   AUTONEGO-MISMATCH
# 9         TDM-PW-RMT_FAIL     TDM-PW-RMT-FAIL     TDM-PW-RMT-FAIL
# 10             OPT-REMOVE          OPT-REMOVE          OPT-REMOVE
# 11           TRK-CONN-MIS        TRK-CONN-MIS        TRK-CONN-MIS
# 12     ProtectionSwitched  ProtectionSwitched  PROTECTIONSWITCHED
# 13             NVRAM-FAIL          NVRAM-FAIL          NVRAM-FAIL
# 14                 PW-LOC              PW-LOC              PW-LOC
# 15               BATT-LOW            BATT-LOW            BATT-LOW
# 16                BOOTING             BOOTING             BOOTING
# 17      ETH-NO-TX-TRAFFIC   ETH-NO-TX-TRAFFIC   ETH-NO-TX-TRAFFIC
# 18              Restarted           Restarted           RESTARTED
# 19            OS_MISMATCH         OS-MISMATCH         OS-MISMATCH
# 20               UNIT-REM            UNIT-REM            UNIT-REM
# 21             TDM-PW-LOF          TDM-PW-LOF          TDM-PW-LOF
# 22           FAN-48V-FAIL        FAN-48V-FAIL        FAN-48V-FAIL
# 23               FAN-FAIL            FAN-FAIL            FAN-FAIL
# 24               48V-FAIL            48V-FAIL            48V-FAIL
# 25           PortShutdown        PortShutdown        PORTSHUTDOWN
# 26                QL_FAIL             QL-FAIL             QL-FAIL
# 27          UNIT-IPC-FAIL       UNIT-IPC-FAIL       UNIT-IPC-FAIL
# 28       LINK_FAIL_MANUAL    LINK-FAIL-MANUAL    LINK-FAIL-MANUAL
# 29                PSU-REM             PSU-REM             PSU-REM
# 30                OPT-MIS             OPT-MIS             OPT-MIS
#
#                                       alarmmsg_tolong
# 0                                      ETHERNET-ERROR
# 1                              OPTICAL-LOSS-OF-SIGNAL
# 2                       DATA-COMMUNICATE-CHANNEL-FAIL
# 3                 LABEL-SWITCHED-PATH-LOSS-OF-CONNECT
# 4                         ETHERNET-NO-RECEIVE-TRAFFIC
# 5                                   OPTICAL-POWER-LOW
# 6                              POWER-SUPPLY-UNIT-FAIL
# 7                                  ETHERNET-LINK-FAIL
# 8                           AUTO-NEGOTIATION-MISMATCH
# 9      TIME-DIVISION-MULTIPLEX-PSEUDOWIRE-REMOTE-FAIL
# 10                                     OPTICAL-REMOVE
# 11                             TRACK-CONNECT-MISMATCH
# 12                                PROTECTION-SWITCHED
# 13             NON-VOLATILE-RANDOM-ACCESS-MEMORY-FAIL
# 14                         PSEUDOWIRE-LOSS-OF-CONNECT
# 15                                        BATTERY-LOW
# 16                                            BOOTING
# 17                   ETHERNET-NO-TRANSMISSION-TRAFFIC
# 18                                          RESTARTED
# 19                          OPERATING-SYSTEM-MISMATCH
# 20                                        UNIT-REMOVE
# 21  TIME-DIVISION-MULTIPLEX-PSEUDOWIRE-LOSS-OF-PACKET
# 22                                           48V-FAIL
# 23                                           FAN-FAIL
# 24                                           48V-FAIL
# 25                                      PORT-SHUTDOWN
# 26                                       QUALITY-FAIL
# 27                UNIT-INTEGRATED-PACKET-CONTROL-FAIL
# 28                                   LINK-FAIL-MANUAL
# 29                           POWER-SUPPLY-UNIT-REMOVE
# 30                                   OPTICAL-MISMATCH

# %%
# 원형 변환 전 후 비교 데이터프레임
final_train_msg = msg_uniq[['alarmmsg_not_processed', 'alarmmsg_tolong']]
final_train_msg
# Out:
#    alarmmsg_not_processed                                    alarmmsg_tolong
# 0                 ETH-ERR                                     ETHERNET-ERROR
# 1                 OPT-LOS                             OPTICAL-LOSS-OF-SIGNAL
# 2                DCC-FAIL                      DATA-COMMUNICATE-CHANNEL-FAIL
# 3                 LSP-LOC                LABEL-SWITCHED-PATH-LOSS-OF-CONNECT
# 4       ETH-NO-RX-TRAFFIC                        ETHERNET-NO-RECEIVE-TRAFFIC
# 5             OPT-PWR-LOW                                  OPTICAL-POWER-LOW
# 6                PSU-FAIL                             POWER-SUPPLY-UNIT-FAIL
# 7           ETH-LINK-FAIL                                 ETHERNET-LINK-FAIL
# 8       AUTONEGO_MISMATCH                          AUTO-NEGOTIATION-MISMATCH
# 9         TDM-PW-RMT_FAIL     TIME-DIVISION-MULTIPLEX-PSEUDOWIRE-REMOTE-FAIL
# 10             OPT-REMOVE                                     OPTICAL-REMOVE
# 11           TRK-CONN-MIS                             TRACK-CONNECT-MISMATCH
# 12     ProtectionSwitched                                PROTECTION-SWITCHED
# 13             NVRAM-FAIL             NON-VOLATILE-RANDOM-ACCESS-MEMORY-FAIL
# 14                 PW-LOC                         PSEUDOWIRE-LOSS-OF-CONNECT
# 15               BATT-LOW                                        BATTERY-LOW
# 16                BOOTING                                            BOOTING
# 17      ETH-NO-TX-TRAFFIC                   ETHERNET-NO-TRANSMISSION-TRAFFIC
# 18              Restarted                                          RESTARTED
# 19            OS_MISMATCH                          OPERATING-SYSTEM-MISMATCH
# 20               UNIT-REM                                        UNIT-REMOVE
# 21             TDM-PW-LOF  TIME-DIVISION-MULTIPLEX-PSEUDOWIRE-LOSS-OF-PACKET
# 22           FAN-48V-FAIL                                           48V-FAIL
# 23               FAN-FAIL                                           FAN-FAIL
# 24               48V-FAIL                                           48V-FAIL
# 25           PortShutdown                                      PORT-SHUTDOWN
# 26                QL_FAIL                                       QUALITY-FAIL
# 27          UNIT-IPC-FAIL                UNIT-INTEGRATED-PACKET-CONTROL-FAIL
# 28       LINK_FAIL_MANUAL                                   LINK-FAIL-MANUAL
# 29                PSU-REM                           POWER-SUPPLY-UNIT-REMOVE
# 30                OPT-MIS                                   OPTICAL-MISMATCH

# %%
# train_org(원데이터)의 알람메시지를 Data Cleansing된 알람메시지로 대체
train_change_msg = pd.merge(train_org, final_train_msg, how = 'inner',left_on = 'alarmmsg_original', right_on = 'alarmmsg_not_processed')
train_change_msg = train_change_msg.drop(['alarmmsg_original', 'alarmmsg_not_processed'], axis = 1)
train_change_msg
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 'alarmtime', 'alarmno' 재정렬
train_change_msg = train_change_msg.sort_values(['alarmtime', 'alarmno'])

# %%
# 최종 데이터프레임
change_col = ['ticketno', 'alarmno', 'alarmtime', 'alarmlevel', 'alarmmsg_tolong','site', 'sysname', 'unit', 'slot', 'port', 'sva', 'root_cause_domain','root_cause_type']


train_change_msg = train_change_msg[change_col]
train_change_msg.rename(columns = {'alarmmsg_tolong' : 'alarmmsg_original'}, inplace = True)
train_change_msg.head()
# Out:
#      ticketno        alarmno                  alarmtime  alarmlevel  \
# 0  21122633.0  1669820428245  2022-12-01 00:02:24+09:00           5
# 1  21122633.0  1669821318728  2022-12-01 00:17:15+09:00           5
# 2  21122633.0  1669822214832  2022-12-01 00:32:11+09:00           5
# 3  21122633.0  1669823114128  2022-12-01 00:47:10+09:00           5
# 4  21122633.0  1669824028082  2022-12-01 01:02:24+09:00           5
#
#   alarmmsg_original  site sysname  unit  slot  port  sva root_cause_domain  \
# 0    ETHERNET-ERROR  ACEN    acnt  EQPT   3.0   1.0  NSA                 A
# 1    ETHERNET-ERROR  ACEN    acnt  EQPT   3.0   1.0  NSA                 A
# 2    ETHERNET-ERROR  ACEN    acnt  EQPT   3.0   1.0  NSA                 A
# 3    ETHERNET-ERROR  ACEN    acnt  EQPT   3.0   1.0  NSA                 A
# 4    ETHERNET-ERROR  ACEN    acnt  EQPT   3.0   1.0  NSA                 A
#
#   root_cause_type
# 0         LinkCut
# 1         LinkCut
# 2         LinkCut
# 3         LinkCut
# 4         LinkCut

# %% [markdown]
# * test 데이터 Data Cleansing을 위한 데이터프레임 생성

# %%
# 제조사별 unique한 알람메시지
msg_test = test_org[['root_cause_domain', 'alarmlevel', 'alarmmsg_original']].drop_duplicates().sort_values(['root_cause_domain', 'alarmlevel'])
msg_test
# Out:
#       root_cause_domain  alarmlevel                        alarmmsg_original
# 12494                 A           3                                  ETH-ERR
# 1568                  A           4                                 PSU-FAIL
# 3042                  A           4                                  BOOTING
# 460                   A           5                        ETH-NO-TX-TRAFFIC
# 1453                  A           5                                  LSP-LOC
# 1917                  A           5                              OPT-PWR-LOW
# 5965                  A           5                        ETH-NO-RX-TRAFFIC
# 5969                  A           5                                 DCC-FAIL
# 6125                  A           5                                  ETH-ERR
# 6506                  A           5                             OPT-PWR-HIGH
# 6524                  A           5                        AUTONEGO_MISMATCH
# 7663                  A           5                                   PW-LOC
# 13109                 A           5                          TDM-PW-RMT_FAIL
# 13615                 A           5                                  QL_FAIL
# 14499                 A           5                                 48V-FAIL
# 39                    A           7                                  OPT-LOS
# 100                   A           7                            ETH-LINK-FAIL
# 2263                  A           7                               OPT-REMOVE
# 7228                  A           7                             TRK-CONN-MIS
# 7883                  A           7                                  OPT-MIS
# 13427                 A           7                         LINK_FAIL_MANUAL
# 2                     B           4                          DDM_RX_PWR_HIGH
# 8                     B           4                           DDM_RX_PWR_LOW
# 396                   B           4                        ETHER_TCA_DROP_1D
# 2338                  B           4                        ETHER_TCA_CRC_15M
# 2339                  B           4                         ETHER_TCA_CRC_1D
# 2469                  B           4                           ETHER_PORT_CRC
# 2612                  B           4                             BATTERY_FAIL
# 2864                  B           4                       ETHER_TCA_DROP_15M
# 6801                  B           4                          DC_INPUT_A_FAIL
# 9306                  B           4                                 DCN_FAIL
# 10970                 B           4                    UNIT_INIT (BY INSLOT)
# 11091                 B           4                     UNIT_INIT (BY RESET)
# 11092                 B           4                                 UNIT_OUT
# 11192                 B           4                       MODULE_OUT ( SFP )
# 11325                 B           4                                 STM1_LOS
# 27306                 B           4                              MEP_LSP_RDI
# 3                     B           5                            BATT_ENV_FAIL
# 16                    B           5                              MEP_LSP_LOC
# 213                   B           5                              MEP_PWE_LOC
# 1197                  B           5                              MEP_PWE_CSF
# 5844                  B           5                                 DCN_FAIL
# 7553                  B           5                              MEP_LSP_RDI
# 12927                 B           5                             SYS_TEMP_LOW
# 33879                 B           5                                  CEP_AIS
# 150                   B           7            ETHER_LINK_DOWN (LOCAL_FAULT)
# 152                   B           7                   ETHER_LINK_DOWN (LLCF)
# 1316                  B           7                                UNIT_FAIL
# 1575                  B           7                    ETHER_LINK_DOWN (LOS)
# 6727                  B           7                      MODULE_OUT ( SFP+ )
# 6732                  B           7                       MODULE_OUT ( SFP )
# 10932                 B           7           ETHER_LINK_DOWN (REMOTE_FAULT)
# 11216                 B           7                                 STM1_LOS
# 14459                 B           7                                 UNIT_OUT
# 19845                 B           7                     UNIT_INIT (BY RESET)
# 10                    C           3                 Remote Defect Indication
# 165                   C           4                                 PPP Fail
# 309                   C           4                                  Rx Fail
# 395                   C           4               Input Power Degrade Defect
# 4399                  C           4                   OAM Loss Of Continuity
# 4432                  C           4                                  OAM RDI
# 6414                  C           4                         Improper Removal
# 6717                  C           4                    OAMLoss Of Continuity
# 7378                  C           4              Manual (Management) Removal
# 7765                  C           4                          Procedure Error
# 13463                 C           4         Abnormal Condition: Laser Forced
# 13955                 C           4    IOC Payload-Links with Matrix Failure
# 0                     C           5                           Loss Of Signal
# 17                    C           5               Input Power Degrade Defect
# 160                   C           5                    Server Signal Failure
# 407                   C           5                       Client Signal Fail
# 427                   C           5                     Loss of Connectivity
# 428                   C           5                           Unexpected MEG
# 1594                  C           5                   OAM Loss Of Continuity
# 4846                  C           5                         Hardware failure
# 6424                  C           5                         Improper Removal
# 6593                  C           5          Underlying Resource Unavailable
# 8100                  C           5              Manual (Management) Removal
# 8112                  C           5                          Procedure Error
# 15337                 C           5                  Remote Fault Indication
# 36699                 C           5        Synchronization Signal Fail Raise
# 249                   C           7                      House Keeping Alarm
# 1893                  C           7  NE Not Reachable Via Primary Mng Interf
# 1907                  C           7                           Node Isolation
# 1908                  C           7      NE Not Reach Via Primary Mng Interf

# %% [markdown]
# * test 데이터의 A제조사

# %%
# test데이터의 A제조사만 추출
msg_A = msg_test.loc[msg_test['root_cause_domain'] == 'A', :]
msg_A
# Out:
#       root_cause_domain  alarmlevel  alarmmsg_original
# 12494                 A           3            ETH-ERR
# 1568                  A           4           PSU-FAIL
# 3042                  A           4            BOOTING
# 460                   A           5  ETH-NO-TX-TRAFFIC
# 1453                  A           5            LSP-LOC
# 1917                  A           5        OPT-PWR-LOW
# 5965                  A           5  ETH-NO-RX-TRAFFIC
# 5969                  A           5           DCC-FAIL
# 6125                  A           5            ETH-ERR
# 6506                  A           5       OPT-PWR-HIGH
# 6524                  A           5  AUTONEGO_MISMATCH
# 7663                  A           5             PW-LOC
# 13109                 A           5    TDM-PW-RMT_FAIL
# 13615                 A           5            QL_FAIL
# 14499                 A           5           48V-FAIL
# 39                    A           7            OPT-LOS
# 100                   A           7      ETH-LINK-FAIL
# 2263                  A           7         OPT-REMOVE
# 7228                  A           7       TRK-CONN-MIS
# 7883                  A           7            OPT-MIS
# 13427                 A           7   LINK_FAIL_MANUAL

# %%
# A제조사의 Data Cleansing 전 알람메시지 모은 데이터프레임
A_msg_uniq = pd.DataFrame(msg_A['alarmmsg_original'].unique(), columns = ['Amsg_not_processed'])
A_msg_uniq
# Out:
#    Amsg_not_processed
# 0             ETH-ERR
# 1            PSU-FAIL
# 2             BOOTING
# 3   ETH-NO-TX-TRAFFIC
# 4             LSP-LOC
# 5         OPT-PWR-LOW
# 6   ETH-NO-RX-TRAFFIC
# 7            DCC-FAIL
# 8        OPT-PWR-HIGH
# 9   AUTONEGO_MISMATCH
# 10             PW-LOC
# 11    TDM-PW-RMT_FAIL
# 12            QL_FAIL
# 13           48V-FAIL
# 14            OPT-LOS
# 15      ETH-LINK-FAIL
# 16         OPT-REMOVE
# 17       TRK-CONN-MIS
# 18            OPT-MIS
# 19   LINK_FAIL_MANUAL

# %%
# preprocess_hyphen 함수 사용
A_msg_uniq['Amsg_hyphen'] = A_msg_uniq['Amsg_not_processed'].apply(preprocess_hyphen)
A_msg_uniq
# Out:
#    Amsg_not_processed        Amsg_hyphen
# 0             ETH-ERR            ETH-ERR
# 1            PSU-FAIL           PSU-FAIL
# 2             BOOTING            BOOTING
# 3   ETH-NO-TX-TRAFFIC  ETH-NO-TX-TRAFFIC
# 4             LSP-LOC            LSP-LOC
# 5         OPT-PWR-LOW        OPT-PWR-LOW
# 6   ETH-NO-RX-TRAFFIC  ETH-NO-RX-TRAFFIC
# 7            DCC-FAIL           DCC-FAIL
# 8        OPT-PWR-HIGH       OPT-PWR-HIGH
# 9   AUTONEGO_MISMATCH  AUTONEGO-MISMATCH
# 10             PW-LOC             PW-LOC
# 11    TDM-PW-RMT_FAIL    TDM-PW-RMT-FAIL
# 12            QL_FAIL            QL-FAIL
# 13           48V-FAIL           48V-FAIL
# 14            OPT-LOS            OPT-LOS
# 15      ETH-LINK-FAIL      ETH-LINK-FAIL
# 16         OPT-REMOVE         OPT-REMOVE
# 17       TRK-CONN-MIS       TRK-CONN-MIS
# 18            OPT-MIS            OPT-MIS
# 19   LINK_FAIL_MANUAL   LINK-FAIL-MANUAL

# %%
# preprocess_blank 함수 사용
A_msg_uniq['Amsg_blank'] = A_msg_uniq['Amsg_hyphen'].apply(preprocess_blank)
A_msg_uniq
# Out:
#    Amsg_not_processed        Amsg_hyphen         Amsg_blank
# 0             ETH-ERR            ETH-ERR            ETH-ERR
# 1            PSU-FAIL           PSU-FAIL           PSU-FAIL
# 2             BOOTING            BOOTING            BOOTING
# 3   ETH-NO-TX-TRAFFIC  ETH-NO-TX-TRAFFIC  ETH-NO-TX-TRAFFIC
# 4             LSP-LOC            LSP-LOC            LSP-LOC
# 5         OPT-PWR-LOW        OPT-PWR-LOW        OPT-PWR-LOW
# 6   ETH-NO-RX-TRAFFIC  ETH-NO-RX-TRAFFIC  ETH-NO-RX-TRAFFIC
# 7            DCC-FAIL           DCC-FAIL           DCC-FAIL
# 8        OPT-PWR-HIGH       OPT-PWR-HIGH       OPT-PWR-HIGH
# 9   AUTONEGO_MISMATCH  AUTONEGO-MISMATCH  AUTONEGO-MISMATCH
# 10             PW-LOC             PW-LOC             PW-LOC
# 11    TDM-PW-RMT_FAIL    TDM-PW-RMT-FAIL    TDM-PW-RMT-FAIL
# 12            QL_FAIL            QL-FAIL            QL-FAIL
# 13           48V-FAIL           48V-FAIL           48V-FAIL
# 14            OPT-LOS            OPT-LOS            OPT-LOS
# 15      ETH-LINK-FAIL      ETH-LINK-FAIL      ETH-LINK-FAIL
# 16         OPT-REMOVE         OPT-REMOVE         OPT-REMOVE
# 17       TRK-CONN-MIS       TRK-CONN-MIS       TRK-CONN-MIS
# 18            OPT-MIS            OPT-MIS            OPT-MIS
# 19   LINK_FAIL_MANUAL   LINK-FAIL-MANUAL   LINK-FAIL-MANUAL

# %%
# preprocess_uppercase 함수 사용
A_msg_uniq['Amsg_uppercase'] = A_msg_uniq['Amsg_blank'].apply(preprocess_uppercase)
A_msg_uniq
# Out:
#    Amsg_not_processed        Amsg_hyphen         Amsg_blank     Amsg_uppercase
# 0             ETH-ERR            ETH-ERR            ETH-ERR            ETH-ERR
# 1            PSU-FAIL           PSU-FAIL           PSU-FAIL           PSU-FAIL
# 2             BOOTING            BOOTING            BOOTING            BOOTING
# 3   ETH-NO-TX-TRAFFIC  ETH-NO-TX-TRAFFIC  ETH-NO-TX-TRAFFIC  ETH-NO-TX-TRAFFIC
# 4             LSP-LOC            LSP-LOC            LSP-LOC            LSP-LOC
# 5         OPT-PWR-LOW        OPT-PWR-LOW        OPT-PWR-LOW        OPT-PWR-LOW
# 6   ETH-NO-RX-TRAFFIC  ETH-NO-RX-TRAFFIC  ETH-NO-RX-TRAFFIC  ETH-NO-RX-TRAFFIC
# 7            DCC-FAIL           DCC-FAIL           DCC-FAIL           DCC-FAIL
# 8        OPT-PWR-HIGH       OPT-PWR-HIGH       OPT-PWR-HIGH       OPT-PWR-HIGH
# 9   AUTONEGO_MISMATCH  AUTONEGO-MISMATCH  AUTONEGO-MISMATCH  AUTONEGO-MISMATCH
# 10             PW-LOC             PW-LOC             PW-LOC             PW-LOC
# 11    TDM-PW-RMT_FAIL    TDM-PW-RMT-FAIL    TDM-PW-RMT-FAIL    TDM-PW-RMT-FAIL
# 12            QL_FAIL            QL-FAIL            QL-FAIL            QL-FAIL
# 13           48V-FAIL           48V-FAIL           48V-FAIL           48V-FAIL
# 14            OPT-LOS            OPT-LOS            OPT-LOS            OPT-LOS
# 15      ETH-LINK-FAIL      ETH-LINK-FAIL      ETH-LINK-FAIL      ETH-LINK-FAIL
# 16         OPT-REMOVE         OPT-REMOVE         OPT-REMOVE         OPT-REMOVE
# 17       TRK-CONN-MIS       TRK-CONN-MIS       TRK-CONN-MIS       TRK-CONN-MIS
# 18            OPT-MIS            OPT-MIS            OPT-MIS            OPT-MIS
# 19   LINK_FAIL_MANUAL   LINK-FAIL-MANUAL   LINK-FAIL-MANUAL   LINK-FAIL-MANUAL

# %%
# preprocess_tolong, replacements_msg = replacements
A_msg_uniq['Amsg_tolong'] = A_msg_uniq['Amsg_uppercase'].apply(preprocess_tolong, replacements_msg = replacements)
A_msg_uniq
# Out:
#    Amsg_not_processed        Amsg_hyphen         Amsg_blank  \
# 0             ETH-ERR            ETH-ERR            ETH-ERR
# 1            PSU-FAIL           PSU-FAIL           PSU-FAIL
# 2             BOOTING            BOOTING            BOOTING
# 3   ETH-NO-TX-TRAFFIC  ETH-NO-TX-TRAFFIC  ETH-NO-TX-TRAFFIC
# 4             LSP-LOC            LSP-LOC            LSP-LOC
# 5         OPT-PWR-LOW        OPT-PWR-LOW        OPT-PWR-LOW
# 6   ETH-NO-RX-TRAFFIC  ETH-NO-RX-TRAFFIC  ETH-NO-RX-TRAFFIC
# 7            DCC-FAIL           DCC-FAIL           DCC-FAIL
# 8        OPT-PWR-HIGH       OPT-PWR-HIGH       OPT-PWR-HIGH
# 9   AUTONEGO_MISMATCH  AUTONEGO-MISMATCH  AUTONEGO-MISMATCH
# 10             PW-LOC             PW-LOC             PW-LOC
# 11    TDM-PW-RMT_FAIL    TDM-PW-RMT-FAIL    TDM-PW-RMT-FAIL
# 12            QL_FAIL            QL-FAIL            QL-FAIL
# 13           48V-FAIL           48V-FAIL           48V-FAIL
# 14            OPT-LOS            OPT-LOS            OPT-LOS
# 15      ETH-LINK-FAIL      ETH-LINK-FAIL      ETH-LINK-FAIL
# 16         OPT-REMOVE         OPT-REMOVE         OPT-REMOVE
# 17       TRK-CONN-MIS       TRK-CONN-MIS       TRK-CONN-MIS
# 18            OPT-MIS            OPT-MIS            OPT-MIS
# 19   LINK_FAIL_MANUAL   LINK-FAIL-MANUAL   LINK-FAIL-MANUAL
#
#        Amsg_uppercase                                     Amsg_tolong
# 0             ETH-ERR                                  ETHERNET-ERROR
# 1            PSU-FAIL                          POWER-SUPPLY-UNIT-FAIL
# 2             BOOTING                                         BOOTING
# 3   ETH-NO-TX-TRAFFIC                ETHERNET-NO-TRANSMISSION-TRAFFIC
# 4             LSP-LOC             LABEL-SWITCHED-PATH-LOSS-OF-CONNECT
# 5         OPT-PWR-LOW                               OPTICAL-POWER-LOW
# 6   ETH-NO-RX-TRAFFIC                     ETHERNET-NO-RECEIVE-TRAFFIC
# 7            DCC-FAIL                   DATA-COMMUNICATE-CHANNEL-FAIL
# 8        OPT-PWR-HIGH                              OPTICAL-POWER-HIGH
# 9   AUTONEGO-MISMATCH                       AUTO-NEGOTIATION-MISMATCH
# 10             PW-LOC                      PSEUDOWIRE-LOSS-OF-CONNECT
# 11    TDM-PW-RMT-FAIL  TIME-DIVISION-MULTIPLEX-PSEUDOWIRE-REMOTE-FAIL
# 12            QL-FAIL                                    QUALITY-FAIL
# 13           48V-FAIL                                        48V-FAIL
# 14            OPT-LOS                          OPTICAL-LOSS-OF-SIGNAL
# 15      ETH-LINK-FAIL                              ETHERNET-LINK-FAIL
# 16         OPT-REMOVE                                  OPTICAL-REMOVE
# 17       TRK-CONN-MIS                          TRACK-CONNECT-MISMATCH
# 18            OPT-MIS                                OPTICAL-MISMATCH
# 19   LINK-FAIL-MANUAL                                LINK-FAIL-MANUAL

# %% [markdown]
# * test 데이터의 B제조사

# %%
# test데이터의 B제조사만 추출
msg_B = msg_test.loc[msg_test['root_cause_domain'] == 'B', :]
msg_B
# Out:
#       root_cause_domain  alarmlevel               alarmmsg_original
# 2                     B           4                 DDM_RX_PWR_HIGH
# 8                     B           4                  DDM_RX_PWR_LOW
# 396                   B           4               ETHER_TCA_DROP_1D
# 2338                  B           4               ETHER_TCA_CRC_15M
# 2339                  B           4                ETHER_TCA_CRC_1D
# 2469                  B           4                  ETHER_PORT_CRC
# 2612                  B           4                    BATTERY_FAIL
# 2864                  B           4              ETHER_TCA_DROP_15M
# 6801                  B           4                 DC_INPUT_A_FAIL
# 9306                  B           4                        DCN_FAIL
# 10970                 B           4           UNIT_INIT (BY INSLOT)
# 11091                 B           4            UNIT_INIT (BY RESET)
# 11092                 B           4                        UNIT_OUT
# 11192                 B           4              MODULE_OUT ( SFP )
# 11325                 B           4                        STM1_LOS
# 27306                 B           4                     MEP_LSP_RDI
# 3                     B           5                   BATT_ENV_FAIL
# 16                    B           5                     MEP_LSP_LOC
# 213                   B           5                     MEP_PWE_LOC
# 1197                  B           5                     MEP_PWE_CSF
# 5844                  B           5                        DCN_FAIL
# 7553                  B           5                     MEP_LSP_RDI
# 12927                 B           5                    SYS_TEMP_LOW
# 33879                 B           5                         CEP_AIS
# 150                   B           7   ETHER_LINK_DOWN (LOCAL_FAULT)
# 152                   B           7          ETHER_LINK_DOWN (LLCF)
# 1316                  B           7                       UNIT_FAIL
# 1575                  B           7           ETHER_LINK_DOWN (LOS)
# 6727                  B           7             MODULE_OUT ( SFP+ )
# 6732                  B           7              MODULE_OUT ( SFP )
# 10932                 B           7  ETHER_LINK_DOWN (REMOTE_FAULT)
# 11216                 B           7                        STM1_LOS
# 14459                 B           7                        UNIT_OUT
# 19845                 B           7            UNIT_INIT (BY RESET)

# %%
# B제조사의 Data Cleansing 전 알람메시지 모은 데이터프레임
B_msg_uniq = pd.DataFrame(msg_B['alarmmsg_original'].unique(), columns = ['Bmsg_not_processed'])
B_msg_uniq
# Out:
#                 Bmsg_not_processed
# 0                  DDM_RX_PWR_HIGH
# 1                   DDM_RX_PWR_LOW
# 2                ETHER_TCA_DROP_1D
# 3                ETHER_TCA_CRC_15M
# 4                 ETHER_TCA_CRC_1D
# 5                   ETHER_PORT_CRC
# 6                     BATTERY_FAIL
# 7               ETHER_TCA_DROP_15M
# 8                  DC_INPUT_A_FAIL
# 9                         DCN_FAIL
# 10           UNIT_INIT (BY INSLOT)
# 11            UNIT_INIT (BY RESET)
# 12                        UNIT_OUT
# 13              MODULE_OUT ( SFP )
# 14                        STM1_LOS
# 15                     MEP_LSP_RDI
# 16                   BATT_ENV_FAIL
# 17                     MEP_LSP_LOC
# 18                     MEP_PWE_LOC
# 19                     MEP_PWE_CSF
# 20                    SYS_TEMP_LOW
# 21                         CEP_AIS
# 22   ETHER_LINK_DOWN (LOCAL_FAULT)
# 23          ETHER_LINK_DOWN (LLCF)
# 24                       UNIT_FAIL
# 25           ETHER_LINK_DOWN (LOS)
# 26             MODULE_OUT ( SFP+ )
# 27  ETHER_LINK_DOWN (REMOTE_FAULT)

# %%
# 괄호 '-'로 변환
B_msg_uniq['Bmsg_no'] = B_msg_uniq['Bmsg_not_processed'].str.replace('(', '-')
B_msg_uniq
# Out:
# <ipython-input-42-8040f37b62ba>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   B_msg_uniq['Bmsg_no'] = B_msg_uniq['Bmsg_not_processed'].str.replace('(', '-')
#                 Bmsg_not_processed                         Bmsg_no
# 0                  DDM_RX_PWR_HIGH                 DDM_RX_PWR_HIGH
# 1                   DDM_RX_PWR_LOW                  DDM_RX_PWR_LOW
# 2                ETHER_TCA_DROP_1D               ETHER_TCA_DROP_1D
# 3                ETHER_TCA_CRC_15M               ETHER_TCA_CRC_15M
# 4                 ETHER_TCA_CRC_1D                ETHER_TCA_CRC_1D
# 5                   ETHER_PORT_CRC                  ETHER_PORT_CRC
# 6                     BATTERY_FAIL                    BATTERY_FAIL
# 7               ETHER_TCA_DROP_15M              ETHER_TCA_DROP_15M
# 8                  DC_INPUT_A_FAIL                 DC_INPUT_A_FAIL
# 9                         DCN_FAIL                        DCN_FAIL
# 10           UNIT_INIT (BY INSLOT)           UNIT_INIT -BY INSLOT)
# 11            UNIT_INIT (BY RESET)            UNIT_INIT -BY RESET)
# 12                        UNIT_OUT                        UNIT_OUT
# 13              MODULE_OUT ( SFP )              MODULE_OUT - SFP )
# 14                        STM1_LOS                        STM1_LOS
# 15                     MEP_LSP_RDI                     MEP_LSP_RDI
# 16                   BATT_ENV_FAIL                   BATT_ENV_FAIL
# 17                     MEP_LSP_LOC                     MEP_LSP_LOC
# 18                     MEP_PWE_LOC                     MEP_PWE_LOC
# 19                     MEP_PWE_CSF                     MEP_PWE_CSF
# 20                    SYS_TEMP_LOW                    SYS_TEMP_LOW
# 21                         CEP_AIS                         CEP_AIS
# 22   ETHER_LINK_DOWN (LOCAL_FAULT)   ETHER_LINK_DOWN -LOCAL_FAULT)
# 23          ETHER_LINK_DOWN (LLCF)          ETHER_LINK_DOWN -LLCF)
# 24                       UNIT_FAIL                       UNIT_FAIL
# 25           ETHER_LINK_DOWN (LOS)           ETHER_LINK_DOWN -LOS)
# 26             MODULE_OUT ( SFP+ )             MODULE_OUT - SFP+ )
# 27  ETHER_LINK_DOWN (REMOTE_FAULT)  ETHER_LINK_DOWN -REMOTE_FAULT)

# %%
# 괄호 제거
B_msg_uniq['Bmsg_on'] = B_msg_uniq['Bmsg_no'].str.replace(')', '')
B_msg_uniq
# Out:
# <ipython-input-43-d7d12291b56a>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   B_msg_uniq['Bmsg_on'] = B_msg_uniq['Bmsg_no'].str.replace(')', '')
#                 Bmsg_not_processed                         Bmsg_no  \
# 0                  DDM_RX_PWR_HIGH                 DDM_RX_PWR_HIGH
# 1                   DDM_RX_PWR_LOW                  DDM_RX_PWR_LOW
# 2                ETHER_TCA_DROP_1D               ETHER_TCA_DROP_1D
# 3                ETHER_TCA_CRC_15M               ETHER_TCA_CRC_15M
# 4                 ETHER_TCA_CRC_1D                ETHER_TCA_CRC_1D
# 5                   ETHER_PORT_CRC                  ETHER_PORT_CRC
# 6                     BATTERY_FAIL                    BATTERY_FAIL
# 7               ETHER_TCA_DROP_15M              ETHER_TCA_DROP_15M
# 8                  DC_INPUT_A_FAIL                 DC_INPUT_A_FAIL
# 9                         DCN_FAIL                        DCN_FAIL
# 10           UNIT_INIT (BY INSLOT)           UNIT_INIT -BY INSLOT)
# 11            UNIT_INIT (BY RESET)            UNIT_INIT -BY RESET)
# 12                        UNIT_OUT                        UNIT_OUT
# 13              MODULE_OUT ( SFP )              MODULE_OUT - SFP )
# 14                        STM1_LOS                        STM1_LOS
# 15                     MEP_LSP_RDI                     MEP_LSP_RDI
# 16                   BATT_ENV_FAIL                   BATT_ENV_FAIL
# 17                     MEP_LSP_LOC                     MEP_LSP_LOC
# 18                     MEP_PWE_LOC                     MEP_PWE_LOC
# 19                     MEP_PWE_CSF                     MEP_PWE_CSF
# 20                    SYS_TEMP_LOW                    SYS_TEMP_LOW
# 21                         CEP_AIS                         CEP_AIS
# 22   ETHER_LINK_DOWN (LOCAL_FAULT)   ETHER_LINK_DOWN -LOCAL_FAULT)
# 23          ETHER_LINK_DOWN (LLCF)          ETHER_LINK_DOWN -LLCF)
# 24                       UNIT_FAIL                       UNIT_FAIL
# 25           ETHER_LINK_DOWN (LOS)           ETHER_LINK_DOWN -LOS)
# 26             MODULE_OUT ( SFP+ )             MODULE_OUT - SFP+ )
# 27  ETHER_LINK_DOWN (REMOTE_FAULT)  ETHER_LINK_DOWN -REMOTE_FAULT)
#
#                           Bmsg_on
# 0                 DDM_RX_PWR_HIGH
# 1                  DDM_RX_PWR_LOW
# 2               ETHER_TCA_DROP_1D
# 3               ETHER_TCA_CRC_15M
# 4                ETHER_TCA_CRC_1D
# 5                  ETHER_PORT_CRC
# 6                    BATTERY_FAIL
# 7              ETHER_TCA_DROP_15M
# 8                 DC_INPUT_A_FAIL
# 9                        DCN_FAIL
# 10           UNIT_INIT -BY INSLOT
# 11            UNIT_INIT -BY RESET
# 12                       UNIT_OUT
# 13              MODULE_OUT - SFP
# 14                       STM1_LOS
# 15                    MEP_LSP_RDI
# 16                  BATT_ENV_FAIL
# 17                    MEP_LSP_LOC
# 18                    MEP_PWE_LOC
# 19                    MEP_PWE_CSF
# 20                   SYS_TEMP_LOW
# 21                        CEP_AIS
# 22   ETHER_LINK_DOWN -LOCAL_FAULT
# 23          ETHER_LINK_DOWN -LLCF
# 24                      UNIT_FAIL
# 25           ETHER_LINK_DOWN -LOS
# 26             MODULE_OUT - SFP+
# 27  ETHER_LINK_DOWN -REMOTE_FAULT

# %%
# preprocess_blank_remove 함수 사용
B_msg_uniq['Bmsg_blank_remove'] = B_msg_uniq['Bmsg_on'].apply(preprocess_blank_remove)
B_msg_uniq
# Out:
#                 Bmsg_not_processed                         Bmsg_no  \
# 0                  DDM_RX_PWR_HIGH                 DDM_RX_PWR_HIGH
# 1                   DDM_RX_PWR_LOW                  DDM_RX_PWR_LOW
# 2                ETHER_TCA_DROP_1D               ETHER_TCA_DROP_1D
# 3                ETHER_TCA_CRC_15M               ETHER_TCA_CRC_15M
# 4                 ETHER_TCA_CRC_1D                ETHER_TCA_CRC_1D
# 5                   ETHER_PORT_CRC                  ETHER_PORT_CRC
# 6                     BATTERY_FAIL                    BATTERY_FAIL
# 7               ETHER_TCA_DROP_15M              ETHER_TCA_DROP_15M
# 8                  DC_INPUT_A_FAIL                 DC_INPUT_A_FAIL
# 9                         DCN_FAIL                        DCN_FAIL
# 10           UNIT_INIT (BY INSLOT)           UNIT_INIT -BY INSLOT)
# 11            UNIT_INIT (BY RESET)            UNIT_INIT -BY RESET)
# 12                        UNIT_OUT                        UNIT_OUT
# 13              MODULE_OUT ( SFP )              MODULE_OUT - SFP )
# 14                        STM1_LOS                        STM1_LOS
# 15                     MEP_LSP_RDI                     MEP_LSP_RDI
# 16                   BATT_ENV_FAIL                   BATT_ENV_FAIL
# 17                     MEP_LSP_LOC                     MEP_LSP_LOC
# 18                     MEP_PWE_LOC                     MEP_PWE_LOC
# 19                     MEP_PWE_CSF                     MEP_PWE_CSF
# 20                    SYS_TEMP_LOW                    SYS_TEMP_LOW
# 21                         CEP_AIS                         CEP_AIS
# 22   ETHER_LINK_DOWN (LOCAL_FAULT)   ETHER_LINK_DOWN -LOCAL_FAULT)
# 23          ETHER_LINK_DOWN (LLCF)          ETHER_LINK_DOWN -LLCF)
# 24                       UNIT_FAIL                       UNIT_FAIL
# 25           ETHER_LINK_DOWN (LOS)           ETHER_LINK_DOWN -LOS)
# 26             MODULE_OUT ( SFP+ )             MODULE_OUT - SFP+ )
# 27  ETHER_LINK_DOWN (REMOTE_FAULT)  ETHER_LINK_DOWN -REMOTE_FAULT)
#
#                           Bmsg_on             Bmsg_blank_remove
# 0                 DDM_RX_PWR_HIGH               DDM_RX_PWR_HIGH
# 1                  DDM_RX_PWR_LOW                DDM_RX_PWR_LOW
# 2               ETHER_TCA_DROP_1D             ETHER_TCA_DROP_1D
# 3               ETHER_TCA_CRC_15M             ETHER_TCA_CRC_15M
# 4                ETHER_TCA_CRC_1D              ETHER_TCA_CRC_1D
# 5                  ETHER_PORT_CRC                ETHER_PORT_CRC
# 6                    BATTERY_FAIL                  BATTERY_FAIL
# 7              ETHER_TCA_DROP_15M            ETHER_TCA_DROP_15M
# 8                 DC_INPUT_A_FAIL               DC_INPUT_A_FAIL
# 9                        DCN_FAIL                      DCN_FAIL
# 10           UNIT_INIT -BY INSLOT            UNIT_INIT-BYINSLOT
# 11            UNIT_INIT -BY RESET             UNIT_INIT-BYRESET
# 12                       UNIT_OUT                      UNIT_OUT
# 13              MODULE_OUT - SFP                 MODULE_OUT-SFP
# 14                       STM1_LOS                      STM1_LOS
# 15                    MEP_LSP_RDI                   MEP_LSP_RDI
# 16                  BATT_ENV_FAIL                 BATT_ENV_FAIL
# 17                    MEP_LSP_LOC                   MEP_LSP_LOC
# 18                    MEP_PWE_LOC                   MEP_PWE_LOC
# 19                    MEP_PWE_CSF                   MEP_PWE_CSF
# 20                   SYS_TEMP_LOW                  SYS_TEMP_LOW
# 21                        CEP_AIS                       CEP_AIS
# 22   ETHER_LINK_DOWN -LOCAL_FAULT   ETHER_LINK_DOWN-LOCAL_FAULT
# 23          ETHER_LINK_DOWN -LLCF          ETHER_LINK_DOWN-LLCF
# 24                      UNIT_FAIL                     UNIT_FAIL
# 25           ETHER_LINK_DOWN -LOS           ETHER_LINK_DOWN-LOS
# 26             MODULE_OUT - SFP+                MODULE_OUT-SFP+
# 27  ETHER_LINK_DOWN -REMOTE_FAULT  ETHER_LINK_DOWN-REMOTE_FAULT

# %%
# preprocess_hyphen 함수 사용
B_msg_uniq['Bmsg_hyphen'] = B_msg_uniq['Bmsg_blank_remove'].apply(preprocess_hyphen)
B_msg_uniq
# Out:
#                 Bmsg_not_processed                         Bmsg_no  \
# 0                  DDM_RX_PWR_HIGH                 DDM_RX_PWR_HIGH
# 1                   DDM_RX_PWR_LOW                  DDM_RX_PWR_LOW
# 2                ETHER_TCA_DROP_1D               ETHER_TCA_DROP_1D
# 3                ETHER_TCA_CRC_15M               ETHER_TCA_CRC_15M
# 4                 ETHER_TCA_CRC_1D                ETHER_TCA_CRC_1D
# 5                   ETHER_PORT_CRC                  ETHER_PORT_CRC
# 6                     BATTERY_FAIL                    BATTERY_FAIL
# 7               ETHER_TCA_DROP_15M              ETHER_TCA_DROP_15M
# 8                  DC_INPUT_A_FAIL                 DC_INPUT_A_FAIL
# 9                         DCN_FAIL                        DCN_FAIL
# 10           UNIT_INIT (BY INSLOT)           UNIT_INIT -BY INSLOT)
# 11            UNIT_INIT (BY RESET)            UNIT_INIT -BY RESET)
# 12                        UNIT_OUT                        UNIT_OUT
# 13              MODULE_OUT ( SFP )              MODULE_OUT - SFP )
# 14                        STM1_LOS                        STM1_LOS
# 15                     MEP_LSP_RDI                     MEP_LSP_RDI
# 16                   BATT_ENV_FAIL                   BATT_ENV_FAIL
# 17                     MEP_LSP_LOC                     MEP_LSP_LOC
# 18                     MEP_PWE_LOC                     MEP_PWE_LOC
# 19                     MEP_PWE_CSF                     MEP_PWE_CSF
# 20                    SYS_TEMP_LOW                    SYS_TEMP_LOW
# 21                         CEP_AIS                         CEP_AIS
# 22   ETHER_LINK_DOWN (LOCAL_FAULT)   ETHER_LINK_DOWN -LOCAL_FAULT)
# 23          ETHER_LINK_DOWN (LLCF)          ETHER_LINK_DOWN -LLCF)
# 24                       UNIT_FAIL                       UNIT_FAIL
# 25           ETHER_LINK_DOWN (LOS)           ETHER_LINK_DOWN -LOS)
# 26             MODULE_OUT ( SFP+ )             MODULE_OUT - SFP+ )
# 27  ETHER_LINK_DOWN (REMOTE_FAULT)  ETHER_LINK_DOWN -REMOTE_FAULT)
#
#                           Bmsg_on             Bmsg_blank_remove  \
# 0                 DDM_RX_PWR_HIGH               DDM_RX_PWR_HIGH
# 1                  DDM_RX_PWR_LOW                DDM_RX_PWR_LOW
# 2               ETHER_TCA_DROP_1D             ETHER_TCA_DROP_1D
# 3               ETHER_TCA_CRC_15M             ETHER_TCA_CRC_15M
# 4                ETHER_TCA_CRC_1D              ETHER_TCA_CRC_1D
# 5                  ETHER_PORT_CRC                ETHER_PORT_CRC
# 6                    BATTERY_FAIL                  BATTERY_FAIL
# 7              ETHER_TCA_DROP_15M            ETHER_TCA_DROP_15M
# 8                 DC_INPUT_A_FAIL               DC_INPUT_A_FAIL
# 9                        DCN_FAIL                      DCN_FAIL
# 10           UNIT_INIT -BY INSLOT            UNIT_INIT-BYINSLOT
# 11            UNIT_INIT -BY RESET             UNIT_INIT-BYRESET
# 12                       UNIT_OUT                      UNIT_OUT
# 13              MODULE_OUT - SFP                 MODULE_OUT-SFP
# 14                       STM1_LOS                      STM1_LOS
# 15                    MEP_LSP_RDI                   MEP_LSP_RDI
# 16                  BATT_ENV_FAIL                 BATT_ENV_FAIL
# 17                    MEP_LSP_LOC                   MEP_LSP_LOC
# 18                    MEP_PWE_LOC                   MEP_PWE_LOC
# 19                    MEP_PWE_CSF                   MEP_PWE_CSF
# 20                   SYS_TEMP_LOW                  SYS_TEMP_LOW
# 21                        CEP_AIS                       CEP_AIS
# 22   ETHER_LINK_DOWN -LOCAL_FAULT   ETHER_LINK_DOWN-LOCAL_FAULT
# 23          ETHER_LINK_DOWN -LLCF          ETHER_LINK_DOWN-LLCF
# 24                      UNIT_FAIL                     UNIT_FAIL
# 25           ETHER_LINK_DOWN -LOS           ETHER_LINK_DOWN-LOS
# 26             MODULE_OUT - SFP+                MODULE_OUT-SFP+
# 27  ETHER_LINK_DOWN -REMOTE_FAULT  ETHER_LINK_DOWN-REMOTE_FAULT
#
#                      Bmsg_hyphen
# 0                DDM-RX-PWR-HIGH
# 1                 DDM-RX-PWR-LOW
# 2              ETHER-TCA-DROP-1D
# 3              ETHER-TCA-CRC-15M
# 4               ETHER-TCA-CRC-1D
# 5                 ETHER-PORT-CRC
# 6                   BATTERY-FAIL
# 7             ETHER-TCA-DROP-15M
# 8                DC-INPUT-A-FAIL
# 9                       DCN-FAIL
# 10            UNIT-INIT-BYINSLOT
# 11             UNIT-INIT-BYRESET
# 12                      UNIT-OUT
# 13                MODULE-OUT-SFP
# 14                      STM1-LOS
# 15                   MEP-LSP-RDI
# 16                 BATT-ENV-FAIL
# 17                   MEP-LSP-LOC
# 18                   MEP-PWE-LOC
# 19                   MEP-PWE-CSF
# 20                  SYS-TEMP-LOW
# 21                       CEP-AIS
# 22   ETHER-LINK-DOWN-LOCAL-FAULT
# 23          ETHER-LINK-DOWN-LLCF
# 24                     UNIT-FAIL
# 25           ETHER-LINK-DOWN-LOS
# 26               MODULE-OUT-SFP+
# 27  ETHER-LINK-DOWN-REMOTE-FAULT

# %%
# B 제조사의 축약어 변환을 위한 딕셔너리 형태의 단어사전
replacements_B = {
    'DDM' : 'ALARM',
    'RX' : 'RECEIVE',
    'TX' : 'TRANSMISSION',
    'PWR' : 'POWER',
    'ETHER' : 'ETHERNET',
    'TCA' : 'ALARM',
    '1D' : '1-DAY',
    '15M' : '15-MINUTE',
    'CRC' : 'CYCLIC-REDUNDANCY-CHECK',
    'DCN' : 'DATA-COMMUNICATE-NETWORK',
    'DC' : 'BATTERY',
    'BYINSLOT' : 'BY-IN-SLOT',
    'BYRESET' : 'BY-RESET',
    'SFP+' : 'ENHANCED-SMALL-FORM-FACTOR-PLUG',
    'SFP' : 'SMALL-FORM-FACTOR-PLUG',
    'STM1' : 'SYNCHRONOUS-TRANSPORT-MODULE-LEVEL-1',
    'LOS' : 'LOSS-OF-SIGNAL',
    'MEP' : 'MAINTENANCE-END-POINT',
    'LSP' : 'LABEL-SWITCHED-PATH',
    'RDI' : 'RECEIVE-FAIL',
    'BATT-' : 'BATTERY-',
    'ENV' : 'ENVIRONMENT',
    'E-LOC' : 'E-LOSS-OF-CONNECT',
    'P-LOC' : 'P-LOSS-OF-CONNECT',
    'H-LOC' : 'H-LOSS-OF-CONNECT',
    'PWE' : 'PSEUDOWIRE-EMULATION',
    'CSF' : 'CLIENT-SIGNAL-FAIL',
    'SYS' : 'SYSTEM',
    'TEMP' : 'TEMPARATURE',
    'CEP' : 'CLIENT-ENVIRONMENT-PROTECTION',
    'AIS' : 'ALARM',
    'LLCF' : 'LINK-LOST-CARRY-FORWARD'
    }

# %%
# preprocess_tolong, replacements_msg = replacements_B 함수 사용
B_msg_uniq['Bmsg_tolong'] = B_msg_uniq['Bmsg_hyphen'].apply(preprocess_tolong, replacements_msg = replacements_B)
B_msg_uniq
# Out:
#                 Bmsg_not_processed                         Bmsg_no  \
# 0                  DDM_RX_PWR_HIGH                 DDM_RX_PWR_HIGH
# 1                   DDM_RX_PWR_LOW                  DDM_RX_PWR_LOW
# 2                ETHER_TCA_DROP_1D               ETHER_TCA_DROP_1D
# 3                ETHER_TCA_CRC_15M               ETHER_TCA_CRC_15M
# 4                 ETHER_TCA_CRC_1D                ETHER_TCA_CRC_1D
# 5                   ETHER_PORT_CRC                  ETHER_PORT_CRC
# 6                     BATTERY_FAIL                    BATTERY_FAIL
# 7               ETHER_TCA_DROP_15M              ETHER_TCA_DROP_15M
# 8                  DC_INPUT_A_FAIL                 DC_INPUT_A_FAIL
# 9                         DCN_FAIL                        DCN_FAIL
# 10           UNIT_INIT (BY INSLOT)           UNIT_INIT -BY INSLOT)
# 11            UNIT_INIT (BY RESET)            UNIT_INIT -BY RESET)
# 12                        UNIT_OUT                        UNIT_OUT
# 13              MODULE_OUT ( SFP )              MODULE_OUT - SFP )
# 14                        STM1_LOS                        STM1_LOS
# 15                     MEP_LSP_RDI                     MEP_LSP_RDI
# 16                   BATT_ENV_FAIL                   BATT_ENV_FAIL
# 17                     MEP_LSP_LOC                     MEP_LSP_LOC
# 18                     MEP_PWE_LOC                     MEP_PWE_LOC
# 19                     MEP_PWE_CSF                     MEP_PWE_CSF
# 20                    SYS_TEMP_LOW                    SYS_TEMP_LOW
# 21                         CEP_AIS                         CEP_AIS
# 22   ETHER_LINK_DOWN (LOCAL_FAULT)   ETHER_LINK_DOWN -LOCAL_FAULT)
# 23          ETHER_LINK_DOWN (LLCF)          ETHER_LINK_DOWN -LLCF)
# 24                       UNIT_FAIL                       UNIT_FAIL
# 25           ETHER_LINK_DOWN (LOS)           ETHER_LINK_DOWN -LOS)
# 26             MODULE_OUT ( SFP+ )             MODULE_OUT - SFP+ )
# 27  ETHER_LINK_DOWN (REMOTE_FAULT)  ETHER_LINK_DOWN -REMOTE_FAULT)
#
#                           Bmsg_on             Bmsg_blank_remove  \
# 0                 DDM_RX_PWR_HIGH               DDM_RX_PWR_HIGH
# 1                  DDM_RX_PWR_LOW                DDM_RX_PWR_LOW
# 2               ETHER_TCA_DROP_1D             ETHER_TCA_DROP_1D
# 3               ETHER_TCA_CRC_15M             ETHER_TCA_CRC_15M
# 4                ETHER_TCA_CRC_1D              ETHER_TCA_CRC_1D
# 5                  ETHER_PORT_CRC                ETHER_PORT_CRC
# 6                    BATTERY_FAIL                  BATTERY_FAIL
# 7              ETHER_TCA_DROP_15M            ETHER_TCA_DROP_15M
# 8                 DC_INPUT_A_FAIL               DC_INPUT_A_FAIL
# 9                        DCN_FAIL                      DCN_FAIL
# 10           UNIT_INIT -BY INSLOT            UNIT_INIT-BYINSLOT
# 11            UNIT_INIT -BY RESET             UNIT_INIT-BYRESET
# 12                       UNIT_OUT                      UNIT_OUT
# 13              MODULE_OUT - SFP                 MODULE_OUT-SFP
# 14                       STM1_LOS                      STM1_LOS
# 15                    MEP_LSP_RDI                   MEP_LSP_RDI
# 16                  BATT_ENV_FAIL                 BATT_ENV_FAIL
# 17                    MEP_LSP_LOC                   MEP_LSP_LOC
# 18                    MEP_PWE_LOC                   MEP_PWE_LOC
# 19                    MEP_PWE_CSF                   MEP_PWE_CSF
# 20                   SYS_TEMP_LOW                  SYS_TEMP_LOW
# 21                        CEP_AIS                       CEP_AIS
# 22   ETHER_LINK_DOWN -LOCAL_FAULT   ETHER_LINK_DOWN-LOCAL_FAULT
# 23          ETHER_LINK_DOWN -LLCF          ETHER_LINK_DOWN-LLCF
# 24                      UNIT_FAIL                     UNIT_FAIL
# 25           ETHER_LINK_DOWN -LOS           ETHER_LINK_DOWN-LOS
# 26             MODULE_OUT - SFP+                MODULE_OUT-SFP+
# 27  ETHER_LINK_DOWN -REMOTE_FAULT  ETHER_LINK_DOWN-REMOTE_FAULT
#
#                      Bmsg_hyphen  \
# 0                DDM-RX-PWR-HIGH
# 1                 DDM-RX-PWR-LOW
# 2              ETHER-TCA-DROP-1D
# 3              ETHER-TCA-CRC-15M
# 4               ETHER-TCA-CRC-1D
# 5                 ETHER-PORT-CRC
# 6                   BATTERY-FAIL
# 7             ETHER-TCA-DROP-15M
# 8                DC-INPUT-A-FAIL
# 9                       DCN-FAIL
# 10            UNIT-INIT-BYINSLOT
# 11             UNIT-INIT-BYRESET
# 12                      UNIT-OUT
# 13                MODULE-OUT-SFP
# 14                      STM1-LOS
# 15                   MEP-LSP-RDI
# 16                 BATT-ENV-FAIL
# 17                   MEP-LSP-LOC
# 18                   MEP-PWE-LOC
# 19                   MEP-PWE-CSF
# 20                  SYS-TEMP-LOW
# 21                       CEP-AIS
# 22   ETHER-LINK-DOWN-LOCAL-FAULT
# 23          ETHER-LINK-DOWN-LLCF
# 24                     UNIT-FAIL
# 25           ETHER-LINK-DOWN-LOS
# 26               MODULE-OUT-SFP+
# 27  ETHER-LINK-DOWN-REMOTE-FAULT
#
#                                           Bmsg_tolong
# 0                            ALARM-RECEIVE-POWER-HIGH
# 1                             ALARM-RECEIVE-POWER-LOW
# 2                           ETHERNET-ALARM-DROP-1-DAY
# 3    ETHERNET-ALARM-CYCLIC-REDUNDANCY-CHECK-15-MINUTE
# 4        ETHERNET-ALARM-CYCLIC-REDUNDANCY-CHECK-1-DAY
# 5               ETHERNET-PORT-CYCLIC-REDUNDANCY-CHECK
# 6                                        BATTERY-FAIL
# 7                       ETHERNET-ALARM-DROP-15-MINUTE
# 8                                BATTERY-INPUT-A-FAIL
# 9                       DATA-COMMUNICATE-NETWORK-FAIL
# 10                               UNIT-INIT-BY-IN-SLOT
# 11                                 UNIT-INIT-BY-RESET
# 12                                           UNIT-OUT
# 13                  MODULE-OUT-SMALL-FORM-FACTOR-PLUG
# 14  SYNCHRONOUS-TRANSPORT-MODULE-LEVEL-1-LOSS-OF-S...
# 15  MAINTENANCE-END-POINT-LABEL-SWITCHED-PATH-RECE...
# 16                           BATTERY-ENVIRONMENT-FAIL
# 17  MAINTENANCE-END-POINT-LABEL-SWITCHED-PATH-LOSS...
# 18  MAINTENANCE-END-POINT-PSEUDOWIRE-EMULATION-LOS...
# 19  MAINTENANCE-END-POINT-PSEUDOWIRE-EMULATION-CLI...
# 20                             SYSTEM-TEMPARATURE-LOW
# 21                CLIENT-ENVIRONMENT-PROTECTION-ALARM
# 22                     ETHERNET-LINK-DOWN-LOCAL-FAULT
# 23         ETHERNET-LINK-DOWN-LINK-LOST-CARRY-FORWARD
# 24                                          UNIT-FAIL
# 25                  ETHERNET-LINK-DOWN-LOSS-OF-SIGNAL
# 26         MODULE-OUT-ENHANCED-SMALL-FORM-FACTOR-PLUG
# 27                    ETHERNET-LINK-DOWN-REMOTE-FAULT

# %%
# 변환 확인
B_msg_uniq['Bmsg_tolong'].unique()
# Out:
# array(['ALARM-RECEIVE-POWER-HIGH', 'ALARM-RECEIVE-POWER-LOW',
#        'ETHERNET-ALARM-DROP-1-DAY',
#        'ETHERNET-ALARM-CYCLIC-REDUNDANCY-CHECK-15-MINUTE',
#        'ETHERNET-ALARM-CYCLIC-REDUNDANCY-CHECK-1-DAY',
#        'ETHERNET-PORT-CYCLIC-REDUNDANCY-CHECK', 'BATTERY-FAIL',
#        'ETHERNET-ALARM-DROP-15-MINUTE', 'BATTERY-INPUT-A-FAIL',
#        'DATA-COMMUNICATE-NETWORK-FAIL', 'UNIT-INIT-BY-IN-SLOT',
#        'UNIT-INIT-BY-RESET', 'UNIT-OUT',
#        'MODULE-OUT-SMALL-FORM-FACTOR-PLUG',
#        'SYNCHRONOUS-TRANSPORT-MODULE-LEVEL-1-LOSS-OF-SIGNAL',
#        'MAINTENANCE-END-POINT-LABEL-SWITCHED-PATH-RECEIVE-FAIL',
#        'BATTERY-ENVIRONMENT-FAIL',
#        'MAINTENANCE-END-POINT-LABEL-SWITCHED-PATH-LOSS-OF-CONNECT',
#        'MAINTENANCE-END-POINT-PSEUDOWIRE-EMULATION-LOSS-OF-CONNECT',
#        'MAINTENANCE-END-POINT-PSEUDOWIRE-EMULATION-CLIENT-SIGNAL-FAIL',
#        'SYSTEM-TEMPARATURE-LOW', 'CLIENT-ENVIRONMENT-PROTECTION-ALARM',
#        'ETHERNET-LINK-DOWN-LOCAL-FAULT',
#        'ETHERNET-LINK-DOWN-LINK-LOST-CARRY-FORWARD', 'UNIT-FAIL',
#        'ETHERNET-LINK-DOWN-LOSS-OF-SIGNAL',
#        'MODULE-OUT-ENHANCED-SMALL-FORM-FACTOR-PLUG',
#        'ETHERNET-LINK-DOWN-REMOTE-FAULT'], dtype=object)

# %% [markdown]
# * test 데이터의 C제조사

# %%
# test데이터의 C제조사만 추출
msg_C = msg_test.loc[msg_test['root_cause_domain'] == 'C', :]
msg_C
# Out:
#       root_cause_domain  alarmlevel                        alarmmsg_original
# 10                    C           3                 Remote Defect Indication
# 165                   C           4                                 PPP Fail
# 309                   C           4                                  Rx Fail
# 395                   C           4               Input Power Degrade Defect
# 4399                  C           4                   OAM Loss Of Continuity
# 4432                  C           4                                  OAM RDI
# 6414                  C           4                         Improper Removal
# 6717                  C           4                    OAMLoss Of Continuity
# 7378                  C           4              Manual (Management) Removal
# 7765                  C           4                          Procedure Error
# 13463                 C           4         Abnormal Condition: Laser Forced
# 13955                 C           4    IOC Payload-Links with Matrix Failure
# 0                     C           5                           Loss Of Signal
# 17                    C           5               Input Power Degrade Defect
# 160                   C           5                    Server Signal Failure
# 407                   C           5                       Client Signal Fail
# 427                   C           5                     Loss of Connectivity
# 428                   C           5                           Unexpected MEG
# 1594                  C           5                   OAM Loss Of Continuity
# 4846                  C           5                         Hardware failure
# 6424                  C           5                         Improper Removal
# 6593                  C           5          Underlying Resource Unavailable
# 8100                  C           5              Manual (Management) Removal
# 8112                  C           5                          Procedure Error
# 15337                 C           5                  Remote Fault Indication
# 36699                 C           5        Synchronization Signal Fail Raise
# 249                   C           7                      House Keeping Alarm
# 1893                  C           7  NE Not Reachable Via Primary Mng Interf
# 1907                  C           7                           Node Isolation
# 1908                  C           7      NE Not Reach Via Primary Mng Interf

# %%
# C제조사의 Data Cleansing 전 알람메시지 모은 데이터프레임
C_msg_uniq = pd.DataFrame(msg_C['alarmmsg_original'].unique(), columns = ['Cmsg_not_processed'])
C_msg_uniq
# Out:
#                          Cmsg_not_processed
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8               Manual (Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf

# %%
# 괄호 제거
C_msg_uniq['Cmsg_no'] = C_msg_uniq['Cmsg_not_processed'].str.replace('(', '')
C_msg_uniq
# Out:
# <ipython-input-51-10859d41cd73>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   C_msg_uniq['Cmsg_no'] = C_msg_uniq['Cmsg_not_processed'].str.replace('(', '')
#                          Cmsg_not_processed  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8               Manual (Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                     Cmsg_no
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                Manual Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf

# %%
# 괄호 제거
C_msg_uniq['Cmsg_on'] = C_msg_uniq['Cmsg_no'].str.replace(')', '')
C_msg_uniq
# Out:
# <ipython-input-52-8a65a9da06ab>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   C_msg_uniq['Cmsg_on'] = C_msg_uniq['Cmsg_no'].str.replace(')', '')
#                          Cmsg_not_processed  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8               Manual (Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                     Cmsg_no  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                Manual Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                     Cmsg_on
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                 Manual Management Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf

# %%
# preprocess_remove_colon 함수 사용
C_msg_uniq['Cmsg_colon'] = C_msg_uniq['Cmsg_on'].apply(preprocess_remove_colon)
C_msg_uniq
# Out:
#                          Cmsg_not_processed  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8               Manual (Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                     Cmsg_no  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                Manual Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                     Cmsg_on  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                 Manual Management Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                  Cmsg_colon
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                 Manual Management Removal
# 9                           Procedure Error
# 10          Abnormal Condition Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf

# %%
# preprocess_blank 함수 사용
C_msg_uniq['Cmsg_blank'] = C_msg_uniq['Cmsg_colon'].apply(preprocess_blank)
C_msg_uniq
# Out:
#                          Cmsg_not_processed  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8               Manual (Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                     Cmsg_no  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                Manual Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                     Cmsg_on  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                 Manual Management Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                  Cmsg_colon  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                 Manual Management Removal
# 9                           Procedure Error
# 10          Abnormal Condition Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                  Cmsg_blank
# 0                  Remote-Defect-Indication
# 1                                  PPP-Fail
# 2                                   Rx-Fail
# 3                Input-Power-Degrade-Defect
# 4                    OAM-Loss-Of-Continuity
# 5                                   OAM-RDI
# 6                          Improper-Removal
# 7                     OAMLoss-Of-Continuity
# 8                 Manual-Management-Removal
# 9                           Procedure-Error
# 10          Abnormal-Condition-Laser-Forced
# 11    IOC-Payload-Links-with-Matrix-Failure
# 12                           Loss-Of-Signal
# 13                    Server-Signal-Failure
# 14                       Client-Signal-Fail
# 15                     Loss-of-Connectivity
# 16                           Unexpected-MEG
# 17                         Hardware-failure
# 18          Underlying-Resource-Unavailable
# 19                  Remote-Fault-Indication
# 20        Synchronization-Signal-Fail-Raise
# 21                      House-Keeping-Alarm
# 22  NE-Not-Reachable-Via-Primary-Mng-Interf
# 23                           Node-Isolation
# 24      NE-Not-Reach-Via-Primary-Mng-Interf

# %%
# preprocess_uppercase 함수 사용
C_msg_uniq['Cmsg_uppercase'] = C_msg_uniq['Cmsg_blank'].apply(preprocess_uppercase)
C_msg_uniq
# Out:
#                          Cmsg_not_processed  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8               Manual (Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                     Cmsg_no  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                Manual Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                     Cmsg_on  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                 Manual Management Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                  Cmsg_colon  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                 Manual Management Removal
# 9                           Procedure Error
# 10          Abnormal Condition Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                  Cmsg_blank  \
# 0                  Remote-Defect-Indication
# 1                                  PPP-Fail
# 2                                   Rx-Fail
# 3                Input-Power-Degrade-Defect
# 4                    OAM-Loss-Of-Continuity
# 5                                   OAM-RDI
# 6                          Improper-Removal
# 7                     OAMLoss-Of-Continuity
# 8                 Manual-Management-Removal
# 9                           Procedure-Error
# 10          Abnormal-Condition-Laser-Forced
# 11    IOC-Payload-Links-with-Matrix-Failure
# 12                           Loss-Of-Signal
# 13                    Server-Signal-Failure
# 14                       Client-Signal-Fail
# 15                     Loss-of-Connectivity
# 16                           Unexpected-MEG
# 17                         Hardware-failure
# 18          Underlying-Resource-Unavailable
# 19                  Remote-Fault-Indication
# 20        Synchronization-Signal-Fail-Raise
# 21                      House-Keeping-Alarm
# 22  NE-Not-Reachable-Via-Primary-Mng-Interf
# 23                           Node-Isolation
# 24      NE-Not-Reach-Via-Primary-Mng-Interf
#
#                              Cmsg_uppercase
# 0                  REMOTE-DEFECT-INDICATION
# 1                                  PPP-FAIL
# 2                                   RX-FAIL
# 3                INPUT-POWER-DEGRADE-DEFECT
# 4                    OAM-LOSS-OF-CONTINUITY
# 5                                   OAM-RDI
# 6                          IMPROPER-REMOVAL
# 7                     OAMLOSS-OF-CONTINUITY
# 8                 MANUAL-MANAGEMENT-REMOVAL
# 9                           PROCEDURE-ERROR
# 10          ABNORMAL-CONDITION-LASER-FORCED
# 11    IOC-PAYLOAD-LINKS-WITH-MATRIX-FAILURE
# 12                           LOSS-OF-SIGNAL
# 13                    SERVER-SIGNAL-FAILURE
# 14                       CLIENT-SIGNAL-FAIL
# 15                     LOSS-OF-CONNECTIVITY
# 16                           UNEXPECTED-MEG
# 17                         HARDWARE-FAILURE
# 18          UNDERLYING-RESOURCE-UNAVAILABLE
# 19                  REMOTE-FAULT-INDICATION
# 20        SYNCHRONIZATION-SIGNAL-FAIL-RAISE
# 21                      HOUSE-KEEPING-ALARM
# 22  NE-NOT-REACHABLE-VIA-PRIMARY-MNG-INTERF
# 23                           NODE-ISOLATION
# 24      NE-NOT-REACH-VIA-PRIMARY-MNG-INTERF

# %%
# C 제조사의 축약어 변환을 위한 딕셔너리 형태의 단어사전
replacements_C = {
    'PPP' : 'ETHERNET',
    'RX' : 'RECEIVE',
    'OAMLOSS' : 'OAM-LOSS',
    'OAM' : 'OPERATION-AND-MAINTENANCE',
    'CONTINUITY' : 'CONNECT',
    'REMOTE-DEFECT-INDICATION' : 'ALARM',
    'RDI' : 'RECEIVE-FAIL',
    'IOC' : 'INPUT-OUTPUT-CONTROLLER',
    'FAILURE' : 'FAIL',
    'MEG' : 'MULTICAST-ETHERNET-GROUP',
    'NE-' : 'NETWORK-ELEMENT-',
    'MNG' : 'MANAGEMENT',
    'INTERF' : 'INTERFACE',
    'HOUSE-KEEPING-ALARM' : 'ALARM',
    'REMOVAL' : 'REMOVE',
    'CONNECTIVITY' : 'CONNECT',
    'REACHABLE' : 'REACH',
    'LINKS' : 'LINK',
    'HARDWARE' : 'UNIT',
    'CONTROLLER' : 'UNIT',
    'DEGRADE' : 'LOW',
    'WITH-MATRIX-' : '',
    '-RAISE' : '',
    'NOT' : 'NO'
    }

# %%
# preprocess_tolong, replacements_msg = replacements_C 함수 사용
C_msg_uniq['Cmsg_tolong'] = C_msg_uniq['Cmsg_uppercase'].apply(preprocess_tolong, replacements_msg = replacements_C)
C_msg_uniq
# Out:
#                          Cmsg_not_processed  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8               Manual (Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                     Cmsg_no  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                Manual Management) Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                     Cmsg_on  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                 Manual Management Removal
# 9                           Procedure Error
# 10         Abnormal Condition: Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                  Cmsg_colon  \
# 0                  Remote Defect Indication
# 1                                  PPP Fail
# 2                                   Rx Fail
# 3                Input Power Degrade Defect
# 4                    OAM Loss Of Continuity
# 5                                   OAM RDI
# 6                          Improper Removal
# 7                     OAMLoss Of Continuity
# 8                 Manual Management Removal
# 9                           Procedure Error
# 10          Abnormal Condition Laser Forced
# 11    IOC Payload-Links with Matrix Failure
# 12                           Loss Of Signal
# 13                    Server Signal Failure
# 14                       Client Signal Fail
# 15                     Loss of Connectivity
# 16                           Unexpected MEG
# 17                         Hardware failure
# 18          Underlying Resource Unavailable
# 19                  Remote Fault Indication
# 20        Synchronization Signal Fail Raise
# 21                      House Keeping Alarm
# 22  NE Not Reachable Via Primary Mng Interf
# 23                           Node Isolation
# 24      NE Not Reach Via Primary Mng Interf
#
#                                  Cmsg_blank  \
# 0                  Remote-Defect-Indication
# 1                                  PPP-Fail
# 2                                   Rx-Fail
# 3                Input-Power-Degrade-Defect
# 4                    OAM-Loss-Of-Continuity
# 5                                   OAM-RDI
# 6                          Improper-Removal
# 7                     OAMLoss-Of-Continuity
# 8                 Manual-Management-Removal
# 9                           Procedure-Error
# 10          Abnormal-Condition-Laser-Forced
# 11    IOC-Payload-Links-with-Matrix-Failure
# 12                           Loss-Of-Signal
# 13                    Server-Signal-Failure
# 14                       Client-Signal-Fail
# 15                     Loss-of-Connectivity
# 16                           Unexpected-MEG
# 17                         Hardware-failure
# 18          Underlying-Resource-Unavailable
# 19                  Remote-Fault-Indication
# 20        Synchronization-Signal-Fail-Raise
# 21                      House-Keeping-Alarm
# 22  NE-Not-Reachable-Via-Primary-Mng-Interf
# 23                           Node-Isolation
# 24      NE-Not-Reach-Via-Primary-Mng-Interf
#
#                              Cmsg_uppercase  \
# 0                  REMOTE-DEFECT-INDICATION
# 1                                  PPP-FAIL
# 2                                   RX-FAIL
# 3                INPUT-POWER-DEGRADE-DEFECT
# 4                    OAM-LOSS-OF-CONTINUITY
# 5                                   OAM-RDI
# 6                          IMPROPER-REMOVAL
# 7                     OAMLOSS-OF-CONTINUITY
# 8                 MANUAL-MANAGEMENT-REMOVAL
# 9                           PROCEDURE-ERROR
# 10          ABNORMAL-CONDITION-LASER-FORCED
# 11    IOC-PAYLOAD-LINKS-WITH-MATRIX-FAILURE
# 12                           LOSS-OF-SIGNAL
# 13                    SERVER-SIGNAL-FAILURE
# 14                       CLIENT-SIGNAL-FAIL
# 15                     LOSS-OF-CONNECTIVITY
# 16                           UNEXPECTED-MEG
# 17                         HARDWARE-FAILURE
# 18          UNDERLYING-RESOURCE-UNAVAILABLE
# 19                  REMOTE-FAULT-INDICATION
# 20        SYNCHRONIZATION-SIGNAL-FAIL-RAISE
# 21                      HOUSE-KEEPING-ALARM
# 22  NE-NOT-REACHABLE-VIA-PRIMARY-MNG-INTERF
# 23                           NODE-ISOLATION
# 24      NE-NOT-REACH-VIA-PRIMARY-MNG-INTERF
#
#                                           Cmsg_tolong
# 0                                               ALARM
# 1                                       ETHERNET-FAIL
# 2                                        RECEIVE-FAIL
# 3                              INPUT-POWER-LOW-DEFECT
# 4           OPERATION-AND-MAINTENANCE-LOSS-OF-CONNECT
# 5              OPERATION-AND-MAINTENANCE-RECEIVE-FAIL
# 6                                     IMPROPER-REMOVE
# 7           OPERATION-AND-MAINTENANCE-LOSS-OF-CONNECT
# 8                            MANUAL-MANAGEMENT-REMOVE
# 9                                     PROCEDURE-ERROR
# 10                    ABNORMAL-CONDITION-LASER-FORCED
# 11                INPUT-OUTPUT-UNIT-PAYLOAD-LINK-FAIL
# 12                                     LOSS-OF-SIGNAL
# 13                                 SERVER-SIGNAL-FAIL
# 14                                 CLIENT-SIGNAL-FAIL
# 15                                    LOSS-OF-CONNECT
# 16                UNEXPECTED-MULTICAST-ETHERNET-GROUP
# 17                                          UNIT-FAIL
# 18                    UNDERLYING-RESOURCE-UNAVAILABLE
# 19                            REMOTE-FAULT-INDICATION
# 20                        SYNCHRONIZATION-SIGNAL-FAIL
# 21                                              ALARM
# 22  NETWORK-ELEMENT-NO-REACH-VIA-PRIMARY-MANAGEMEN...
# 23                                     NODE-ISOLATION
# 24  NETWORK-ELEMENT-NO-REACH-VIA-PRIMARY-MANAGEMEN...

# %%
# 변환 확인
C_msg_uniq['Cmsg_tolong'].unique()
# Out:
# array(['ALARM', 'ETHERNET-FAIL', 'RECEIVE-FAIL', 'INPUT-POWER-LOW-DEFECT',
#        'OPERATION-AND-MAINTENANCE-LOSS-OF-CONNECT',
#        'OPERATION-AND-MAINTENANCE-RECEIVE-FAIL', 'IMPROPER-REMOVE',
#        'MANUAL-MANAGEMENT-REMOVE', 'PROCEDURE-ERROR',
#        'ABNORMAL-CONDITION-LASER-FORCED',
#        'INPUT-OUTPUT-UNIT-PAYLOAD-LINK-FAIL', 'LOSS-OF-SIGNAL',
#        'SERVER-SIGNAL-FAIL', 'CLIENT-SIGNAL-FAIL', 'LOSS-OF-CONNECT',
#        'UNEXPECTED-MULTICAST-ETHERNET-GROUP', 'UNIT-FAIL',
#        'UNDERLYING-RESOURCE-UNAVAILABLE', 'REMOTE-FAULT-INDICATION',
#        'SYNCHRONIZATION-SIGNAL-FAIL',
#        'NETWORK-ELEMENT-NO-REACH-VIA-PRIMARY-MANAGEMENT-INTERFACE',
#        'NODE-ISOLATION'], dtype=object)

# %% [markdown]
# * djlfaklj

# %%
A_msg_uniq.rename(columns = {'Amsg_not_processed' : 'msg_not_processed'}, inplace = True)
B_msg_uniq.rename(columns = {'Bmsg_not_processed' : 'msg_not_processed'}, inplace = True)
C_msg_uniq.rename(columns = {'Cmsg_not_processed' : 'msg_not_processed'}, inplace = True)

# %%
A_msg_uniq.rename(columns = {'Amsg_tolong' : 'msg_tolong'}, inplace = True)
B_msg_uniq.rename(columns = {'Bmsg_tolong' : 'msg_tolong'}, inplace = True)
C_msg_uniq.rename(columns = {'Cmsg_tolong' : 'msg_tolong'}, inplace = True)

# %%
A_msg_uniq = A_msg_uniq[['msg_not_processed', 'msg_tolong']]
B_msg_uniq = B_msg_uniq[['msg_not_processed', 'msg_tolong']]
C_msg_uniq = C_msg_uniq[['msg_not_processed', 'msg_tolong']]

# %%
A_B_msg = pd.concat([A_msg_uniq, B_msg_uniq], join = 'outer')
A_B_C_msg = pd.concat([A_B_msg, C_msg_uniq], join = 'outer')

# %%
print(A_B_C_msg.shape)
A_B_C_msg.head()
# Out:
# (73, 2)
#    msg_not_processed                           msg_tolong
# 0            ETH-ERR                       ETHERNET-ERROR
# 1           PSU-FAIL               POWER-SUPPLY-UNIT-FAIL
# 2            BOOTING                              BOOTING
# 3  ETH-NO-TX-TRAFFIC     ETHERNET-NO-TRANSMISSION-TRAFFIC
# 4            LSP-LOC  LABEL-SWITCHED-PATH-LOSS-OF-CONNECT

# %%
test_change_msg = pd.merge(test_org, A_B_C_msg, how = 'left',\
                           left_on = 'alarmmsg_original', right_on = 'msg_not_processed')
test_change_msg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37671 entries, 0 to 37670
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ticketno           37671 non-null  float64
#  1   alarmno            37671 non-null  int64
#  2   alarmtime          37671 non-null  object
#  3   alarmlevel         37671 non-null  int64
#  4   alarmmsg_original  37671 non-null  object
#  5   site               37671 non-null  object
#  6   sysname            37671 non-null  object
#  7   unit               37671 non-null  object
#  8   slot               34890 non-null  float64
#  9   port               34853 non-null  float64
#  10  sva                37671 non-null  object
#  11  root_cause_domain  37671 non-null  object
#  12  msg_not_processed  37671 non-null  object
#  13  msg_tolong         37671 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 4.3+ MB

# %%
test_change_msg = test_change_msg.drop(['alarmmsg_original', 'msg_not_processed'], axis = 1)
test_change_msg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37671 entries, 0 to 37670
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ticketno           37671 non-null  float64
#  1   alarmno            37671 non-null  int64
#  2   alarmtime          37671 non-null  object
#  3   alarmlevel         37671 non-null  int64
#  4   site               37671 non-null  object
#  5   sysname            37671 non-null  object
#  6   unit               37671 non-null  object
#  7   slot               34890 non-null  float64
#  8   port               34853 non-null  float64
#  9   sva                37671 non-null  object
#  10  root_cause_domain  37671 non-null  object
#  11  msg_tolong         37671 non-null  object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 3.7+ MB

# %%
test_change_msg = test_change_msg.sort_values(['alarmtime', 'alarmno'])
test_change_msg.head(6)
# Out:
#      ticketno        alarmno                  alarmtime  alarmlevel  site  \
# 0  21812391.0  1671894138838  2022-12-25 00:02:16+09:00           5  AEAQ
# 1  21775988.0  1671894172511  2022-12-25 00:02:51+09:00           5  ADZW
# 2  21792259.0  1671894204682  2022-12-25 00:03:22+09:00           4  AECE
# 3  21812412.0  1671894215702  2022-12-25 00:03:33+09:00           5  ACCN
# 4  21812417.0  1671894220812  2022-12-25 00:03:39+09:00           5  AEAQ
# 5  21775315.0  1671894237831  2022-12-25 00:03:56+09:00           5  ADPE
#
#   sysname                       unit  slot  port  sva root_cause_domain  \
# 0    afbd  r1sr1sl16/ETHLocPort#15#1  16.0  15.0  NSA                 C
# 1    aezn  r1sr1sl13/ETHLocPort#20#1  13.0  20.0  NSA                 C
# 2    afeg                      X2FUA   2.0   1.0  NSA                 B
# 3    aclp                        ---   NaN   NaN   SA                 B
# 4    afbd  r1sr1sl16/ETHLocPort#16#1  16.0  16.0  NSA                 C
# 5    aeiq  r1sr1sl19/ETHLocPort#12#1  19.0  12.0  NSA                 C
#
#                  msg_tolong
# 0            LOSS-OF-SIGNAL
# 1            LOSS-OF-SIGNAL
# 2  ALARM-RECEIVE-POWER-HIGH
# 3  BATTERY-ENVIRONMENT-FAIL
# 4            LOSS-OF-SIGNAL
# 5            LOSS-OF-SIGNAL

# %%
change_col_test = ['ticketno', 'alarmno', 'alarmtime', 'alarmlevel', 'msg_tolong',\
              'site', 'sysname', 'unit', 'slot', 'port', 'sva', 'root_cause_domain']

test_change_msg = test_change_msg[change_col_test]
test_change_msg.rename(columns = {'msg_tolong' : 'alarmmsg_original'}, inplace = True)

# %%
print(test_change_msg['alarmmsg_original'].nunique())
print(test_change_msg['alarmmsg_original'].unique())
print('------------------------------------' * 3)
print(test_org['alarmmsg_original'].nunique())
print(test_org['alarmmsg_original'].unique())
# Out:
# 69
# ['LOSS-OF-SIGNAL' 'ALARM-RECEIVE-POWER-HIGH' 'BATTERY-ENVIRONMENT-FAIL'
#  'ALARM-RECEIVE-POWER-LOW' 'ALARM'
#  'MAINTENANCE-END-POINT-LABEL-SWITCHED-PATH-LOSS-OF-CONNECT'
#  'INPUT-POWER-LOW-DEFECT' 'OPTICAL-LOSS-OF-SIGNAL' 'ETHERNET-LINK-FAIL'
#  'ETHERNET-LINK-DOWN-LOCAL-FAULT'
#  'ETHERNET-LINK-DOWN-LINK-LOST-CARRY-FORWARD' 'SERVER-SIGNAL-FAIL'
#  'ETHERNET-FAIL'
#  'MAINTENANCE-END-POINT-PSEUDOWIRE-EMULATION-LOSS-OF-CONNECT'
#  'RECEIVE-FAIL' 'ETHERNET-ALARM-DROP-1-DAY' 'CLIENT-SIGNAL-FAIL'
#  'LOSS-OF-CONNECT' 'UNEXPECTED-MULTICAST-ETHERNET-GROUP'
#  'ETHERNET-NO-TRANSMISSION-TRAFFIC'
#  'MAINTENANCE-END-POINT-PSEUDOWIRE-EMULATION-CLIENT-SIGNAL-FAIL'
#  'UNIT-FAIL' 'LABEL-SWITCHED-PATH-LOSS-OF-CONNECT'
#  'POWER-SUPPLY-UNIT-FAIL' 'ETHERNET-LINK-DOWN-LOSS-OF-SIGNAL'
#  'OPERATION-AND-MAINTENANCE-LOSS-OF-CONNECT'
#  'NETWORK-ELEMENT-NO-REACH-VIA-PRIMARY-MANAGEMENT-INTERFACE'
#  'NODE-ISOLATION' 'OPTICAL-POWER-LOW' 'OPTICAL-REMOVE'
#  'ETHERNET-ALARM-CYCLIC-REDUNDANCY-CHECK-1-DAY'
#  'ETHERNET-ALARM-CYCLIC-REDUNDANCY-CHECK-15-MINUTE'
#  'ETHERNET-PORT-CYCLIC-REDUNDANCY-CHECK' 'BATTERY-FAIL'
#  'ETHERNET-ALARM-DROP-15-MINUTE' 'BOOTING'
#  'OPERATION-AND-MAINTENANCE-RECEIVE-FAIL' 'DATA-COMMUNICATE-NETWORK-FAIL'
#  'ETHERNET-NO-RECEIVE-TRAFFIC' 'DATA-COMMUNICATE-CHANNEL-FAIL'
#  'ETHERNET-ERROR' 'IMPROPER-REMOVE' 'OPTICAL-POWER-HIGH'
#  'AUTO-NEGOTIATION-MISMATCH' 'UNDERLYING-RESOURCE-UNAVAILABLE'
#  'MODULE-OUT-ENHANCED-SMALL-FORM-FACTOR-PLUG'
#  'MODULE-OUT-SMALL-FORM-FACTOR-PLUG' 'BATTERY-INPUT-A-FAIL'
#  'TRACK-CONNECT-MISMATCH' 'MANUAL-MANAGEMENT-REMOVE'
#  'MAINTENANCE-END-POINT-LABEL-SWITCHED-PATH-RECEIVE-FAIL'
#  'PSEUDOWIRE-LOSS-OF-CONNECT' 'PROCEDURE-ERROR' 'OPTICAL-MISMATCH'
#  'ETHERNET-LINK-DOWN-REMOTE-FAULT' 'UNIT-INIT-BY-IN-SLOT'
#  'UNIT-INIT-BY-RESET' 'UNIT-OUT'
#  'SYNCHRONOUS-TRANSPORT-MODULE-LEVEL-1-LOSS-OF-SIGNAL'
#  'SYSTEM-TEMPARATURE-LOW' 'TIME-DIVISION-MULTIPLEX-PSEUDOWIRE-REMOTE-FAIL'
#  'LINK-FAIL-MANUAL' 'ABNORMAL-CONDITION-LASER-FORCED' 'QUALITY-FAIL'
#  'INPUT-OUTPUT-UNIT-PAYLOAD-LINK-FAIL' '48V-FAIL'
#  'REMOTE-FAULT-INDICATION' 'CLIENT-ENVIRONMENT-PROTECTION-ALARM'
#  'SYNCHRONIZATION-SIGNAL-FAIL']
# ------------------------------------------------------------------------------------------------------------
# 73
# ['Loss Of Signal' 'DDM_RX_PWR_HIGH' 'BATT_ENV_FAIL' 'DDM_RX_PWR_LOW'
#  'Remote Defect Indication' 'MEP_LSP_LOC' 'Input Power Degrade Defect'
#  'OPT-LOS' 'ETH-LINK-FAIL' 'ETHER_LINK_DOWN (LOCAL_FAULT)'
#  'ETHER_LINK_DOWN (LLCF)' 'Server Signal Failure' 'PPP Fail' 'MEP_PWE_LOC'
#  'House Keeping Alarm' 'Rx Fail' 'ETHER_TCA_DROP_1D' 'Client Signal Fail'
#  'Loss of Connectivity' 'Unexpected MEG' 'ETH-NO-TX-TRAFFIC' 'MEP_PWE_CSF'
#  'UNIT_FAIL' 'LSP-LOC' 'PSU-FAIL' 'ETHER_LINK_DOWN (LOS)'
#  'OAM Loss Of Continuity' 'NE Not Reachable Via Primary Mng Interf'
#  'Node Isolation' 'NE Not Reach Via Primary Mng Interf' 'OPT-PWR-LOW'
#  'OPT-REMOVE' 'ETHER_TCA_CRC_15M' 'ETHER_TCA_CRC_1D' 'ETHER_PORT_CRC'
#  'BATTERY_FAIL' 'ETHER_TCA_DROP_15M' 'BOOTING' 'OAM RDI'
#  'Hardware failure' 'DCN_FAIL' 'ETH-NO-RX-TRAFFIC' 'DCC-FAIL' 'ETH-ERR'
#  'Improper Removal' 'OPT-PWR-HIGH' 'AUTONEGO_MISMATCH'
#  'Underlying Resource Unavailable' 'OAMLoss Of Continuity'
#  'MODULE_OUT ( SFP+ )' 'MODULE_OUT ( SFP )' 'DC_INPUT_A_FAIL'
#  'TRK-CONN-MIS' 'Manual (Management) Removal' 'MEP_LSP_RDI' 'PW-LOC'
#  'Procedure Error' 'OPT-MIS' 'ETHER_LINK_DOWN (REMOTE_FAULT)'
#  'UNIT_INIT (BY INSLOT)' 'UNIT_INIT (BY RESET)' 'UNIT_OUT' 'STM1_LOS'
#  'SYS_TEMP_LOW' 'TDM-PW-RMT_FAIL' 'LINK_FAIL_MANUAL'
#  'Abnormal Condition: Laser Forced' 'QL_FAIL'
#  'IOC Payload-Links with Matrix Failure' '48V-FAIL'
#  'Remote Fault Indication' 'CEP_AIS' 'Synchronization Signal Fail Raise']

# %% [markdown]
# # 2. Pre-Processing 과정은 각 모델링 파일에 첨부함

# %% [markdown]
# # **EDA(탐색적 자료 분석)**

# %%
# train의 제조사와 알람레벨별 알람메시지
train_A = train_org[['root_cause_domain', 'alarmlevel', 'alarmmsg_original']].drop_duplicates().sort_values(['root_cause_domain', 'alarmlevel'])
print(len(train_A))
train_A
# Out:
# 32
#      root_cause_domain  alarmlevel   alarmmsg_original
# 1663                 A           3  ProtectionSwitched
# 4069                 A           3           Restarted
# 4422                 A           3             LSP-LOC
# 4770                 A           3        PortShutdown
# 102                  A           4            PSU-FAIL
# 2906                 A           4             BOOTING
# 4673                 A           4        FAN-48V-FAIL
# 4675                 A           4            FAN-FAIL
# 8143                 A           4             PSU-REM
# 0                    A           5             ETH-ERR
# 6                    A           5            DCC-FAIL
# 8                    A           5             LSP-LOC
# 11                   A           5   ETH-NO-RX-TRAFFIC
# 27                   A           5         OPT-PWR-LOW
# 107                  A           5   AUTONEGO_MISMATCH
# 248                  A           5     TDM-PW-RMT_FAIL
# 2790                 A           5              PW-LOC
# 2828                 A           5            BATT-LOW
# 3565                 A           5   ETH-NO-TX-TRAFFIC
# 4073                 A           5         OS_MISMATCH
# 4147                 A           5          TDM-PW-LOF
# 4678                 A           5            48V-FAIL
# 6309                 A           5             QL_FAIL
# 5                    A           7             OPT-LOS
# 103                  A           7       ETH-LINK-FAIL
# 411                  A           7          OPT-REMOVE
# 1445                 A           7        TRK-CONN-MIS
# 1805                 A           7          NVRAM-FAIL
# 4082                 A           7            UNIT-REM
# 6478                 A           7       UNIT-IPC-FAIL
# 7519                 A           7    LINK_FAIL_MANUAL
# 8507                 A           7             OPT-MIS

# %%
# test의 제조사와 알람레벨별 알람메시지
test_ABC = test_org[['root_cause_domain', 'alarmlevel', 'alarmmsg_original']].drop_duplicates().sort_values(['root_cause_domain', 'alarmlevel'])
print(len(test_ABC))
test_ABC
# Out:
# 85
#       root_cause_domain  alarmlevel                        alarmmsg_original
# 12494                 A           3                                  ETH-ERR
# 1568                  A           4                                 PSU-FAIL
# 3042                  A           4                                  BOOTING
# 460                   A           5                        ETH-NO-TX-TRAFFIC
# 1453                  A           5                                  LSP-LOC
# 1917                  A           5                              OPT-PWR-LOW
# 5965                  A           5                        ETH-NO-RX-TRAFFIC
# 5969                  A           5                                 DCC-FAIL
# 6125                  A           5                                  ETH-ERR
# 6506                  A           5                             OPT-PWR-HIGH
# 6524                  A           5                        AUTONEGO_MISMATCH
# 7663                  A           5                                   PW-LOC
# 13109                 A           5                          TDM-PW-RMT_FAIL
# 13615                 A           5                                  QL_FAIL
# 14499                 A           5                                 48V-FAIL
# 39                    A           7                                  OPT-LOS
# 100                   A           7                            ETH-LINK-FAIL
# 2263                  A           7                               OPT-REMOVE
# 7228                  A           7                             TRK-CONN-MIS
# 7883                  A           7                                  OPT-MIS
# 13427                 A           7                         LINK_FAIL_MANUAL
# 2                     B           4                          DDM_RX_PWR_HIGH
# 8                     B           4                           DDM_RX_PWR_LOW
# 396                   B           4                        ETHER_TCA_DROP_1D
# 2338                  B           4                        ETHER_TCA_CRC_15M
# 2339                  B           4                         ETHER_TCA_CRC_1D
# 2469                  B           4                           ETHER_PORT_CRC
# 2612                  B           4                             BATTERY_FAIL
# 2864                  B           4                       ETHER_TCA_DROP_15M
# 6801                  B           4                          DC_INPUT_A_FAIL
# 9306                  B           4                                 DCN_FAIL
# 10970                 B           4                    UNIT_INIT (BY INSLOT)
# 11091                 B           4                     UNIT_INIT (BY RESET)
# 11092                 B           4                                 UNIT_OUT
# 11192                 B           4                       MODULE_OUT ( SFP )
# 11325                 B           4                                 STM1_LOS
# 27306                 B           4                              MEP_LSP_RDI
# 3                     B           5                            BATT_ENV_FAIL
# 16                    B           5                              MEP_LSP_LOC
# 213                   B           5                              MEP_PWE_LOC
# 1197                  B           5                              MEP_PWE_CSF
# 5844                  B           5                                 DCN_FAIL
# 7553                  B           5                              MEP_LSP_RDI
# 12927                 B           5                             SYS_TEMP_LOW
# 33879                 B           5                                  CEP_AIS
# 150                   B           7            ETHER_LINK_DOWN (LOCAL_FAULT)
# 152                   B           7                   ETHER_LINK_DOWN (LLCF)
# 1316                  B           7                                UNIT_FAIL
# 1575                  B           7                    ETHER_LINK_DOWN (LOS)
# 6727                  B           7                      MODULE_OUT ( SFP+ )
# 6732                  B           7                       MODULE_OUT ( SFP )
# 10932                 B           7           ETHER_LINK_DOWN (REMOTE_FAULT)
# 11216                 B           7                                 STM1_LOS
# 14459                 B           7                                 UNIT_OUT
# 19845                 B           7                     UNIT_INIT (BY RESET)
# 10                    C           3                 Remote Defect Indication
# 165                   C           4                                 PPP Fail
# 309                   C           4                                  Rx Fail
# 395                   C           4               Input Power Degrade Defect
# 4399                  C           4                   OAM Loss Of Continuity
# 4432                  C           4                                  OAM RDI
# 6414                  C           4                         Improper Removal
# 6717                  C           4                    OAMLoss Of Continuity
# 7378                  C           4              Manual (Management) Removal
# 7765                  C           4                          Procedure Error
# 13463                 C           4         Abnormal Condition: Laser Forced
# 13955                 C           4    IOC Payload-Links with Matrix Failure
# 0                     C           5                           Loss Of Signal
# 17                    C           5               Input Power Degrade Defect
# 160                   C           5                    Server Signal Failure
# 407                   C           5                       Client Signal Fail
# 427                   C           5                     Loss of Connectivity
# 428                   C           5                           Unexpected MEG
# 1594                  C           5                   OAM Loss Of Continuity
# 4846                  C           5                         Hardware failure
# 6424                  C           5                         Improper Removal
# 6593                  C           5          Underlying Resource Unavailable
# 8100                  C           5              Manual (Management) Removal
# 8112                  C           5                          Procedure Error
# 15337                 C           5                  Remote Fault Indication
# 36699                 C           5        Synchronization Signal Fail Raise
# 249                   C           7                      House Keeping Alarm
# 1893                  C           7  NE Not Reachable Via Primary Mng Interf
# 1907                  C           7                           Node Isolation
# 1908                  C           7      NE Not Reach Via Primary Mng Interf

# %%
# alarmlevel별 타겟 분포 그래프
fig = plt.figure(figsize = (8, 6))


ax1 = fig.add_subplot(1, 2, 1)
sns.countplot(x = 'alarmlevel', data = train_org, ax = ax1)
ax1.set_xlabel('alarmlevel')

ax1.set_title('Dist of alarmlevel')

ax2 = fig.add_subplot(1, 2, 2)
sns.countplot(x = 'alarmlevel', data = train_org, hue ='root_cause_type', ax = ax2)
ax2.set_title('Dist of alarmlevel by root_cause_type')

plt.show()

# %%
# 타겟 분포 그래프
sns.countplot(x='root_cause_type', data=train_org)
# Out:
# <Axes: xlabel='root_cause_type', ylabel='count'>
